# %%
from math import sqrt
import pandas as pd
import numpy as np
import os
import torch
import torch.nn.functional as F
from rdkit import Chem
import matplotlib.pyplot as plt

from torch_geometric.loader import DataLoader
from torch_geometric.datasets import MoleculeNet
from torch_geometric.nn import global_mean_pool, global_max_pool
# %matplotlib inline

# %%
gpuid = 0
torch.cuda.set_device(gpuid)
print(torch.cuda.current_device())
# Out:
# 0

# %%
import sys
sys.path.insert(0, '/home/was966/Research/bidd-clsar/')

# %%
from clsar.dataset import LSSNS, HSSMS
from clsar.feature import Gen39AtomFeatures
from clsar.model.model import ACANet_PNA, get_deg, _fix_reproducibility,ACANet_GAT, ACANet_GCN, ACANet_GIN
from clsar.model.loss import ACALoss, get_best_cliff
_fix_reproducibility(42)

# %%
ACANET_MODEL = ACANet_GIN

# %%
def train(train_loader, model, optimizer, aca_loss):

    total_examples = 0
    total_loss =  0    
    total_tsm_loss = 0
    total_reg_loss = 0   
    n_triplets = []
    n_pos_triplets = []
    model.train()
    for i, data in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        predictions, embeddings = model(data.x.float(), data.edge_index, 
                                        data.edge_attr, data.batch)
        
        loss_out = aca_loss(labels = data.y, 
                            predictions = predictions,
                            embeddings = embeddings)
        loss, reg_loss, tsm_loss, n, n_pos = loss_out
        
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
        total_tsm_loss += float(tsm_loss) * data.num_graphs        
        total_reg_loss += float(reg_loss) * data.num_graphs        
        total_examples += data.num_graphs
        
        n_triplets.append(int(n))
        n_pos_triplets.append(int(n_pos))
        
    train_loss = total_loss / total_examples
    total_tsm_loss = total_tsm_loss / total_examples
    total_reg_loss = total_reg_loss / total_examples
    n_triplets = int(sum(n_triplets) / (i+1))
    n_pos_triplets = int(sum(n_pos_triplets) / (i+1))
    
    return train_loss, total_tsm_loss, total_reg_loss, n_triplets, n_pos_triplets

@torch.no_grad()
def test(test_loader, model, aca_loss):
    model.eval()
    total_examples = 0
    total_loss = 0
    total_tsm_loss = 0
    total_reg_loss = 0
    n_triplets = []
    n_pos_triplets = []
    mse = []
    for i, data in enumerate(test_loader):
        data = data.to(device)
        predictions, embeddings = model(data.x.float(), data.edge_index,
                                        data.edge_attr, data.batch)
        loss_out = aca_loss(labels=data.y,
                            predictions=predictions,
                            embeddings=embeddings)

        loss, reg_loss, tsm_loss, n, n_pos = loss_out

        total_loss += float(loss) * data.num_graphs
        total_tsm_loss += float(tsm_loss) * data.num_graphs
        total_reg_loss += float(reg_loss) * data.num_graphs
        total_examples += data.num_graphs

        n_triplets.append(int(n))
        n_pos_triplets.append(int(n_pos))

        mse.append(F.mse_loss(predictions, data.y, reduction='none').cpu())

    test_loss = total_loss / total_examples
    total_tsm_loss = total_tsm_loss / total_examples
    total_reg_loss = total_reg_loss / total_examples
    n_triplets = int(sum(n_triplets) / (i+1))
    n_pos_triplets = int(sum(n_pos_triplets) / (i+1))
    
    test_rmse = float(torch.cat(mse, dim=0).mean().sqrt())
    
    return test_loss, total_tsm_loss, total_reg_loss, n_triplets, n_pos_triplets, test_rmse



def Test_performance(alpha=1.0):
    
    
    model = ACANET_MODEL(**pub_args, train_eps = True).to(device)  
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=10**-5)
    aca_loss = ACALoss(alpha=alpha, cliff_lower = 1., cliff_upper = 1.)
    
    history = []
    #ls_his = []
    for epoch in range(1, epochs):
        train_loss, tsm_loss, reg_loss, n_triplets, n_pos_triplets = train(train_loader, model, optimizer, aca_loss)

        _, _, _, _, train_n_pos_triplets, train_rmse = test(train_loader, model, aca_loss)
        _, _, _, _, val_n_pos_triplets, val_rmse = test(val_loader, model, aca_loss)
        _, _, _, _, test_n_pos_triplets, test_rmse = test(test_loader, model, aca_loss)

        
        print(f'Epoch: {epoch:03d}, Loss: {train_loss:.4f} tsm_loss: {tsm_loss:.4f} reg_loss: {reg_loss:.4f} '
              f'n_pos_triplets: {n_pos_triplets:03d};  Val: {val_rmse:.4f} Test: {test_rmse:.4f}')
    
        history.append({'Epoch':epoch, 'train_loss':train_loss, 'train_triplet_loss':tsm_loss,'train_mae_loss':reg_loss,
                        'val_rmse':val_rmse, 'test_rmse':test_rmse, 'train_rmse':train_rmse,'n_triplets': n_triplets, 
                        'n_pos_triplets':n_pos_triplets, 
                        'train_n_pos_triplets':train_n_pos_triplets,
                        'val_n_pos_triplets':val_n_pos_triplets,
                        'test_n_pos_triplets':test_n_pos_triplets,
                       
                       })
        #ls_his.append({'Epoch':epoch, 'mae_loss':float(mae_loss), 'triplet_loss':float(triplet_loss)})
    dfh = pd.DataFrame(history)
    return dfh

# %%
dataset_name = 'CHEMBL3979_EC50'
Dataset =  HSSMS #LSSNS 
epochs = 800
batch_size = 128
lr = 1e-4

pre_transform = Gen39AtomFeatures()
in_channels = pre_transform.in_channels
path = '../data/'

## model HPs
pub_args = {'in_channels':pre_transform.in_channels, 
            'edge_dim':pre_transform.edge_dim,
            'convs_layers': [64, 128, 256, 512],   
            'dense_layers': [256, 128, 32], 
            'out_channels':1, 
            # 'aggregators': ['mean', 'min', 'max', 'sum','std'],
            # 'scalers':['identity', 'amplification', 'attenuation'] ,
            'dropout_p': 0}

# %%
len(Dataset(path, name=dataset_name, pre_transform=pre_transform).shuffle(42))
# Out:
# 1125

# %%
# train, valid, test splitting
res1 = []
res2 = []
for seed in [8, 16, 24, 42, 64, 128, 256, 512, 1024, 2048]:
    dataset = Dataset(path, name=dataset_name, pre_transform=pre_transform).shuffle(42)
    N = len(dataset) // 5
    val_dataset = dataset[:N]
    test_dataset = dataset[N:2 * N]
    train_dataset = dataset[2 * N:]
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    deg = get_deg(train_dataset)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # With AC-Awareness ($\alpha = 1$)
    df1 = Test_performance(alpha=1.0)
    df1['seed'] = seed
    # Without AC-Awareness ($\alpha = 0$)
    df2 = Test_performance(alpha=0.0)
    df2['seed'] = seed
    res1.append(df1)
    res2.append(df2)
# Out:
# /home/was966/micromamba/envs/responder/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /home/was966/micromamba/envs/responder/lib/python3.8/site-packages/torch_geometric/warnings.py:17: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# Epoch: 001, Loss: 12.2169 tsm_loss: 5.6128 reg_loss: 6.6041 n_pos_triplets: 220218;  Val: 6.6338 Test: 6.6553
# Epoch: 002, Loss: 10.8433 tsm_loss: 4.6742 reg_loss: 6.1691 n_pos_triplets: 214672;  Val: 6.5979 Test: 6.6187
# Epoch: 003, Loss: 9.8324 tsm_loss: 4.2639 reg_loss: 5.5685 n_pos_triplets: 215424;  Val: 6.4137 Test: 6.4308
# Epoch: 004, Loss: 8.3810 tsm_loss: 3.7004 reg_loss: 4.6806 n_pos_triplets: 211580;  Val: 5.9056 Test: 5.9181
# Epoch: 005, Loss: 6.7112 tsm_loss: 3.2691 reg_loss: 3.4421 n_pos_triplets: 210668;  Val: 4.8523 Test: 4.8627
# Epoch: 006, Loss: 4.8344 tsm_loss: 3.0232 reg_loss: 1.8112 n_pos_triplets: 210166;  Val: 3.1186 Test: 3.1321
# Epoch: 007, Loss: 3.8548 tsm_loss: 2.7685 reg_loss: 1.0863 n_pos_triplets: 206288;  Val: 1.5612 Test: 1.5742
# Epoch: 008, Loss: 3.7627 tsm_loss: 2.4861 reg_loss: 1.2767 n_pos_triplets: 199487;  Val: 1.2704 Test: 1.2653
# Epoch: 009, Loss: 3.2329 tsm_loss: 2.3298 reg_loss: 0.9032 n_pos_triplets: 195429;  Val: 1.4226 Test: 1.4066
# Epoch: 010, Loss: 3.0443 tsm_loss: 2.1610 reg_loss: 0.8833 n_pos_triplets: 192013;  Val: 1.2618 Test: 1.2457
# Epoch: 011, Loss: 2.8962 tsm_loss: 2.0904 reg_loss: 0.8058 n_pos_triplets: 189714;  Val: 0.9490 Test: 0.9281
# Epoch: 012, Loss: 2.7072 tsm_loss: 1.9749 reg_loss: 0.7323 n_pos_triplets: 187316;  Val: 0.8725 Test: 0.8584
# Epoch: 013, Loss: 2.5745 tsm_loss: 1.8807 reg_loss: 0.6939 n_pos_triplets: 181081;  Val: 0.8587 Test: 0.8473
# Epoch: 014, Loss: 2.4674 tsm_loss: 1.8072 reg_loss: 0.6602 n_pos_triplets: 180060;  Val: 0.8366 Test: 0.8277
# Epoch: 015, Loss: 2.3547 tsm_loss: 1.7301 reg_loss: 0.6247 n_pos_triplets: 174426;  Val: 0.8082 Test: 0.8060
# Epoch: 016, Loss: 2.3443 tsm_loss: 1.7141 reg_loss: 0.6303 n_pos_triplets: 175040;  Val: 0.7886 Test: 0.7945
# Epoch: 017, Loss: 2.2209 tsm_loss: 1.6239 reg_loss: 0.5971 n_pos_triplets: 174792;  Val: 0.8017 Test: 0.8040
# Epoch: 018, Loss: 2.1850 tsm_loss: 1.5884 reg_loss: 0.5966 n_pos_triplets: 171047;  Val: 0.7713 Test: 0.7753
# Epoch: 019, Loss: 2.1316 tsm_loss: 1.5476 reg_loss: 0.5839 n_pos_triplets: 169143;  Val: 0.7479 Test: 0.7629
# Epoch: 020, Loss: 2.0194 tsm_loss: 1.4737 reg_loss: 0.5457 n_pos_triplets: 166268;  Val: 0.7388 Test: 0.7623
# Epoch: 021, Loss: 1.9949 tsm_loss: 1.4564 reg_loss: 0.5386 n_pos_triplets: 167012;  Val: 0.7396 Test: 0.7592
# Epoch: 022, Loss: 1.9481 tsm_loss: 1.4169 reg_loss: 0.5312 n_pos_triplets: 164534;  Val: 0.7294 Test: 0.7467
# Epoch: 023, Loss: 1.9179 tsm_loss: 1.3869 reg_loss: 0.5310 n_pos_triplets: 161291;  Val: 0.7297 Test: 0.7392
# Epoch: 024, Loss: 1.8445 tsm_loss: 1.3299 reg_loss: 0.5146 n_pos_triplets: 160740;  Val: 0.7232 Test: 0.7316
# Epoch: 025, Loss: 1.8199 tsm_loss: 1.3203 reg_loss: 0.4996 n_pos_triplets: 160540;  Val: 0.7174 Test: 0.7291
# Epoch: 026, Loss: 1.7799 tsm_loss: 1.2807 reg_loss: 0.4992 n_pos_triplets: 156861;  Val: 0.7168 Test: 0.7241
# Epoch: 027, Loss: 1.7508 tsm_loss: 1.2605 reg_loss: 0.4903 n_pos_triplets: 154477;  Val: 0.7069 Test: 0.7302
# Epoch: 028, Loss: 1.6686 tsm_loss: 1.1982 reg_loss: 0.4704 n_pos_triplets: 152195;  Val: 0.7033 Test: 0.7256
# Epoch: 029, Loss: 1.6831 tsm_loss: 1.2114 reg_loss: 0.4717 n_pos_triplets: 154935;  Val: 0.7024 Test: 0.7261
# Epoch: 030, Loss: 1.6855 tsm_loss: 1.2114 reg_loss: 0.4741 n_pos_triplets: 156843;  Val: 0.6988 Test: 0.7287
# Epoch: 031, Loss: 1.5946 tsm_loss: 1.1359 reg_loss: 0.4587 n_pos_triplets: 147832;  Val: 0.7008 Test: 0.7246
# Epoch: 032, Loss: 1.6061 tsm_loss: 1.1487 reg_loss: 0.4574 n_pos_triplets: 148744;  Val: 0.6924 Test: 0.7223
# Epoch: 033, Loss: 1.5648 tsm_loss: 1.1219 reg_loss: 0.4429 n_pos_triplets: 150199;  Val: 0.6953 Test: 0.7208
# Epoch: 034, Loss: 1.5896 tsm_loss: 1.1417 reg_loss: 0.4479 n_pos_triplets: 145761;  Val: 0.6853 Test: 0.7192
# Epoch: 035, Loss: 1.5285 tsm_loss: 1.0868 reg_loss: 0.4417 n_pos_triplets: 145774;  Val: 0.6915 Test: 0.7173
# Epoch: 036, Loss: 1.5150 tsm_loss: 1.0618 reg_loss: 0.4532 n_pos_triplets: 144221;  Val: 0.6938 Test: 0.7257
# Epoch: 037, Loss: 1.4889 tsm_loss: 1.0549 reg_loss: 0.4340 n_pos_triplets: 141032;  Val: 0.6860 Test: 0.7099
# Epoch: 038, Loss: 1.4432 tsm_loss: 1.0207 reg_loss: 0.4225 n_pos_triplets: 142768;  Val: 0.6804 Test: 0.7049
# Epoch: 039, Loss: 1.4143 tsm_loss: 0.9929 reg_loss: 0.4214 n_pos_triplets: 140427;  Val: 0.6805 Test: 0.7060
# Epoch: 040, Loss: 1.4194 tsm_loss: 0.9941 reg_loss: 0.4253 n_pos_triplets: 140041;  Val: 0.6821 Test: 0.7058
# Epoch: 041, Loss: 1.4071 tsm_loss: 0.9737 reg_loss: 0.4334 n_pos_triplets: 137407;  Val: 0.6931 Test: 0.7086
# Epoch: 042, Loss: 1.4267 tsm_loss: 0.9886 reg_loss: 0.4381 n_pos_triplets: 140678;  Val: 0.6767 Test: 0.7070
# Epoch: 043, Loss: 1.4426 tsm_loss: 0.9968 reg_loss: 0.4458 n_pos_triplets: 139264;  Val: 0.6753 Test: 0.6960
# Epoch: 044, Loss: 1.3612 tsm_loss: 0.9292 reg_loss: 0.4320 n_pos_triplets: 134002;  Val: 0.6904 Test: 0.7035
# Epoch: 045, Loss: 1.3720 tsm_loss: 0.9658 reg_loss: 0.4062 n_pos_triplets: 138826;  Val: 0.6740 Test: 0.7002
# Epoch: 046, Loss: 1.3464 tsm_loss: 0.9381 reg_loss: 0.4083 n_pos_triplets: 136210;  Val: 0.6829 Test: 0.6997
# Epoch: 047, Loss: 1.3076 tsm_loss: 0.9098 reg_loss: 0.3978 n_pos_triplets: 131793;  Val: 0.6856 Test: 0.6932
# Epoch: 048, Loss: 1.3421 tsm_loss: 0.9521 reg_loss: 0.3900 n_pos_triplets: 137999;  Val: 0.6704 Test: 0.6986
# Epoch: 049, Loss: 1.2890 tsm_loss: 0.8935 reg_loss: 0.3956 n_pos_triplets: 134179;  Val: 0.6857 Test: 0.6945
# Epoch: 050, Loss: 1.2949 tsm_loss: 0.8959 reg_loss: 0.3990 n_pos_triplets: 132370;  Val: 0.6784 Test: 0.6898
# Epoch: 051, Loss: 1.2613 tsm_loss: 0.8671 reg_loss: 0.3942 n_pos_triplets: 128371;  Val: 0.6709 Test: 0.6867
# Epoch: 052, Loss: 1.2603 tsm_loss: 0.8847 reg_loss: 0.3756 n_pos_triplets: 130388;  Val: 0.6767 Test: 0.6810
# Epoch: 053, Loss: 1.2760 tsm_loss: 0.8999 reg_loss: 0.3761 n_pos_triplets: 135269;  Val: 0.6746 Test: 0.6852
# Epoch: 054, Loss: 1.2631 tsm_loss: 0.8733 reg_loss: 0.3898 n_pos_triplets: 134023;  Val: 0.6809 Test: 0.6880
# Epoch: 055, Loss: 1.2175 tsm_loss: 0.8395 reg_loss: 0.3780 n_pos_triplets: 129490;  Val: 0.6832 Test: 0.7006
# Epoch: 056, Loss: 1.2056 tsm_loss: 0.8226 reg_loss: 0.3831 n_pos_triplets: 128398;  Val: 0.6749 Test: 0.6805
# Epoch: 057, Loss: 1.2186 tsm_loss: 0.8379 reg_loss: 0.3807 n_pos_triplets: 126613;  Val: 0.6995 Test: 0.7049
# Epoch: 058, Loss: 1.2102 tsm_loss: 0.8256 reg_loss: 0.3846 n_pos_triplets: 128098;  Val: 0.6797 Test: 0.6714
# Epoch: 059, Loss: 1.1777 tsm_loss: 0.8226 reg_loss: 0.3550 n_pos_triplets: 126329;  Val: 0.6719 Test: 0.6821
# Epoch: 060, Loss: 1.2213 tsm_loss: 0.8317 reg_loss: 0.3896 n_pos_triplets: 129756;  Val: 0.6988 Test: 0.7044
# Epoch: 061, Loss: 1.1883 tsm_loss: 0.8125 reg_loss: 0.3758 n_pos_triplets: 128002;  Val: 0.6591 Test: 0.6879
# Epoch: 062, Loss: 1.1532 tsm_loss: 0.7829 reg_loss: 0.3703 n_pos_triplets: 126860;  Val: 0.6864 Test: 0.6905
# Epoch: 063, Loss: 1.1608 tsm_loss: 0.7894 reg_loss: 0.3714 n_pos_triplets: 126832;  Val: 0.6718 Test: 0.6827
# Epoch: 064, Loss: 1.1405 tsm_loss: 0.7790 reg_loss: 0.3616 n_pos_triplets: 124804;  Val: 0.6806 Test: 0.6845
# Epoch: 065, Loss: 1.1257 tsm_loss: 0.7696 reg_loss: 0.3561 n_pos_triplets: 124256;  Val: 0.6927 Test: 0.6974
# Epoch: 066, Loss: 1.1058 tsm_loss: 0.7482 reg_loss: 0.3576 n_pos_triplets: 125298;  Val: 0.6773 Test: 0.6778
# Epoch: 067, Loss: 1.0960 tsm_loss: 0.7481 reg_loss: 0.3479 n_pos_triplets: 122459;  Val: 0.6649 Test: 0.6801
# Epoch: 068, Loss: 1.0773 tsm_loss: 0.7182 reg_loss: 0.3591 n_pos_triplets: 117265;  Val: 0.6694 Test: 0.6872
# Epoch: 069, Loss: 1.0936 tsm_loss: 0.7420 reg_loss: 0.3515 n_pos_triplets: 118517;  Val: 0.6749 Test: 0.6809
# Epoch: 070, Loss: 1.0982 tsm_loss: 0.7374 reg_loss: 0.3608 n_pos_triplets: 122771;  Val: 0.6694 Test: 0.6850
# Epoch: 071, Loss: 1.0844 tsm_loss: 0.7306 reg_loss: 0.3538 n_pos_triplets: 119842;  Val: 0.6839 Test: 0.6932
# Epoch: 072, Loss: 1.0321 tsm_loss: 0.7036 reg_loss: 0.3286 n_pos_triplets: 118661;  Val: 0.6608 Test: 0.6705
# Epoch: 073, Loss: 1.0377 tsm_loss: 0.7052 reg_loss: 0.3325 n_pos_triplets: 116616;  Val: 0.6683 Test: 0.6680
# Epoch: 074, Loss: 1.0526 tsm_loss: 0.7223 reg_loss: 0.3303 n_pos_triplets: 120250;  Val: 0.6669 Test: 0.6676
# Epoch: 075, Loss: 1.0465 tsm_loss: 0.7164 reg_loss: 0.3301 n_pos_triplets: 118634;  Val: 0.6781 Test: 0.6979
# Epoch: 076, Loss: 1.0482 tsm_loss: 0.7075 reg_loss: 0.3407 n_pos_triplets: 117958;  Val: 0.6704 Test: 0.6822
# Epoch: 077, Loss: 1.0207 tsm_loss: 0.6946 reg_loss: 0.3261 n_pos_triplets: 116994;  Val: 0.6799 Test: 0.6929
# Epoch: 078, Loss: 1.0323 tsm_loss: 0.7068 reg_loss: 0.3255 n_pos_triplets: 115890;  Val: 0.6632 Test: 0.6705
# Epoch: 079, Loss: 1.0141 tsm_loss: 0.6861 reg_loss: 0.3280 n_pos_triplets: 116516;  Val: 0.6740 Test: 0.6727
# Epoch: 080, Loss: 1.0113 tsm_loss: 0.6833 reg_loss: 0.3280 n_pos_triplets: 115065;  Val: 0.6711 Test: 0.6610
# Epoch: 081, Loss: 0.9673 tsm_loss: 0.6434 reg_loss: 0.3240 n_pos_triplets: 115755;  Val: 0.6772 Test: 0.6737
# Epoch: 082, Loss: 0.9606 tsm_loss: 0.6579 reg_loss: 0.3027 n_pos_triplets: 114291;  Val: 0.6609 Test: 0.6639
# Epoch: 083, Loss: 0.9591 tsm_loss: 0.6383 reg_loss: 0.3208 n_pos_triplets: 116709;  Val: 0.6582 Test: 0.6651
# Epoch: 084, Loss: 0.9759 tsm_loss: 0.6625 reg_loss: 0.3134 n_pos_triplets: 115922;  Val: 0.6681 Test: 0.6584
# Epoch: 085, Loss: 0.9412 tsm_loss: 0.6339 reg_loss: 0.3073 n_pos_triplets: 111773;  Val: 0.6995 Test: 0.6929
# Epoch: 086, Loss: 0.9503 tsm_loss: 0.6415 reg_loss: 0.3088 n_pos_triplets: 112645;  Val: 0.6734 Test: 0.6622
# Epoch: 087, Loss: 0.9533 tsm_loss: 0.6392 reg_loss: 0.3142 n_pos_triplets: 110143;  Val: 0.6769 Test: 0.6726
# Epoch: 088, Loss: 0.9782 tsm_loss: 0.6531 reg_loss: 0.3252 n_pos_triplets: 115848;  Val: 0.6929 Test: 0.6616
# Epoch: 089, Loss: 0.9623 tsm_loss: 0.6393 reg_loss: 0.3230 n_pos_triplets: 112546;  Val: 0.6796 Test: 0.6712
# Epoch: 090, Loss: 0.9416 tsm_loss: 0.6328 reg_loss: 0.3088 n_pos_triplets: 112233;  Val: 0.6988 Test: 0.6958
# Epoch: 091, Loss: 0.9469 tsm_loss: 0.6339 reg_loss: 0.3130 n_pos_triplets: 110374;  Val: 0.6834 Test: 0.6866
# Epoch: 092, Loss: 0.9414 tsm_loss: 0.6263 reg_loss: 0.3150 n_pos_triplets: 112857;  Val: 0.6545 Test: 0.6529
# Epoch: 093, Loss: 0.9424 tsm_loss: 0.6355 reg_loss: 0.3069 n_pos_triplets: 112845;  Val: 0.6856 Test: 0.6650
# Epoch: 094, Loss: 0.9292 tsm_loss: 0.6168 reg_loss: 0.3124 n_pos_triplets: 110811;  Val: 0.6756 Test: 0.6513
# Epoch: 095, Loss: 0.9038 tsm_loss: 0.6162 reg_loss: 0.2875 n_pos_triplets: 108365;  Val: 0.6663 Test: 0.6474
# Epoch: 096, Loss: 0.8788 tsm_loss: 0.5960 reg_loss: 0.2828 n_pos_triplets: 108065;  Val: 0.6640 Test: 0.6564
# Epoch: 097, Loss: 0.8887 tsm_loss: 0.6035 reg_loss: 0.2852 n_pos_triplets: 105517;  Val: 0.6798 Test: 0.6496
# Epoch: 098, Loss: 0.8597 tsm_loss: 0.5898 reg_loss: 0.2699 n_pos_triplets: 105454;  Val: 0.6733 Test: 0.6448
# Epoch: 099, Loss: 0.8909 tsm_loss: 0.5948 reg_loss: 0.2961 n_pos_triplets: 109115;  Val: 0.6650 Test: 0.6576
# Epoch: 100, Loss: 0.8949 tsm_loss: 0.5973 reg_loss: 0.2976 n_pos_triplets: 109875;  Val: 0.6752 Test: 0.6661
# Epoch: 101, Loss: 0.8850 tsm_loss: 0.5938 reg_loss: 0.2912 n_pos_triplets: 109392;  Val: 0.6610 Test: 0.6513
# Epoch: 102, Loss: 0.8614 tsm_loss: 0.5831 reg_loss: 0.2783 n_pos_triplets: 107335;  Val: 0.6636 Test: 0.6490
# Epoch: 103, Loss: 0.8460 tsm_loss: 0.5730 reg_loss: 0.2731 n_pos_triplets: 104519;  Val: 0.6687 Test: 0.6641
# Epoch: 104, Loss: 0.9408 tsm_loss: 0.6380 reg_loss: 0.3028 n_pos_triplets: 110785;  Val: 0.6668 Test: 0.6558
# Epoch: 105, Loss: 0.8554 tsm_loss: 0.5794 reg_loss: 0.2760 n_pos_triplets: 106076;  Val: 0.6734 Test: 0.6461
# Epoch: 106, Loss: 0.8352 tsm_loss: 0.5629 reg_loss: 0.2723 n_pos_triplets: 104896;  Val: 0.6601 Test: 0.6365
# Epoch: 107, Loss: 0.8717 tsm_loss: 0.5928 reg_loss: 0.2788 n_pos_triplets: 104752;  Val: 0.6712 Test: 0.6636
# Epoch: 108, Loss: 0.8516 tsm_loss: 0.5705 reg_loss: 0.2812 n_pos_triplets: 104548;  Val: 0.6695 Test: 0.6695
# Epoch: 109, Loss: 0.8744 tsm_loss: 0.5658 reg_loss: 0.3086 n_pos_triplets: 106876;  Val: 0.6606 Test: 0.6481
# Epoch: 110, Loss: 0.8391 tsm_loss: 0.5452 reg_loss: 0.2938 n_pos_triplets: 102526;  Val: 0.6745 Test: 0.6662
# Epoch: 111, Loss: 0.8188 tsm_loss: 0.5310 reg_loss: 0.2878 n_pos_triplets: 101538;  Val: 0.6637 Test: 0.6524
# Epoch: 112, Loss: 0.8346 tsm_loss: 0.5627 reg_loss: 0.2719 n_pos_triplets: 103174;  Val: 0.6606 Test: 0.6437
# Epoch: 113, Loss: 0.8333 tsm_loss: 0.5542 reg_loss: 0.2791 n_pos_triplets: 103333;  Val: 0.6780 Test: 0.6568
# Epoch: 114, Loss: 0.9037 tsm_loss: 0.5458 reg_loss: 0.3579 n_pos_triplets: 102902;  Val: 0.6711 Test: 0.6572
# Epoch: 115, Loss: 0.8256 tsm_loss: 0.5187 reg_loss: 0.3070 n_pos_triplets: 98751;  Val: 0.6763 Test: 0.6620
# Epoch: 116, Loss: 0.8225 tsm_loss: 0.5309 reg_loss: 0.2915 n_pos_triplets: 99858;  Val: 0.6826 Test: 0.6733
# Epoch: 117, Loss: 0.8264 tsm_loss: 0.5218 reg_loss: 0.3046 n_pos_triplets: 100999;  Val: 0.6681 Test: 0.6644
# Epoch: 118, Loss: 0.7963 tsm_loss: 0.5343 reg_loss: 0.2620 n_pos_triplets: 101947;  Val: 0.6703 Test: 0.6569
# Epoch: 119, Loss: 0.7940 tsm_loss: 0.5361 reg_loss: 0.2579 n_pos_triplets: 101041;  Val: 0.6649 Test: 0.6430
# Epoch: 120, Loss: 0.8330 tsm_loss: 0.5621 reg_loss: 0.2710 n_pos_triplets: 103592;  Val: 0.6619 Test: 0.6479
# Epoch: 121, Loss: 0.8223 tsm_loss: 0.5317 reg_loss: 0.2906 n_pos_triplets: 100696;  Val: 0.6665 Test: 0.6465
# Epoch: 122, Loss: 0.8253 tsm_loss: 0.5271 reg_loss: 0.2982 n_pos_triplets: 102242;  Val: 0.6957 Test: 0.6706
# Epoch: 123, Loss: 0.7915 tsm_loss: 0.5067 reg_loss: 0.2849 n_pos_triplets: 97426;  Val: 0.6931 Test: 0.6647
# Epoch: 124, Loss: 0.7822 tsm_loss: 0.4956 reg_loss: 0.2866 n_pos_triplets: 98873;  Val: 0.6760 Test: 0.6686
# Epoch: 125, Loss: 0.7336 tsm_loss: 0.4879 reg_loss: 0.2457 n_pos_triplets: 96397;  Val: 0.6626 Test: 0.6461
# Epoch: 126, Loss: 0.7663 tsm_loss: 0.5127 reg_loss: 0.2536 n_pos_triplets: 98186;  Val: 0.6695 Test: 0.6514
# Epoch: 127, Loss: 0.7303 tsm_loss: 0.4933 reg_loss: 0.2369 n_pos_triplets: 98320;  Val: 0.6591 Test: 0.6426
# Epoch: 128, Loss: 0.7273 tsm_loss: 0.4780 reg_loss: 0.2493 n_pos_triplets: 95875;  Val: 0.6893 Test: 0.6784
# Epoch: 129, Loss: 0.7617 tsm_loss: 0.4973 reg_loss: 0.2644 n_pos_triplets: 99775;  Val: 0.7104 Test: 0.6849
# Epoch: 130, Loss: 0.7914 tsm_loss: 0.4932 reg_loss: 0.2982 n_pos_triplets: 94183;  Val: 0.6835 Test: 0.6617
# Epoch: 131, Loss: 0.7304 tsm_loss: 0.4717 reg_loss: 0.2588 n_pos_triplets: 94235;  Val: 0.6827 Test: 0.6485
# Epoch: 132, Loss: 0.7648 tsm_loss: 0.5102 reg_loss: 0.2545 n_pos_triplets: 99617;  Val: 0.6660 Test: 0.6391
# Epoch: 133, Loss: 0.7544 tsm_loss: 0.5084 reg_loss: 0.2460 n_pos_triplets: 96983;  Val: 0.6713 Test: 0.6464
# Epoch: 134, Loss: 0.7349 tsm_loss: 0.4836 reg_loss: 0.2512 n_pos_triplets: 93821;  Val: 0.6700 Test: 0.6385
# Epoch: 135, Loss: 0.7184 tsm_loss: 0.4892 reg_loss: 0.2292 n_pos_triplets: 97183;  Val: 0.6712 Test: 0.6443
# Epoch: 136, Loss: 0.6949 tsm_loss: 0.4657 reg_loss: 0.2293 n_pos_triplets: 95916;  Val: 0.6655 Test: 0.6430
# Epoch: 137, Loss: 0.7528 tsm_loss: 0.4927 reg_loss: 0.2601 n_pos_triplets: 98030;  Val: 0.6638 Test: 0.6459
# Epoch: 138, Loss: 0.7145 tsm_loss: 0.4856 reg_loss: 0.2289 n_pos_triplets: 94271;  Val: 0.6776 Test: 0.6582
# Epoch: 139, Loss: 0.7267 tsm_loss: 0.4922 reg_loss: 0.2345 n_pos_triplets: 98081;  Val: 0.6722 Test: 0.6439
# Epoch: 140, Loss: 0.6952 tsm_loss: 0.4641 reg_loss: 0.2311 n_pos_triplets: 93920;  Val: 0.6759 Test: 0.6497
# Epoch: 141, Loss: 0.7073 tsm_loss: 0.4736 reg_loss: 0.2338 n_pos_triplets: 95007;  Val: 0.6690 Test: 0.6460
# Epoch: 142, Loss: 0.6985 tsm_loss: 0.4665 reg_loss: 0.2320 n_pos_triplets: 92269;  Val: 0.6583 Test: 0.6372
# Epoch: 143, Loss: 0.7517 tsm_loss: 0.4853 reg_loss: 0.2664 n_pos_triplets: 93606;  Val: 0.6892 Test: 0.6728
# Epoch: 144, Loss: 0.7228 tsm_loss: 0.4611 reg_loss: 0.2617 n_pos_triplets: 93769;  Val: 0.6902 Test: 0.6609
# Epoch: 145, Loss: 0.6809 tsm_loss: 0.4654 reg_loss: 0.2155 n_pos_triplets: 93660;  Val: 0.6810 Test: 0.6544
# Epoch: 146, Loss: 0.6963 tsm_loss: 0.4588 reg_loss: 0.2375 n_pos_triplets: 92999;  Val: 0.6649 Test: 0.6406
# Epoch: 147, Loss: 0.7063 tsm_loss: 0.4473 reg_loss: 0.2590 n_pos_triplets: 92659;  Val: 0.6692 Test: 0.6481
# Epoch: 148, Loss: 0.7070 tsm_loss: 0.4522 reg_loss: 0.2547 n_pos_triplets: 91538;  Val: 0.6709 Test: 0.6461
# Epoch: 149, Loss: 0.6843 tsm_loss: 0.4479 reg_loss: 0.2364 n_pos_triplets: 93904;  Val: 0.6688 Test: 0.6432
# Epoch: 150, Loss: 0.6734 tsm_loss: 0.4382 reg_loss: 0.2352 n_pos_triplets: 93504;  Val: 0.6841 Test: 0.6581
# Epoch: 151, Loss: 0.6918 tsm_loss: 0.4552 reg_loss: 0.2366 n_pos_triplets: 95589;  Val: 0.6736 Test: 0.6429
# Epoch: 152, Loss: 0.6601 tsm_loss: 0.4417 reg_loss: 0.2185 n_pos_triplets: 91291;  Val: 0.6644 Test: 0.6368
# Epoch: 153, Loss: 0.6489 tsm_loss: 0.4348 reg_loss: 0.2141 n_pos_triplets: 88737;  Val: 0.6682 Test: 0.6416
# Epoch: 154, Loss: 0.6741 tsm_loss: 0.4260 reg_loss: 0.2481 n_pos_triplets: 89538;  Val: 0.6620 Test: 0.6346
# Epoch: 155, Loss: 0.6654 tsm_loss: 0.4364 reg_loss: 0.2291 n_pos_triplets: 90633;  Val: 0.6683 Test: 0.6354
# Epoch: 156, Loss: 0.6501 tsm_loss: 0.4367 reg_loss: 0.2134 n_pos_triplets: 92175;  Val: 0.6609 Test: 0.6278
# Epoch: 157, Loss: 0.6595 tsm_loss: 0.4317 reg_loss: 0.2278 n_pos_triplets: 89703;  Val: 0.6533 Test: 0.6329
# Epoch: 158, Loss: 0.6524 tsm_loss: 0.4447 reg_loss: 0.2077 n_pos_triplets: 91711;  Val: 0.6694 Test: 0.6417
# Epoch: 159, Loss: 0.6597 tsm_loss: 0.4321 reg_loss: 0.2276 n_pos_triplets: 90545;  Val: 0.6861 Test: 0.6611
# Epoch: 160, Loss: 0.6874 tsm_loss: 0.4279 reg_loss: 0.2595 n_pos_triplets: 89758;  Val: 0.6623 Test: 0.6333
# Epoch: 161, Loss: 0.6868 tsm_loss: 0.4319 reg_loss: 0.2549 n_pos_triplets: 89300;  Val: 0.6641 Test: 0.6351
# Epoch: 162, Loss: 0.6717 tsm_loss: 0.4351 reg_loss: 0.2366 n_pos_triplets: 90868;  Val: 0.6677 Test: 0.6386
# Epoch: 163, Loss: 0.6875 tsm_loss: 0.4347 reg_loss: 0.2528 n_pos_triplets: 89237;  Val: 0.6918 Test: 0.6585
# Epoch: 164, Loss: 0.6521 tsm_loss: 0.4193 reg_loss: 0.2328 n_pos_triplets: 88031;  Val: 0.6558 Test: 0.6213
# Epoch: 165, Loss: 0.6402 tsm_loss: 0.4192 reg_loss: 0.2209 n_pos_triplets: 88576;  Val: 0.6498 Test: 0.6235
# Epoch: 166, Loss: 0.6350 tsm_loss: 0.4277 reg_loss: 0.2074 n_pos_triplets: 92248;  Val: 0.6877 Test: 0.6606
# Epoch: 167, Loss: 0.6837 tsm_loss: 0.4246 reg_loss: 0.2591 n_pos_triplets: 88170;  Val: 0.6750 Test: 0.6460
# Epoch: 168, Loss: 0.6557 tsm_loss: 0.4170 reg_loss: 0.2387 n_pos_triplets: 86955;  Val: 0.6664 Test: 0.6407
# Epoch: 169, Loss: 0.6486 tsm_loss: 0.4348 reg_loss: 0.2138 n_pos_triplets: 91086;  Val: 0.6589 Test: 0.6266
# Epoch: 170, Loss: 0.6537 tsm_loss: 0.4246 reg_loss: 0.2291 n_pos_triplets: 86970;  Val: 0.6653 Test: 0.6217
# Epoch: 171, Loss: 0.6233 tsm_loss: 0.4158 reg_loss: 0.2075 n_pos_triplets: 87551;  Val: 0.6605 Test: 0.6269
# Epoch: 172, Loss: 0.6056 tsm_loss: 0.4108 reg_loss: 0.1949 n_pos_triplets: 86933;  Val: 0.6640 Test: 0.6268
# Epoch: 173, Loss: 0.6044 tsm_loss: 0.3970 reg_loss: 0.2074 n_pos_triplets: 86817;  Val: 0.6805 Test: 0.6409
# Epoch: 174, Loss: 0.6325 tsm_loss: 0.4190 reg_loss: 0.2135 n_pos_triplets: 87067;  Val: 0.6932 Test: 0.6528
# Epoch: 175, Loss: 0.6394 tsm_loss: 0.3944 reg_loss: 0.2450 n_pos_triplets: 86178;  Val: 0.6636 Test: 0.6309
# Epoch: 176, Loss: 0.6359 tsm_loss: 0.3946 reg_loss: 0.2414 n_pos_triplets: 85498;  Val: 0.6750 Test: 0.6334
# Epoch: 177, Loss: 0.5945 tsm_loss: 0.3912 reg_loss: 0.2034 n_pos_triplets: 84259;  Val: 0.6498 Test: 0.6124
# Epoch: 178, Loss: 0.5935 tsm_loss: 0.3861 reg_loss: 0.2074 n_pos_triplets: 83763;  Val: 0.6593 Test: 0.6233
# Epoch: 179, Loss: 0.6192 tsm_loss: 0.3982 reg_loss: 0.2210 n_pos_triplets: 84944;  Val: 0.6845 Test: 0.6512
# Epoch: 180, Loss: 0.6013 tsm_loss: 0.3740 reg_loss: 0.2273 n_pos_triplets: 84135;  Val: 0.6627 Test: 0.6293
# Epoch: 181, Loss: 0.6452 tsm_loss: 0.3939 reg_loss: 0.2513 n_pos_triplets: 84352;  Val: 0.6630 Test: 0.6196
# Epoch: 182, Loss: 0.5962 tsm_loss: 0.3819 reg_loss: 0.2144 n_pos_triplets: 82314;  Val: 0.6781 Test: 0.6444
# Epoch: 183, Loss: 0.6019 tsm_loss: 0.3870 reg_loss: 0.2148 n_pos_triplets: 84174;  Val: 0.6626 Test: 0.6357
# Epoch: 184, Loss: 0.6376 tsm_loss: 0.3851 reg_loss: 0.2525 n_pos_triplets: 82684;  Val: 0.6708 Test: 0.6403
# Epoch: 185, Loss: 0.6382 tsm_loss: 0.4030 reg_loss: 0.2351 n_pos_triplets: 86473;  Val: 0.7250 Test: 0.7002
# Epoch: 186, Loss: 0.6803 tsm_loss: 0.3891 reg_loss: 0.2912 n_pos_triplets: 84379;  Val: 0.7071 Test: 0.6684
# Epoch: 187, Loss: 0.6378 tsm_loss: 0.4030 reg_loss: 0.2348 n_pos_triplets: 82962;  Val: 0.6985 Test: 0.6618
# Epoch: 188, Loss: 0.6497 tsm_loss: 0.3901 reg_loss: 0.2596 n_pos_triplets: 85449;  Val: 0.6706 Test: 0.6315
# Epoch: 189, Loss: 0.6253 tsm_loss: 0.3897 reg_loss: 0.2356 n_pos_triplets: 84187;  Val: 0.6636 Test: 0.6213
# Epoch: 190, Loss: 0.5917 tsm_loss: 0.3893 reg_loss: 0.2024 n_pos_triplets: 83094;  Val: 0.6627 Test: 0.6194
# Epoch: 191, Loss: 0.5721 tsm_loss: 0.3735 reg_loss: 0.1986 n_pos_triplets: 81242;  Val: 0.6705 Test: 0.6327
# Epoch: 192, Loss: 0.5684 tsm_loss: 0.3800 reg_loss: 0.1884 n_pos_triplets: 83139;  Val: 0.6639 Test: 0.6258
# Epoch: 193, Loss: 0.5705 tsm_loss: 0.3693 reg_loss: 0.2011 n_pos_triplets: 81340;  Val: 0.6762 Test: 0.6400
# Epoch: 194, Loss: 0.5823 tsm_loss: 0.3858 reg_loss: 0.1965 n_pos_triplets: 82682;  Val: 0.6622 Test: 0.6324
# Epoch: 195, Loss: 0.5581 tsm_loss: 0.3616 reg_loss: 0.1964 n_pos_triplets: 82167;  Val: 0.6648 Test: 0.6253
# Epoch: 196, Loss: 0.5510 tsm_loss: 0.3658 reg_loss: 0.1852 n_pos_triplets: 80158;  Val: 0.6734 Test: 0.6301
# Epoch: 197, Loss: 0.5716 tsm_loss: 0.3679 reg_loss: 0.2038 n_pos_triplets: 80613;  Val: 0.6600 Test: 0.6172
# Epoch: 198, Loss: 0.5595 tsm_loss: 0.3693 reg_loss: 0.1902 n_pos_triplets: 82143;  Val: 0.6642 Test: 0.6261
# Epoch: 199, Loss: 0.5785 tsm_loss: 0.3714 reg_loss: 0.2071 n_pos_triplets: 82363;  Val: 0.6718 Test: 0.6338
# Epoch: 200, Loss: 0.5830 tsm_loss: 0.3761 reg_loss: 0.2069 n_pos_triplets: 80708;  Val: 0.6599 Test: 0.6296
# Epoch: 201, Loss: 0.5785 tsm_loss: 0.3780 reg_loss: 0.2004 n_pos_triplets: 84625;  Val: 0.6589 Test: 0.6257
# Epoch: 202, Loss: 0.5411 tsm_loss: 0.3526 reg_loss: 0.1885 n_pos_triplets: 81188;  Val: 0.6707 Test: 0.6196
# Epoch: 203, Loss: 0.5684 tsm_loss: 0.3574 reg_loss: 0.2111 n_pos_triplets: 81109;  Val: 0.6669 Test: 0.6202
# Epoch: 204, Loss: 0.5544 tsm_loss: 0.3613 reg_loss: 0.1931 n_pos_triplets: 82076;  Val: 0.6613 Test: 0.6239
# Epoch: 205, Loss: 0.5222 tsm_loss: 0.3423 reg_loss: 0.1799 n_pos_triplets: 77495;  Val: 0.6572 Test: 0.6178
# Epoch: 206, Loss: 0.5195 tsm_loss: 0.3508 reg_loss: 0.1687 n_pos_triplets: 78880;  Val: 0.6615 Test: 0.6133
# Epoch: 207, Loss: 0.5370 tsm_loss: 0.3584 reg_loss: 0.1786 n_pos_triplets: 79134;  Val: 0.6618 Test: 0.6256
# Epoch: 208, Loss: 0.5573 tsm_loss: 0.3806 reg_loss: 0.1767 n_pos_triplets: 84732;  Val: 0.6581 Test: 0.6202
# Epoch: 209, Loss: 0.5609 tsm_loss: 0.3708 reg_loss: 0.1900 n_pos_triplets: 81766;  Val: 0.6766 Test: 0.6330
# Epoch: 210, Loss: 0.5411 tsm_loss: 0.3654 reg_loss: 0.1757 n_pos_triplets: 81302;  Val: 0.6576 Test: 0.6154
# Epoch: 211, Loss: 0.5378 tsm_loss: 0.3599 reg_loss: 0.1778 n_pos_triplets: 78753;  Val: 0.6574 Test: 0.6129
# Epoch: 212, Loss: 0.5410 tsm_loss: 0.3580 reg_loss: 0.1829 n_pos_triplets: 79166;  Val: 0.6580 Test: 0.6060
# Epoch: 213, Loss: 0.5171 tsm_loss: 0.3532 reg_loss: 0.1638 n_pos_triplets: 81477;  Val: 0.6511 Test: 0.6099
# Epoch: 214, Loss: 0.5301 tsm_loss: 0.3422 reg_loss: 0.1879 n_pos_triplets: 78880;  Val: 0.6687 Test: 0.6226
# Epoch: 215, Loss: 0.5238 tsm_loss: 0.3422 reg_loss: 0.1815 n_pos_triplets: 78057;  Val: 0.6595 Test: 0.6132
# Epoch: 216, Loss: 0.4978 tsm_loss: 0.3342 reg_loss: 0.1637 n_pos_triplets: 75922;  Val: 0.6551 Test: 0.6204
# Epoch: 217, Loss: 0.5419 tsm_loss: 0.3480 reg_loss: 0.1938 n_pos_triplets: 77969;  Val: 0.6618 Test: 0.6327
# Epoch: 218, Loss: 0.5200 tsm_loss: 0.3472 reg_loss: 0.1728 n_pos_triplets: 78340;  Val: 0.6617 Test: 0.6254
# Epoch: 219, Loss: 0.5281 tsm_loss: 0.3542 reg_loss: 0.1739 n_pos_triplets: 78771;  Val: 0.6737 Test: 0.6279
# Epoch: 220, Loss: 0.5381 tsm_loss: 0.3442 reg_loss: 0.1939 n_pos_triplets: 77494;  Val: 0.6735 Test: 0.6255
# Epoch: 221, Loss: 0.5184 tsm_loss: 0.3457 reg_loss: 0.1727 n_pos_triplets: 77702;  Val: 0.6676 Test: 0.6208
# Epoch: 222, Loss: 0.5493 tsm_loss: 0.3472 reg_loss: 0.2021 n_pos_triplets: 79258;  Val: 0.6552 Test: 0.6167
# Epoch: 223, Loss: 0.5400 tsm_loss: 0.3542 reg_loss: 0.1858 n_pos_triplets: 77475;  Val: 0.6868 Test: 0.6372
# Epoch: 224, Loss: 0.5599 tsm_loss: 0.3459 reg_loss: 0.2140 n_pos_triplets: 79047;  Val: 0.6714 Test: 0.6214
# Epoch: 225, Loss: 0.5516 tsm_loss: 0.3226 reg_loss: 0.2290 n_pos_triplets: 75089;  Val: 0.6752 Test: 0.6339
# Epoch: 226, Loss: 0.5163 tsm_loss: 0.3394 reg_loss: 0.1768 n_pos_triplets: 77578;  Val: 0.6532 Test: 0.6177
# Epoch: 227, Loss: 0.5187 tsm_loss: 0.3389 reg_loss: 0.1798 n_pos_triplets: 78649;  Val: 0.6583 Test: 0.6238
# Epoch: 228, Loss: 0.4972 tsm_loss: 0.3268 reg_loss: 0.1703 n_pos_triplets: 73740;  Val: 0.7000 Test: 0.6624
# Epoch: 229, Loss: 0.5192 tsm_loss: 0.3307 reg_loss: 0.1885 n_pos_triplets: 78005;  Val: 0.6629 Test: 0.6109
# Epoch: 230, Loss: 0.5220 tsm_loss: 0.3302 reg_loss: 0.1918 n_pos_triplets: 76401;  Val: 0.6593 Test: 0.6082
# Epoch: 231, Loss: 0.4793 tsm_loss: 0.3169 reg_loss: 0.1624 n_pos_triplets: 74850;  Val: 0.6676 Test: 0.6213
# Epoch: 232, Loss: 0.4799 tsm_loss: 0.3181 reg_loss: 0.1618 n_pos_triplets: 74106;  Val: 0.6775 Test: 0.6367
# Epoch: 233, Loss: 0.5217 tsm_loss: 0.3226 reg_loss: 0.1991 n_pos_triplets: 74216;  Val: 0.6675 Test: 0.6191
# Epoch: 234, Loss: 0.4990 tsm_loss: 0.3080 reg_loss: 0.1909 n_pos_triplets: 71236;  Val: 0.6611 Test: 0.6179
# Epoch: 235, Loss: 0.4835 tsm_loss: 0.3261 reg_loss: 0.1573 n_pos_triplets: 74434;  Val: 0.6619 Test: 0.6218
# Epoch: 236, Loss: 0.4898 tsm_loss: 0.3203 reg_loss: 0.1694 n_pos_triplets: 74523;  Val: 0.6747 Test: 0.6227
# Epoch: 237, Loss: 0.4844 tsm_loss: 0.3233 reg_loss: 0.1611 n_pos_triplets: 73489;  Val: 0.6534 Test: 0.6129
# Epoch: 238, Loss: 0.5064 tsm_loss: 0.3274 reg_loss: 0.1790 n_pos_triplets: 74461;  Val: 0.6527 Test: 0.6205
# Epoch: 239, Loss: 0.4962 tsm_loss: 0.3262 reg_loss: 0.1699 n_pos_triplets: 74726;  Val: 0.6625 Test: 0.6189
# Epoch: 240, Loss: 0.4891 tsm_loss: 0.3290 reg_loss: 0.1601 n_pos_triplets: 75031;  Val: 0.6700 Test: 0.6242
# Epoch: 241, Loss: 0.4669 tsm_loss: 0.3075 reg_loss: 0.1594 n_pos_triplets: 72386;  Val: 0.6640 Test: 0.6209
# Epoch: 242, Loss: 0.4655 tsm_loss: 0.3107 reg_loss: 0.1548 n_pos_triplets: 75036;  Val: 0.6700 Test: 0.6170
# Epoch: 243, Loss: 0.4901 tsm_loss: 0.3228 reg_loss: 0.1672 n_pos_triplets: 76273;  Val: 0.6654 Test: 0.6045
# Epoch: 244, Loss: 0.4593 tsm_loss: 0.3136 reg_loss: 0.1457 n_pos_triplets: 73376;  Val: 0.6905 Test: 0.6398
# Epoch: 245, Loss: 0.4767 tsm_loss: 0.3200 reg_loss: 0.1567 n_pos_triplets: 72097;  Val: 0.6797 Test: 0.6195
# Epoch: 246, Loss: 0.5128 tsm_loss: 0.3106 reg_loss: 0.2022 n_pos_triplets: 70595;  Val: 0.6691 Test: 0.6262
# Epoch: 247, Loss: 0.4924 tsm_loss: 0.3165 reg_loss: 0.1759 n_pos_triplets: 73992;  Val: 0.6755 Test: 0.6303
# Epoch: 248, Loss: 0.4836 tsm_loss: 0.2995 reg_loss: 0.1841 n_pos_triplets: 72729;  Val: 0.6877 Test: 0.6376
# Epoch: 249, Loss: 0.5242 tsm_loss: 0.3088 reg_loss: 0.2155 n_pos_triplets: 70417;  Val: 0.6915 Test: 0.6518
# Epoch: 250, Loss: 0.4960 tsm_loss: 0.2965 reg_loss: 0.1995 n_pos_triplets: 72571;  Val: 0.6672 Test: 0.6161
# Epoch: 251, Loss: 0.5078 tsm_loss: 0.3129 reg_loss: 0.1949 n_pos_triplets: 72590;  Val: 0.6622 Test: 0.6051
# Epoch: 252, Loss: 0.4996 tsm_loss: 0.3237 reg_loss: 0.1759 n_pos_triplets: 74592;  Val: 0.6527 Test: 0.6077
# Epoch: 253, Loss: 0.4676 tsm_loss: 0.3080 reg_loss: 0.1596 n_pos_triplets: 72243;  Val: 0.6673 Test: 0.6190
# Epoch: 254, Loss: 0.4685 tsm_loss: 0.3099 reg_loss: 0.1586 n_pos_triplets: 71879;  Val: 0.6726 Test: 0.6218
# Epoch: 255, Loss: 0.5222 tsm_loss: 0.3127 reg_loss: 0.2095 n_pos_triplets: 70798;  Val: 0.6650 Test: 0.6155
# Epoch: 256, Loss: 0.4809 tsm_loss: 0.3002 reg_loss: 0.1807 n_pos_triplets: 70666;  Val: 0.6689 Test: 0.6298
# Epoch: 257, Loss: 0.4613 tsm_loss: 0.3189 reg_loss: 0.1424 n_pos_triplets: 71238;  Val: 0.6706 Test: 0.6184
# Epoch: 258, Loss: 0.5007 tsm_loss: 0.3195 reg_loss: 0.1811 n_pos_triplets: 71340;  Val: 0.6821 Test: 0.6322
# Epoch: 259, Loss: 0.4687 tsm_loss: 0.3059 reg_loss: 0.1628 n_pos_triplets: 74577;  Val: 0.6753 Test: 0.6256
# Epoch: 260, Loss: 0.4996 tsm_loss: 0.3087 reg_loss: 0.1909 n_pos_triplets: 72108;  Val: 0.6651 Test: 0.6122
# Epoch: 261, Loss: 0.4409 tsm_loss: 0.2988 reg_loss: 0.1421 n_pos_triplets: 71041;  Val: 0.6667 Test: 0.6113
# Epoch: 262, Loss: 0.4436 tsm_loss: 0.2964 reg_loss: 0.1471 n_pos_triplets: 71507;  Val: 0.6788 Test: 0.6345
# Epoch: 263, Loss: 0.4815 tsm_loss: 0.3036 reg_loss: 0.1779 n_pos_triplets: 70888;  Val: 0.6622 Test: 0.6148
# Epoch: 264, Loss: 0.4409 tsm_loss: 0.2981 reg_loss: 0.1428 n_pos_triplets: 71494;  Val: 0.6951 Test: 0.6536
# Epoch: 265, Loss: 0.4655 tsm_loss: 0.3011 reg_loss: 0.1644 n_pos_triplets: 69934;  Val: 0.6748 Test: 0.6239
# Epoch: 266, Loss: 0.4865 tsm_loss: 0.2902 reg_loss: 0.1963 n_pos_triplets: 70806;  Val: 0.6670 Test: 0.6143
# Epoch: 267, Loss: 0.4406 tsm_loss: 0.2880 reg_loss: 0.1526 n_pos_triplets: 69848;  Val: 0.6707 Test: 0.6123
# Epoch: 268, Loss: 0.4752 tsm_loss: 0.3039 reg_loss: 0.1713 n_pos_triplets: 70912;  Val: 0.6658 Test: 0.6021
# Epoch: 269, Loss: 0.4366 tsm_loss: 0.2909 reg_loss: 0.1457 n_pos_triplets: 69385;  Val: 0.6563 Test: 0.6117
# Epoch: 270, Loss: 0.4557 tsm_loss: 0.2882 reg_loss: 0.1675 n_pos_triplets: 69430;  Val: 0.6776 Test: 0.6199
# Epoch: 271, Loss: 0.4570 tsm_loss: 0.2823 reg_loss: 0.1747 n_pos_triplets: 68442;  Val: 0.6807 Test: 0.6169
# Epoch: 272, Loss: 0.4553 tsm_loss: 0.2919 reg_loss: 0.1633 n_pos_triplets: 70167;  Val: 0.6614 Test: 0.5995
# Epoch: 273, Loss: 0.5224 tsm_loss: 0.3107 reg_loss: 0.2117 n_pos_triplets: 74588;  Val: 0.6630 Test: 0.6007
# Epoch: 274, Loss: 0.4460 tsm_loss: 0.2936 reg_loss: 0.1524 n_pos_triplets: 69119;  Val: 0.6829 Test: 0.6191
# Epoch: 275, Loss: 0.4283 tsm_loss: 0.2826 reg_loss: 0.1456 n_pos_triplets: 67988;  Val: 0.6648 Test: 0.6042
# Epoch: 276, Loss: 0.4365 tsm_loss: 0.2922 reg_loss: 0.1443 n_pos_triplets: 68328;  Val: 0.6755 Test: 0.6073
# Epoch: 277, Loss: 0.4220 tsm_loss: 0.2777 reg_loss: 0.1443 n_pos_triplets: 66698;  Val: 0.6753 Test: 0.6287
# Epoch: 278, Loss: 0.4217 tsm_loss: 0.2762 reg_loss: 0.1454 n_pos_triplets: 69233;  Val: 0.6676 Test: 0.6080
# Epoch: 279, Loss: 0.4250 tsm_loss: 0.2808 reg_loss: 0.1442 n_pos_triplets: 69387;  Val: 0.6737 Test: 0.6291
# Epoch: 280, Loss: 0.4303 tsm_loss: 0.2842 reg_loss: 0.1460 n_pos_triplets: 66887;  Val: 0.6587 Test: 0.6076
# Epoch: 281, Loss: 0.4473 tsm_loss: 0.2905 reg_loss: 0.1568 n_pos_triplets: 68962;  Val: 0.6637 Test: 0.6189
# Epoch: 282, Loss: 0.4191 tsm_loss: 0.2831 reg_loss: 0.1360 n_pos_triplets: 68419;  Val: 0.6600 Test: 0.6075
# Epoch: 283, Loss: 0.4163 tsm_loss: 0.2933 reg_loss: 0.1230 n_pos_triplets: 69477;  Val: 0.6812 Test: 0.6255
# Epoch: 284, Loss: 0.4503 tsm_loss: 0.2827 reg_loss: 0.1676 n_pos_triplets: 69090;  Val: 0.6700 Test: 0.6124
# Epoch: 285, Loss: 0.4204 tsm_loss: 0.2805 reg_loss: 0.1399 n_pos_triplets: 69195;  Val: 0.6777 Test: 0.6298
# Epoch: 286, Loss: 0.4688 tsm_loss: 0.2609 reg_loss: 0.2079 n_pos_triplets: 65574;  Val: 0.6801 Test: 0.6208
# Epoch: 287, Loss: 0.4674 tsm_loss: 0.2841 reg_loss: 0.1832 n_pos_triplets: 66286;  Val: 0.6706 Test: 0.6133
# Epoch: 288, Loss: 0.4523 tsm_loss: 0.2776 reg_loss: 0.1747 n_pos_triplets: 68592;  Val: 0.6639 Test: 0.6159
# Epoch: 289, Loss: 0.4256 tsm_loss: 0.2760 reg_loss: 0.1496 n_pos_triplets: 67737;  Val: 0.6728 Test: 0.6192
# Epoch: 290, Loss: 0.4456 tsm_loss: 0.2905 reg_loss: 0.1551 n_pos_triplets: 68659;  Val: 0.6748 Test: 0.6275
# Epoch: 291, Loss: 0.4343 tsm_loss: 0.2763 reg_loss: 0.1580 n_pos_triplets: 67354;  Val: 0.6565 Test: 0.6127
# Epoch: 292, Loss: 0.4267 tsm_loss: 0.2783 reg_loss: 0.1484 n_pos_triplets: 67672;  Val: 0.6617 Test: 0.6131
# Epoch: 293, Loss: 0.4312 tsm_loss: 0.2807 reg_loss: 0.1505 n_pos_triplets: 68084;  Val: 0.6668 Test: 0.6184
# Epoch: 294, Loss: 0.4528 tsm_loss: 0.2733 reg_loss: 0.1795 n_pos_triplets: 65089;  Val: 0.6604 Test: 0.6168
# Epoch: 295, Loss: 0.4294 tsm_loss: 0.2820 reg_loss: 0.1474 n_pos_triplets: 66247;  Val: 0.6754 Test: 0.6312
# Epoch: 296, Loss: 0.4569 tsm_loss: 0.2894 reg_loss: 0.1675 n_pos_triplets: 66804;  Val: 0.6973 Test: 0.6373
# Epoch: 297, Loss: 0.4812 tsm_loss: 0.2942 reg_loss: 0.1870 n_pos_triplets: 68254;  Val: 0.6766 Test: 0.6150
# Epoch: 298, Loss: 0.4287 tsm_loss: 0.2646 reg_loss: 0.1641 n_pos_triplets: 64287;  Val: 0.7054 Test: 0.6704
# Epoch: 299, Loss: 0.4469 tsm_loss: 0.2564 reg_loss: 0.1905 n_pos_triplets: 64549;  Val: 0.6620 Test: 0.6174
# Epoch: 300, Loss: 0.4007 tsm_loss: 0.2657 reg_loss: 0.1350 n_pos_triplets: 64512;  Val: 0.6696 Test: 0.6088
# Epoch: 301, Loss: 0.3982 tsm_loss: 0.2617 reg_loss: 0.1365 n_pos_triplets: 63713;  Val: 0.6632 Test: 0.6054
# Epoch: 302, Loss: 0.4015 tsm_loss: 0.2648 reg_loss: 0.1367 n_pos_triplets: 64790;  Val: 0.6622 Test: 0.6107
# Epoch: 303, Loss: 0.4227 tsm_loss: 0.2712 reg_loss: 0.1515 n_pos_triplets: 65524;  Val: 0.6814 Test: 0.6227
# Epoch: 304, Loss: 0.4334 tsm_loss: 0.2611 reg_loss: 0.1723 n_pos_triplets: 63235;  Val: 0.6825 Test: 0.6180
# Epoch: 305, Loss: 0.4683 tsm_loss: 0.2701 reg_loss: 0.1982 n_pos_triplets: 67426;  Val: 0.6685 Test: 0.6207
# Epoch: 306, Loss: 0.4258 tsm_loss: 0.2718 reg_loss: 0.1539 n_pos_triplets: 65731;  Val: 0.6664 Test: 0.6202
# Epoch: 307, Loss: 0.4535 tsm_loss: 0.2791 reg_loss: 0.1744 n_pos_triplets: 66421;  Val: 0.6680 Test: 0.6128
# Epoch: 308, Loss: 0.4228 tsm_loss: 0.2646 reg_loss: 0.1581 n_pos_triplets: 63275;  Val: 0.6681 Test: 0.6025
# Epoch: 309, Loss: 0.4016 tsm_loss: 0.2653 reg_loss: 0.1363 n_pos_triplets: 65898;  Val: 0.6605 Test: 0.6045
# Epoch: 310, Loss: 0.4090 tsm_loss: 0.2633 reg_loss: 0.1457 n_pos_triplets: 63993;  Val: 0.6750 Test: 0.6155
# Epoch: 311, Loss: 0.4078 tsm_loss: 0.2641 reg_loss: 0.1437 n_pos_triplets: 63822;  Val: 0.6657 Test: 0.6034
# Epoch: 312, Loss: 0.3875 tsm_loss: 0.2601 reg_loss: 0.1273 n_pos_triplets: 63859;  Val: 0.6587 Test: 0.6076
# Epoch: 313, Loss: 0.4056 tsm_loss: 0.2732 reg_loss: 0.1324 n_pos_triplets: 66530;  Val: 0.6648 Test: 0.6011
# Epoch: 314, Loss: 0.4430 tsm_loss: 0.2678 reg_loss: 0.1752 n_pos_triplets: 63105;  Val: 0.6770 Test: 0.6205
# Epoch: 315, Loss: 0.4386 tsm_loss: 0.2708 reg_loss: 0.1679 n_pos_triplets: 66110;  Val: 0.6538 Test: 0.5925
# Epoch: 316, Loss: 0.4230 tsm_loss: 0.2574 reg_loss: 0.1656 n_pos_triplets: 65800;  Val: 0.6574 Test: 0.5954
# Epoch: 317, Loss: 0.3922 tsm_loss: 0.2511 reg_loss: 0.1411 n_pos_triplets: 62753;  Val: 0.6730 Test: 0.6100
# Epoch: 318, Loss: 0.4102 tsm_loss: 0.2585 reg_loss: 0.1517 n_pos_triplets: 63212;  Val: 0.6661 Test: 0.6074
# Epoch: 319, Loss: 0.4122 tsm_loss: 0.2485 reg_loss: 0.1637 n_pos_triplets: 62049;  Val: 0.6702 Test: 0.6023
# Epoch: 320, Loss: 0.4891 tsm_loss: 0.2708 reg_loss: 0.2183 n_pos_triplets: 66351;  Val: 0.6912 Test: 0.6291
# Epoch: 321, Loss: 0.4439 tsm_loss: 0.2522 reg_loss: 0.1916 n_pos_triplets: 62803;  Val: 0.6818 Test: 0.6055
# Epoch: 322, Loss: 0.4256 tsm_loss: 0.2676 reg_loss: 0.1579 n_pos_triplets: 66667;  Val: 0.6813 Test: 0.6243
# Epoch: 323, Loss: 0.4266 tsm_loss: 0.2600 reg_loss: 0.1666 n_pos_triplets: 62729;  Val: 0.6736 Test: 0.6073
# Epoch: 324, Loss: 0.4313 tsm_loss: 0.2641 reg_loss: 0.1672 n_pos_triplets: 62475;  Val: 0.6752 Test: 0.5979
# Epoch: 325, Loss: 0.4232 tsm_loss: 0.2600 reg_loss: 0.1632 n_pos_triplets: 64675;  Val: 0.6842 Test: 0.6211
# Epoch: 326, Loss: 0.4210 tsm_loss: 0.2670 reg_loss: 0.1541 n_pos_triplets: 63050;  Val: 0.6631 Test: 0.6092
# Epoch: 327, Loss: 0.3867 tsm_loss: 0.2469 reg_loss: 0.1398 n_pos_triplets: 59537;  Val: 0.6617 Test: 0.6016
# Epoch: 328, Loss: 0.4095 tsm_loss: 0.2612 reg_loss: 0.1483 n_pos_triplets: 64880;  Val: 0.6963 Test: 0.6371
# Epoch: 329, Loss: 0.4505 tsm_loss: 0.2656 reg_loss: 0.1849 n_pos_triplets: 63759;  Val: 0.6575 Test: 0.6027
# Epoch: 330, Loss: 0.4034 tsm_loss: 0.2605 reg_loss: 0.1429 n_pos_triplets: 63432;  Val: 0.6724 Test: 0.6040
# Epoch: 331, Loss: 0.4050 tsm_loss: 0.2704 reg_loss: 0.1346 n_pos_triplets: 64568;  Val: 0.6728 Test: 0.6190
# Epoch: 332, Loss: 0.3883 tsm_loss: 0.2461 reg_loss: 0.1422 n_pos_triplets: 62472;  Val: 0.6638 Test: 0.6101
# Epoch: 333, Loss: 0.4254 tsm_loss: 0.2677 reg_loss: 0.1576 n_pos_triplets: 63877;  Val: 0.6647 Test: 0.6034
# Epoch: 334, Loss: 0.3897 tsm_loss: 0.2450 reg_loss: 0.1447 n_pos_triplets: 61640;  Val: 0.6764 Test: 0.6072
# Epoch: 335, Loss: 0.4867 tsm_loss: 0.2806 reg_loss: 0.2060 n_pos_triplets: 63885;  Val: 0.6723 Test: 0.6065
# Epoch: 336, Loss: 0.4014 tsm_loss: 0.2506 reg_loss: 0.1508 n_pos_triplets: 62690;  Val: 0.6765 Test: 0.6074
# Epoch: 337, Loss: 0.3907 tsm_loss: 0.2428 reg_loss: 0.1479 n_pos_triplets: 60873;  Val: 0.6680 Test: 0.6048
# Epoch: 338, Loss: 0.3814 tsm_loss: 0.2430 reg_loss: 0.1384 n_pos_triplets: 60787;  Val: 0.6722 Test: 0.6120
# Epoch: 339, Loss: 0.3809 tsm_loss: 0.2476 reg_loss: 0.1333 n_pos_triplets: 62317;  Val: 0.6629 Test: 0.6120
# Epoch: 340, Loss: 0.3974 tsm_loss: 0.2622 reg_loss: 0.1352 n_pos_triplets: 63570;  Val: 0.6712 Test: 0.6103
# Epoch: 341, Loss: 0.3878 tsm_loss: 0.2449 reg_loss: 0.1430 n_pos_triplets: 61532;  Val: 0.6610 Test: 0.5937
# Epoch: 342, Loss: 0.3533 tsm_loss: 0.2311 reg_loss: 0.1222 n_pos_triplets: 59834;  Val: 0.6580 Test: 0.6051
# Epoch: 343, Loss: 0.4000 tsm_loss: 0.2419 reg_loss: 0.1581 n_pos_triplets: 61815;  Val: 0.6733 Test: 0.6163
# Epoch: 344, Loss: 0.4004 tsm_loss: 0.2314 reg_loss: 0.1690 n_pos_triplets: 57708;  Val: 0.6722 Test: 0.6085
# Epoch: 345, Loss: 0.4887 tsm_loss: 0.2527 reg_loss: 0.2360 n_pos_triplets: 61892;  Val: 0.7088 Test: 0.6532
# Epoch: 346, Loss: 0.4535 tsm_loss: 0.2503 reg_loss: 0.2032 n_pos_triplets: 62985;  Val: 0.6743 Test: 0.6151
# Epoch: 347, Loss: 0.4275 tsm_loss: 0.2424 reg_loss: 0.1850 n_pos_triplets: 61308;  Val: 0.6940 Test: 0.6472
# Epoch: 348, Loss: 0.3955 tsm_loss: 0.2439 reg_loss: 0.1516 n_pos_triplets: 58661;  Val: 0.6606 Test: 0.5968
# Epoch: 349, Loss: 0.3641 tsm_loss: 0.2431 reg_loss: 0.1210 n_pos_triplets: 60309;  Val: 0.6614 Test: 0.5979
# Epoch: 350, Loss: 0.3947 tsm_loss: 0.2543 reg_loss: 0.1404 n_pos_triplets: 62278;  Val: 0.6603 Test: 0.6029
# Epoch: 351, Loss: 0.3857 tsm_loss: 0.2471 reg_loss: 0.1387 n_pos_triplets: 62508;  Val: 0.6695 Test: 0.6032
# Epoch: 352, Loss: 0.3826 tsm_loss: 0.2470 reg_loss: 0.1356 n_pos_triplets: 61885;  Val: 0.6656 Test: 0.5974
# Epoch: 353, Loss: 0.3614 tsm_loss: 0.2406 reg_loss: 0.1209 n_pos_triplets: 61425;  Val: 0.6623 Test: 0.6027
# Epoch: 354, Loss: 0.3579 tsm_loss: 0.2422 reg_loss: 0.1157 n_pos_triplets: 58877;  Val: 0.6554 Test: 0.6045
# Epoch: 355, Loss: 0.3558 tsm_loss: 0.2347 reg_loss: 0.1211 n_pos_triplets: 60583;  Val: 0.6598 Test: 0.6041
# Epoch: 356, Loss: 0.3645 tsm_loss: 0.2395 reg_loss: 0.1250 n_pos_triplets: 60798;  Val: 0.6597 Test: 0.6009
# Epoch: 357, Loss: 0.3608 tsm_loss: 0.2286 reg_loss: 0.1323 n_pos_triplets: 60763;  Val: 0.6677 Test: 0.6097
# Epoch: 358, Loss: 0.3385 tsm_loss: 0.2183 reg_loss: 0.1202 n_pos_triplets: 57793;  Val: 0.6719 Test: 0.6153
# Epoch: 359, Loss: 0.3495 tsm_loss: 0.2286 reg_loss: 0.1209 n_pos_triplets: 58810;  Val: 0.6547 Test: 0.5901
# Epoch: 360, Loss: 0.3568 tsm_loss: 0.2269 reg_loss: 0.1299 n_pos_triplets: 58304;  Val: 0.6723 Test: 0.5968
# Epoch: 361, Loss: 0.3534 tsm_loss: 0.2366 reg_loss: 0.1168 n_pos_triplets: 61160;  Val: 0.6691 Test: 0.6068
# Epoch: 362, Loss: 0.3703 tsm_loss: 0.2358 reg_loss: 0.1345 n_pos_triplets: 60897;  Val: 0.6656 Test: 0.5994
# Epoch: 363, Loss: 0.3680 tsm_loss: 0.2339 reg_loss: 0.1341 n_pos_triplets: 57627;  Val: 0.6567 Test: 0.5985
# Epoch: 364, Loss: 0.3875 tsm_loss: 0.2459 reg_loss: 0.1416 n_pos_triplets: 62159;  Val: 0.6610 Test: 0.6054
# Epoch: 365, Loss: 0.3759 tsm_loss: 0.2374 reg_loss: 0.1384 n_pos_triplets: 58963;  Val: 0.6590 Test: 0.6021
# Epoch: 366, Loss: 0.3500 tsm_loss: 0.2301 reg_loss: 0.1199 n_pos_triplets: 62525;  Val: 0.6613 Test: 0.6045
# Epoch: 367, Loss: 0.3674 tsm_loss: 0.2366 reg_loss: 0.1308 n_pos_triplets: 63208;  Val: 0.6691 Test: 0.6069
# Epoch: 368, Loss: 0.3601 tsm_loss: 0.2155 reg_loss: 0.1446 n_pos_triplets: 58001;  Val: 0.6798 Test: 0.6310
# Epoch: 369, Loss: 0.3734 tsm_loss: 0.2327 reg_loss: 0.1407 n_pos_triplets: 58949;  Val: 0.6657 Test: 0.6071
# Epoch: 370, Loss: 0.4015 tsm_loss: 0.2378 reg_loss: 0.1636 n_pos_triplets: 61135;  Val: 0.6613 Test: 0.5994
# Epoch: 371, Loss: 0.3796 tsm_loss: 0.2333 reg_loss: 0.1464 n_pos_triplets: 59170;  Val: 0.6774 Test: 0.6202
# Epoch: 372, Loss: 0.3503 tsm_loss: 0.2254 reg_loss: 0.1249 n_pos_triplets: 60200;  Val: 0.6666 Test: 0.6140
# Epoch: 373, Loss: 0.3826 tsm_loss: 0.2399 reg_loss: 0.1427 n_pos_triplets: 60377;  Val: 0.6715 Test: 0.6162
# Epoch: 374, Loss: 0.3894 tsm_loss: 0.2294 reg_loss: 0.1600 n_pos_triplets: 58008;  Val: 0.6776 Test: 0.6072
# Epoch: 375, Loss: 0.3409 tsm_loss: 0.2217 reg_loss: 0.1192 n_pos_triplets: 57789;  Val: 0.6708 Test: 0.6035
# Epoch: 376, Loss: 0.3606 tsm_loss: 0.2316 reg_loss: 0.1290 n_pos_triplets: 60383;  Val: 0.6692 Test: 0.6144
# Epoch: 377, Loss: 0.3666 tsm_loss: 0.2403 reg_loss: 0.1263 n_pos_triplets: 59788;  Val: 0.6655 Test: 0.5998
# Epoch: 378, Loss: 0.3385 tsm_loss: 0.2117 reg_loss: 0.1268 n_pos_triplets: 56547;  Val: 0.6672 Test: 0.5988
# Epoch: 379, Loss: 0.3771 tsm_loss: 0.2245 reg_loss: 0.1526 n_pos_triplets: 58086;  Val: 0.6899 Test: 0.6317
# Epoch: 380, Loss: 0.4059 tsm_loss: 0.2428 reg_loss: 0.1630 n_pos_triplets: 59669;  Val: 0.6623 Test: 0.6094
# Epoch: 381, Loss: 0.3808 tsm_loss: 0.2336 reg_loss: 0.1472 n_pos_triplets: 58096;  Val: 0.6746 Test: 0.6023
# Epoch: 382, Loss: 0.3535 tsm_loss: 0.2277 reg_loss: 0.1258 n_pos_triplets: 57056;  Val: 0.6843 Test: 0.6304
# Epoch: 383, Loss: 0.3716 tsm_loss: 0.2278 reg_loss: 0.1438 n_pos_triplets: 58585;  Val: 0.6579 Test: 0.6072
# Epoch: 384, Loss: 0.3897 tsm_loss: 0.2302 reg_loss: 0.1595 n_pos_triplets: 60613;  Val: 0.6626 Test: 0.5973
# Epoch: 385, Loss: 0.3937 tsm_loss: 0.2224 reg_loss: 0.1713 n_pos_triplets: 59195;  Val: 0.6712 Test: 0.6213
# Epoch: 386, Loss: 0.3345 tsm_loss: 0.2168 reg_loss: 0.1177 n_pos_triplets: 56982;  Val: 0.6492 Test: 0.6123
# Epoch: 387, Loss: 0.3776 tsm_loss: 0.2174 reg_loss: 0.1602 n_pos_triplets: 56520;  Val: 0.6635 Test: 0.6067
# Epoch: 388, Loss: 0.3572 tsm_loss: 0.2204 reg_loss: 0.1369 n_pos_triplets: 55894;  Val: 0.6729 Test: 0.6149
# Epoch: 389, Loss: 0.3393 tsm_loss: 0.2119 reg_loss: 0.1275 n_pos_triplets: 57575;  Val: 0.6634 Test: 0.6079
# Epoch: 390, Loss: 0.3491 tsm_loss: 0.2098 reg_loss: 0.1392 n_pos_triplets: 55700;  Val: 0.6887 Test: 0.6343
# Epoch: 391, Loss: 0.3377 tsm_loss: 0.2130 reg_loss: 0.1246 n_pos_triplets: 55843;  Val: 0.6689 Test: 0.6103
# Epoch: 392, Loss: 0.3445 tsm_loss: 0.2151 reg_loss: 0.1294 n_pos_triplets: 57502;  Val: 0.6591 Test: 0.6037
# Epoch: 393, Loss: 0.3413 tsm_loss: 0.2016 reg_loss: 0.1397 n_pos_triplets: 54356;  Val: 0.6684 Test: 0.6119
# Epoch: 394, Loss: 0.3931 tsm_loss: 0.2263 reg_loss: 0.1668 n_pos_triplets: 57134;  Val: 0.6721 Test: 0.6099
# Epoch: 395, Loss: 0.3441 tsm_loss: 0.2199 reg_loss: 0.1242 n_pos_triplets: 58295;  Val: 0.6658 Test: 0.5990
# Epoch: 396, Loss: 0.3354 tsm_loss: 0.2120 reg_loss: 0.1234 n_pos_triplets: 55590;  Val: 0.6704 Test: 0.6108
# Epoch: 397, Loss: 0.3510 tsm_loss: 0.2171 reg_loss: 0.1339 n_pos_triplets: 57228;  Val: 0.6714 Test: 0.6103
# Epoch: 398, Loss: 0.3362 tsm_loss: 0.2177 reg_loss: 0.1185 n_pos_triplets: 58383;  Val: 0.6563 Test: 0.5940
# Epoch: 399, Loss: 0.3281 tsm_loss: 0.2197 reg_loss: 0.1084 n_pos_triplets: 55436;  Val: 0.6620 Test: 0.6054
# Epoch: 400, Loss: 0.3229 tsm_loss: 0.2127 reg_loss: 0.1103 n_pos_triplets: 57313;  Val: 0.6724 Test: 0.6077
# Epoch: 401, Loss: 0.3319 tsm_loss: 0.2095 reg_loss: 0.1224 n_pos_triplets: 54107;  Val: 0.6648 Test: 0.5940
# Epoch: 402, Loss: 0.3446 tsm_loss: 0.2115 reg_loss: 0.1331 n_pos_triplets: 55688;  Val: 0.6594 Test: 0.5847
# Epoch: 403, Loss: 0.3381 tsm_loss: 0.2104 reg_loss: 0.1276 n_pos_triplets: 57116;  Val: 0.6740 Test: 0.6078
# Epoch: 404, Loss: 0.3993 tsm_loss: 0.2066 reg_loss: 0.1927 n_pos_triplets: 53775;  Val: 0.7121 Test: 0.6431
# Epoch: 405, Loss: 0.4093 tsm_loss: 0.2194 reg_loss: 0.1899 n_pos_triplets: 58307;  Val: 0.6770 Test: 0.5969
# Epoch: 406, Loss: 0.3923 tsm_loss: 0.2073 reg_loss: 0.1850 n_pos_triplets: 55524;  Val: 0.6900 Test: 0.6368
# Epoch: 407, Loss: 0.3493 tsm_loss: 0.2053 reg_loss: 0.1440 n_pos_triplets: 55112;  Val: 0.6580 Test: 0.6005
# Epoch: 408, Loss: 0.3575 tsm_loss: 0.2086 reg_loss: 0.1490 n_pos_triplets: 55618;  Val: 0.6529 Test: 0.6056
# Epoch: 409, Loss: 0.3114 tsm_loss: 0.1952 reg_loss: 0.1162 n_pos_triplets: 53628;  Val: 0.6587 Test: 0.6034
# Epoch: 410, Loss: 0.3433 tsm_loss: 0.2020 reg_loss: 0.1412 n_pos_triplets: 52965;  Val: 0.6907 Test: 0.5997
# Epoch: 411, Loss: 0.3509 tsm_loss: 0.2024 reg_loss: 0.1485 n_pos_triplets: 53583;  Val: 0.6654 Test: 0.5975
# Epoch: 412, Loss: 0.3398 tsm_loss: 0.2109 reg_loss: 0.1289 n_pos_triplets: 56941;  Val: 0.6675 Test: 0.6062
# Epoch: 413, Loss: 0.3337 tsm_loss: 0.2172 reg_loss: 0.1166 n_pos_triplets: 57830;  Val: 0.6657 Test: 0.5944
# Epoch: 414, Loss: 0.3263 tsm_loss: 0.2055 reg_loss: 0.1207 n_pos_triplets: 53710;  Val: 0.6655 Test: 0.6072
# Epoch: 415, Loss: 0.3222 tsm_loss: 0.1976 reg_loss: 0.1246 n_pos_triplets: 55963;  Val: 0.6727 Test: 0.6188
# Epoch: 416, Loss: 0.3650 tsm_loss: 0.2161 reg_loss: 0.1488 n_pos_triplets: 55442;  Val: 0.6668 Test: 0.5892
# Epoch: 417, Loss: 0.3268 tsm_loss: 0.1993 reg_loss: 0.1275 n_pos_triplets: 54126;  Val: 0.6633 Test: 0.5991
# Epoch: 418, Loss: 0.3672 tsm_loss: 0.2252 reg_loss: 0.1420 n_pos_triplets: 56960;  Val: 0.6622 Test: 0.5978
# Epoch: 419, Loss: 0.3368 tsm_loss: 0.1901 reg_loss: 0.1468 n_pos_triplets: 53311;  Val: 0.6610 Test: 0.5998
# Epoch: 420, Loss: 0.3435 tsm_loss: 0.2067 reg_loss: 0.1369 n_pos_triplets: 54324;  Val: 0.6842 Test: 0.6242
# Epoch: 421, Loss: 0.3928 tsm_loss: 0.2004 reg_loss: 0.1924 n_pos_triplets: 54429;  Val: 0.6701 Test: 0.5978
# Epoch: 422, Loss: 0.3544 tsm_loss: 0.2206 reg_loss: 0.1338 n_pos_triplets: 57642;  Val: 0.6596 Test: 0.6007
# Epoch: 423, Loss: 0.3367 tsm_loss: 0.2071 reg_loss: 0.1296 n_pos_triplets: 55644;  Val: 0.6591 Test: 0.5981
# Epoch: 424, Loss: 0.3201 tsm_loss: 0.2010 reg_loss: 0.1191 n_pos_triplets: 55832;  Val: 0.6742 Test: 0.5999
# Epoch: 425, Loss: 0.3304 tsm_loss: 0.2093 reg_loss: 0.1211 n_pos_triplets: 55388;  Val: 0.6671 Test: 0.5968
# Epoch: 426, Loss: 0.3080 tsm_loss: 0.2012 reg_loss: 0.1068 n_pos_triplets: 56542;  Val: 0.6742 Test: 0.6033
# Epoch: 427, Loss: 0.3312 tsm_loss: 0.2041 reg_loss: 0.1271 n_pos_triplets: 55228;  Val: 0.6694 Test: 0.5952
# Epoch: 428, Loss: 0.2961 tsm_loss: 0.1887 reg_loss: 0.1074 n_pos_triplets: 51297;  Val: 0.6623 Test: 0.6004
# Epoch: 429, Loss: 0.3610 tsm_loss: 0.2197 reg_loss: 0.1413 n_pos_triplets: 54288;  Val: 0.6718 Test: 0.6091
# Epoch: 430, Loss: 0.3106 tsm_loss: 0.1969 reg_loss: 0.1137 n_pos_triplets: 54094;  Val: 0.6690 Test: 0.5960
# Epoch: 431, Loss: 0.2906 tsm_loss: 0.1927 reg_loss: 0.0979 n_pos_triplets: 52117;  Val: 0.6702 Test: 0.6132
# Epoch: 432, Loss: 0.3327 tsm_loss: 0.1973 reg_loss: 0.1354 n_pos_triplets: 54923;  Val: 0.6656 Test: 0.6075
# Epoch: 433, Loss: 0.3419 tsm_loss: 0.2054 reg_loss: 0.1365 n_pos_triplets: 54555;  Val: 0.6743 Test: 0.6049
# Epoch: 434, Loss: 0.3348 tsm_loss: 0.2035 reg_loss: 0.1313 n_pos_triplets: 54015;  Val: 0.6658 Test: 0.6021
# Epoch: 435, Loss: 0.3065 tsm_loss: 0.1983 reg_loss: 0.1082 n_pos_triplets: 53187;  Val: 0.6565 Test: 0.5897
# Epoch: 436, Loss: 0.3123 tsm_loss: 0.1964 reg_loss: 0.1160 n_pos_triplets: 53974;  Val: 0.6740 Test: 0.6105
# Epoch: 437, Loss: 0.3304 tsm_loss: 0.2007 reg_loss: 0.1297 n_pos_triplets: 53720;  Val: 0.6646 Test: 0.5959
# Epoch: 438, Loss: 0.3593 tsm_loss: 0.1988 reg_loss: 0.1605 n_pos_triplets: 54139;  Val: 0.6762 Test: 0.6182
# ...
# Epoch: 113, Loss: 0.8940 tsm_loss: 0.5798 reg_loss: 0.3143 n_pos_triplets: 110332;  Val: 0.7171 Test: 0.6399
# Epoch: 114, Loss: 0.8659 tsm_loss: 0.5762 reg_loss: 0.2897 n_pos_triplets: 106567;  Val: 0.6872 Test: 0.6162
# Epoch: 115, Loss: 0.8546 tsm_loss: 0.5670 reg_loss: 0.2876 n_pos_triplets: 108434;  Val: 0.6845 Test: 0.6086
# Epoch: 116, Loss: 0.8551 tsm_loss: 0.5684 reg_loss: 0.2868 n_pos_triplets: 108725;  Val: 0.7122 Test: 0.6200
# Epoch: 117, Loss: 0.8717 tsm_loss: 0.5468 reg_loss: 0.3250 n_pos_triplets: 107120;  Val: 0.6920 Test: 0.6309
# Epoch: 118, Loss: 0.8460 tsm_loss: 0.5637 reg_loss: 0.2823 n_pos_triplets: 104990;  Val: 0.7161 Test: 0.6343
# Epoch: 119, Loss: 0.8502 tsm_loss: 0.5648 reg_loss: 0.2854 n_pos_triplets: 107360;  Val: 0.6867 Test: 0.6152
# Epoch: 120, Loss: 0.8406 tsm_loss: 0.5602 reg_loss: 0.2804 n_pos_triplets: 108421;  Val: 0.6953 Test: 0.6111
# Epoch: 121, Loss: 0.8489 tsm_loss: 0.5548 reg_loss: 0.2941 n_pos_triplets: 105845;  Val: 0.6897 Test: 0.6090
# Epoch: 122, Loss: 0.8605 tsm_loss: 0.5584 reg_loss: 0.3021 n_pos_triplets: 104941;  Val: 0.7014 Test: 0.6319
# Epoch: 123, Loss: 0.8840 tsm_loss: 0.5521 reg_loss: 0.3319 n_pos_triplets: 108642;  Val: 0.6864 Test: 0.6230
# Epoch: 124, Loss: 0.9401 tsm_loss: 0.5830 reg_loss: 0.3572 n_pos_triplets: 105712;  Val: 0.7221 Test: 0.6440
# Epoch: 125, Loss: 0.8597 tsm_loss: 0.5547 reg_loss: 0.3050 n_pos_triplets: 103658;  Val: 0.6851 Test: 0.6184
# Epoch: 126, Loss: 0.8276 tsm_loss: 0.5447 reg_loss: 0.2829 n_pos_triplets: 106602;  Val: 0.7286 Test: 0.6426
# Epoch: 127, Loss: 0.8721 tsm_loss: 0.5529 reg_loss: 0.3192 n_pos_triplets: 107187;  Val: 0.6831 Test: 0.6059
# Epoch: 128, Loss: 0.7883 tsm_loss: 0.5302 reg_loss: 0.2582 n_pos_triplets: 103677;  Val: 0.6968 Test: 0.6075
# Epoch: 129, Loss: 0.8301 tsm_loss: 0.5510 reg_loss: 0.2791 n_pos_triplets: 106155;  Val: 0.6824 Test: 0.6077
# Epoch: 130, Loss: 0.7805 tsm_loss: 0.5029 reg_loss: 0.2776 n_pos_triplets: 101332;  Val: 0.6833 Test: 0.6029
# Epoch: 131, Loss: 0.8301 tsm_loss: 0.5431 reg_loss: 0.2870 n_pos_triplets: 104045;  Val: 0.6855 Test: 0.6039
# Epoch: 132, Loss: 0.7804 tsm_loss: 0.5149 reg_loss: 0.2655 n_pos_triplets: 100243;  Val: 0.6908 Test: 0.6160
# Epoch: 133, Loss: 0.7912 tsm_loss: 0.5179 reg_loss: 0.2733 n_pos_triplets: 102403;  Val: 0.6848 Test: 0.5975
# Epoch: 134, Loss: 0.8181 tsm_loss: 0.5196 reg_loss: 0.2984 n_pos_triplets: 103869;  Val: 0.7004 Test: 0.6066
# Epoch: 135, Loss: 0.7962 tsm_loss: 0.5187 reg_loss: 0.2775 n_pos_triplets: 103881;  Val: 0.6862 Test: 0.6180
# Epoch: 136, Loss: 0.8546 tsm_loss: 0.5150 reg_loss: 0.3395 n_pos_triplets: 101946;  Val: 0.7468 Test: 0.6607
# Epoch: 137, Loss: 0.8207 tsm_loss: 0.5072 reg_loss: 0.3135 n_pos_triplets: 102863;  Val: 0.7181 Test: 0.6532
# Epoch: 138, Loss: 0.8542 tsm_loss: 0.4952 reg_loss: 0.3590 n_pos_triplets: 100446;  Val: 0.7263 Test: 0.6330
# Epoch: 139, Loss: 0.8008 tsm_loss: 0.5272 reg_loss: 0.2736 n_pos_triplets: 103590;  Val: 0.6971 Test: 0.6250
# Epoch: 140, Loss: 0.8125 tsm_loss: 0.4974 reg_loss: 0.3151 n_pos_triplets: 100766;  Val: 0.7266 Test: 0.6391
# Epoch: 141, Loss: 0.7981 tsm_loss: 0.5016 reg_loss: 0.2965 n_pos_triplets: 101224;  Val: 0.6843 Test: 0.6068
# Epoch: 142, Loss: 0.8013 tsm_loss: 0.5339 reg_loss: 0.2674 n_pos_triplets: 105046;  Val: 0.7200 Test: 0.6300
# Epoch: 143, Loss: 0.7416 tsm_loss: 0.4921 reg_loss: 0.2495 n_pos_triplets: 100320;  Val: 0.6896 Test: 0.6047
# Epoch: 144, Loss: 0.7532 tsm_loss: 0.4891 reg_loss: 0.2641 n_pos_triplets: 100342;  Val: 0.7055 Test: 0.6035
# Epoch: 145, Loss: 0.7388 tsm_loss: 0.4804 reg_loss: 0.2584 n_pos_triplets: 97940;  Val: 0.6852 Test: 0.6026
# Epoch: 146, Loss: 0.7502 tsm_loss: 0.4809 reg_loss: 0.2693 n_pos_triplets: 99642;  Val: 0.6932 Test: 0.6008
# Epoch: 147, Loss: 0.7745 tsm_loss: 0.5126 reg_loss: 0.2619 n_pos_triplets: 102112;  Val: 0.7098 Test: 0.6087
# Epoch: 148, Loss: 0.7519 tsm_loss: 0.5000 reg_loss: 0.2519 n_pos_triplets: 98536;  Val: 0.6933 Test: 0.6060
# Epoch: 149, Loss: 0.7724 tsm_loss: 0.4864 reg_loss: 0.2860 n_pos_triplets: 98749;  Val: 0.7330 Test: 0.6330
# Epoch: 150, Loss: 0.7805 tsm_loss: 0.5008 reg_loss: 0.2797 n_pos_triplets: 98676;  Val: 0.6942 Test: 0.6028
# Epoch: 151, Loss: 0.7308 tsm_loss: 0.4943 reg_loss: 0.2365 n_pos_triplets: 101841;  Val: 0.6906 Test: 0.6013
# Epoch: 152, Loss: 0.7239 tsm_loss: 0.4766 reg_loss: 0.2474 n_pos_triplets: 100133;  Val: 0.6991 Test: 0.6049
# Epoch: 153, Loss: 0.7302 tsm_loss: 0.4733 reg_loss: 0.2569 n_pos_triplets: 97570;  Val: 0.7125 Test: 0.6083
# Epoch: 154, Loss: 0.7653 tsm_loss: 0.4939 reg_loss: 0.2714 n_pos_triplets: 101672;  Val: 0.6860 Test: 0.5957
# Epoch: 155, Loss: 0.7442 tsm_loss: 0.4978 reg_loss: 0.2465 n_pos_triplets: 99185;  Val: 0.6947 Test: 0.6037
# Epoch: 156, Loss: 0.7309 tsm_loss: 0.4835 reg_loss: 0.2473 n_pos_triplets: 101454;  Val: 0.6992 Test: 0.6032
# Epoch: 157, Loss: 0.6837 tsm_loss: 0.4538 reg_loss: 0.2299 n_pos_triplets: 95743;  Val: 0.6954 Test: 0.6004
# Epoch: 158, Loss: 0.7062 tsm_loss: 0.4590 reg_loss: 0.2472 n_pos_triplets: 97330;  Val: 0.7115 Test: 0.6015
# Epoch: 159, Loss: 0.7308 tsm_loss: 0.4680 reg_loss: 0.2628 n_pos_triplets: 97334;  Val: 0.6931 Test: 0.5864
# Epoch: 160, Loss: 0.6856 tsm_loss: 0.4425 reg_loss: 0.2431 n_pos_triplets: 95161;  Val: 0.6856 Test: 0.5854
# Epoch: 161, Loss: 0.7636 tsm_loss: 0.4789 reg_loss: 0.2847 n_pos_triplets: 95598;  Val: 0.7169 Test: 0.6087
# Epoch: 162, Loss: 0.6893 tsm_loss: 0.4535 reg_loss: 0.2358 n_pos_triplets: 94201;  Val: 0.6990 Test: 0.6015
# Epoch: 163, Loss: 0.6871 tsm_loss: 0.4599 reg_loss: 0.2272 n_pos_triplets: 96520;  Val: 0.6887 Test: 0.5946
# Epoch: 164, Loss: 0.6708 tsm_loss: 0.4474 reg_loss: 0.2234 n_pos_triplets: 97850;  Val: 0.6985 Test: 0.5904
# Epoch: 165, Loss: 0.6833 tsm_loss: 0.4527 reg_loss: 0.2305 n_pos_triplets: 96514;  Val: 0.7110 Test: 0.6030
# Epoch: 166, Loss: 0.7002 tsm_loss: 0.4598 reg_loss: 0.2405 n_pos_triplets: 99612;  Val: 0.6967 Test: 0.5992
# Epoch: 167, Loss: 0.6746 tsm_loss: 0.4415 reg_loss: 0.2331 n_pos_triplets: 94983;  Val: 0.7097 Test: 0.6055
# Epoch: 168, Loss: 0.6739 tsm_loss: 0.4440 reg_loss: 0.2299 n_pos_triplets: 94927;  Val: 0.6889 Test: 0.5950
# Epoch: 169, Loss: 0.7075 tsm_loss: 0.4379 reg_loss: 0.2696 n_pos_triplets: 92654;  Val: 0.7569 Test: 0.6508
# Epoch: 170, Loss: 0.6856 tsm_loss: 0.4411 reg_loss: 0.2445 n_pos_triplets: 94013;  Val: 0.6989 Test: 0.5899
# Epoch: 171, Loss: 0.6632 tsm_loss: 0.4372 reg_loss: 0.2259 n_pos_triplets: 93398;  Val: 0.6891 Test: 0.5855
# Epoch: 172, Loss: 0.6679 tsm_loss: 0.4361 reg_loss: 0.2318 n_pos_triplets: 95138;  Val: 0.7033 Test: 0.5983
# Epoch: 173, Loss: 0.6739 tsm_loss: 0.4252 reg_loss: 0.2487 n_pos_triplets: 91704;  Val: 0.6924 Test: 0.5901
# Epoch: 174, Loss: 0.6574 tsm_loss: 0.4298 reg_loss: 0.2275 n_pos_triplets: 91355;  Val: 0.7094 Test: 0.5989
# Epoch: 175, Loss: 0.6685 tsm_loss: 0.4325 reg_loss: 0.2361 n_pos_triplets: 93865;  Val: 0.6942 Test: 0.5986
# Epoch: 176, Loss: 0.6788 tsm_loss: 0.4456 reg_loss: 0.2332 n_pos_triplets: 95735;  Val: 0.7001 Test: 0.6025
# Epoch: 177, Loss: 0.6583 tsm_loss: 0.4196 reg_loss: 0.2387 n_pos_triplets: 92280;  Val: 0.7039 Test: 0.5921
# Epoch: 178, Loss: 0.6409 tsm_loss: 0.4217 reg_loss: 0.2191 n_pos_triplets: 91163;  Val: 0.6967 Test: 0.5827
# Epoch: 179, Loss: 0.6608 tsm_loss: 0.4399 reg_loss: 0.2209 n_pos_triplets: 95343;  Val: 0.7052 Test: 0.5939
# Epoch: 180, Loss: 0.6932 tsm_loss: 0.4337 reg_loss: 0.2595 n_pos_triplets: 93740;  Val: 0.7059 Test: 0.6133
# Epoch: 181, Loss: 0.6403 tsm_loss: 0.4029 reg_loss: 0.2373 n_pos_triplets: 88666;  Val: 0.7068 Test: 0.6014
# Epoch: 182, Loss: 0.6393 tsm_loss: 0.4184 reg_loss: 0.2209 n_pos_triplets: 91826;  Val: 0.7077 Test: 0.6033
# Epoch: 183, Loss: 0.6475 tsm_loss: 0.4151 reg_loss: 0.2325 n_pos_triplets: 88388;  Val: 0.6939 Test: 0.5958
# Epoch: 184, Loss: 0.6523 tsm_loss: 0.4329 reg_loss: 0.2193 n_pos_triplets: 91971;  Val: 0.7033 Test: 0.5921
# Epoch: 185, Loss: 0.6174 tsm_loss: 0.4122 reg_loss: 0.2052 n_pos_triplets: 89523;  Val: 0.7210 Test: 0.6074
# Epoch: 186, Loss: 0.6205 tsm_loss: 0.4058 reg_loss: 0.2147 n_pos_triplets: 90447;  Val: 0.7027 Test: 0.6032
# Epoch: 187, Loss: 0.6564 tsm_loss: 0.4202 reg_loss: 0.2362 n_pos_triplets: 92376;  Val: 0.7105 Test: 0.5903
# Epoch: 188, Loss: 0.6343 tsm_loss: 0.4262 reg_loss: 0.2081 n_pos_triplets: 92337;  Val: 0.7198 Test: 0.5953
# Epoch: 189, Loss: 0.6216 tsm_loss: 0.4035 reg_loss: 0.2180 n_pos_triplets: 90416;  Val: 0.7066 Test: 0.5916
# Epoch: 190, Loss: 0.6037 tsm_loss: 0.3944 reg_loss: 0.2094 n_pos_triplets: 90782;  Val: 0.7130 Test: 0.6063
# Epoch: 191, Loss: 0.6278 tsm_loss: 0.4197 reg_loss: 0.2081 n_pos_triplets: 92960;  Val: 0.6967 Test: 0.5909
# Epoch: 192, Loss: 0.6314 tsm_loss: 0.4021 reg_loss: 0.2293 n_pos_triplets: 89070;  Val: 0.6976 Test: 0.5858
# Epoch: 193, Loss: 0.6065 tsm_loss: 0.3920 reg_loss: 0.2145 n_pos_triplets: 91015;  Val: 0.7160 Test: 0.5978
# Epoch: 194, Loss: 0.6068 tsm_loss: 0.3933 reg_loss: 0.2134 n_pos_triplets: 90119;  Val: 0.7027 Test: 0.5924
# Epoch: 195, Loss: 0.5820 tsm_loss: 0.3771 reg_loss: 0.2048 n_pos_triplets: 85925;  Val: 0.7013 Test: 0.5828
# Epoch: 196, Loss: 0.6017 tsm_loss: 0.3927 reg_loss: 0.2091 n_pos_triplets: 86907;  Val: 0.6954 Test: 0.5786
# Epoch: 197, Loss: 0.5908 tsm_loss: 0.3903 reg_loss: 0.2005 n_pos_triplets: 86868;  Val: 0.6972 Test: 0.5867
# Epoch: 198, Loss: 0.5991 tsm_loss: 0.4008 reg_loss: 0.1982 n_pos_triplets: 88558;  Val: 0.7003 Test: 0.5946
# Epoch: 199, Loss: 0.5925 tsm_loss: 0.3865 reg_loss: 0.2060 n_pos_triplets: 87322;  Val: 0.7044 Test: 0.5925
# Epoch: 200, Loss: 0.5829 tsm_loss: 0.3834 reg_loss: 0.1995 n_pos_triplets: 84422;  Val: 0.7012 Test: 0.5898
# Epoch: 201, Loss: 0.6489 tsm_loss: 0.4032 reg_loss: 0.2458 n_pos_triplets: 89776;  Val: 0.7638 Test: 0.6487
# Epoch: 202, Loss: 0.6377 tsm_loss: 0.3797 reg_loss: 0.2579 n_pos_triplets: 85728;  Val: 0.6978 Test: 0.5837
# Epoch: 203, Loss: 0.6068 tsm_loss: 0.3955 reg_loss: 0.2113 n_pos_triplets: 88045;  Val: 0.6917 Test: 0.5770
# Epoch: 204, Loss: 0.6243 tsm_loss: 0.4096 reg_loss: 0.2147 n_pos_triplets: 89957;  Val: 0.6983 Test: 0.5824
# Epoch: 205, Loss: 0.5840 tsm_loss: 0.3814 reg_loss: 0.2026 n_pos_triplets: 87566;  Val: 0.7058 Test: 0.5915
# Epoch: 206, Loss: 0.6085 tsm_loss: 0.3829 reg_loss: 0.2256 n_pos_triplets: 88688;  Val: 0.6925 Test: 0.5827
# Epoch: 207, Loss: 0.5804 tsm_loss: 0.3797 reg_loss: 0.2007 n_pos_triplets: 84909;  Val: 0.7106 Test: 0.5950
# Epoch: 208, Loss: 0.5767 tsm_loss: 0.3736 reg_loss: 0.2032 n_pos_triplets: 85881;  Val: 0.7001 Test: 0.5939
# Epoch: 209, Loss: 0.5838 tsm_loss: 0.3769 reg_loss: 0.2070 n_pos_triplets: 85406;  Val: 0.7044 Test: 0.5946
# Epoch: 210, Loss: 0.5750 tsm_loss: 0.3629 reg_loss: 0.2121 n_pos_triplets: 85109;  Val: 0.7123 Test: 0.5907
# Epoch: 211, Loss: 0.5732 tsm_loss: 0.3717 reg_loss: 0.2014 n_pos_triplets: 84897;  Val: 0.7031 Test: 0.5906
# Epoch: 212, Loss: 0.5768 tsm_loss: 0.3757 reg_loss: 0.2011 n_pos_triplets: 84178;  Val: 0.7097 Test: 0.5881
# Epoch: 213, Loss: 0.5890 tsm_loss: 0.3764 reg_loss: 0.2125 n_pos_triplets: 88054;  Val: 0.7100 Test: 0.5879
# Epoch: 214, Loss: 0.5680 tsm_loss: 0.3753 reg_loss: 0.1927 n_pos_triplets: 84885;  Val: 0.7183 Test: 0.5974
# Epoch: 215, Loss: 0.5852 tsm_loss: 0.3772 reg_loss: 0.2080 n_pos_triplets: 88261;  Val: 0.7096 Test: 0.5903
# Epoch: 216, Loss: 0.5527 tsm_loss: 0.3637 reg_loss: 0.1890 n_pos_triplets: 85087;  Val: 0.7112 Test: 0.5914
# Epoch: 217, Loss: 0.5392 tsm_loss: 0.3583 reg_loss: 0.1809 n_pos_triplets: 83000;  Val: 0.7197 Test: 0.5956
# Epoch: 218, Loss: 0.5541 tsm_loss: 0.3713 reg_loss: 0.1828 n_pos_triplets: 86201;  Val: 0.7155 Test: 0.5957
# Epoch: 219, Loss: 0.6259 tsm_loss: 0.3716 reg_loss: 0.2542 n_pos_triplets: 84753;  Val: 0.7421 Test: 0.6207
# Epoch: 220, Loss: 0.5735 tsm_loss: 0.3632 reg_loss: 0.2103 n_pos_triplets: 84090;  Val: 0.7079 Test: 0.5880
# Epoch: 221, Loss: 0.5672 tsm_loss: 0.3734 reg_loss: 0.1939 n_pos_triplets: 85112;  Val: 0.7054 Test: 0.5875
# Epoch: 222, Loss: 0.5906 tsm_loss: 0.3739 reg_loss: 0.2166 n_pos_triplets: 86332;  Val: 0.7041 Test: 0.5905
# Epoch: 223, Loss: 0.5499 tsm_loss: 0.3586 reg_loss: 0.1913 n_pos_triplets: 84031;  Val: 0.6984 Test: 0.5898
# Epoch: 224, Loss: 0.5655 tsm_loss: 0.3691 reg_loss: 0.1964 n_pos_triplets: 84382;  Val: 0.7219 Test: 0.6132
# Epoch: 225, Loss: 0.5520 tsm_loss: 0.3578 reg_loss: 0.1942 n_pos_triplets: 85201;  Val: 0.6954 Test: 0.5849
# Epoch: 226, Loss: 0.5645 tsm_loss: 0.3514 reg_loss: 0.2131 n_pos_triplets: 83244;  Val: 0.7071 Test: 0.5863
# Epoch: 227, Loss: 0.5761 tsm_loss: 0.3630 reg_loss: 0.2132 n_pos_triplets: 83202;  Val: 0.7309 Test: 0.6107
# Epoch: 228, Loss: 0.5593 tsm_loss: 0.3596 reg_loss: 0.1997 n_pos_triplets: 84414;  Val: 0.7132 Test: 0.5889
# Epoch: 229, Loss: 0.5413 tsm_loss: 0.3539 reg_loss: 0.1874 n_pos_triplets: 84778;  Val: 0.6988 Test: 0.5782
# Epoch: 230, Loss: 0.5300 tsm_loss: 0.3499 reg_loss: 0.1801 n_pos_triplets: 83613;  Val: 0.7043 Test: 0.5850
# Epoch: 231, Loss: 0.5636 tsm_loss: 0.3529 reg_loss: 0.2107 n_pos_triplets: 82318;  Val: 0.7229 Test: 0.5953
# Epoch: 232, Loss: 0.5765 tsm_loss: 0.3590 reg_loss: 0.2174 n_pos_triplets: 83171;  Val: 0.7038 Test: 0.5799
# Epoch: 233, Loss: 0.5123 tsm_loss: 0.3358 reg_loss: 0.1765 n_pos_triplets: 81565;  Val: 0.7168 Test: 0.5982
# Epoch: 234, Loss: 0.5314 tsm_loss: 0.3401 reg_loss: 0.1913 n_pos_triplets: 84033;  Val: 0.6978 Test: 0.5939
# Epoch: 235, Loss: 0.5312 tsm_loss: 0.3321 reg_loss: 0.1992 n_pos_triplets: 80562;  Val: 0.7171 Test: 0.5997
# Epoch: 236, Loss: 0.5300 tsm_loss: 0.3392 reg_loss: 0.1908 n_pos_triplets: 79934;  Val: 0.7071 Test: 0.5839
# Epoch: 237, Loss: 0.5436 tsm_loss: 0.3501 reg_loss: 0.1935 n_pos_triplets: 81583;  Val: 0.7150 Test: 0.5917
# Epoch: 238, Loss: 0.5582 tsm_loss: 0.3479 reg_loss: 0.2103 n_pos_triplets: 84431;  Val: 0.7429 Test: 0.6159
# Epoch: 239, Loss: 0.5677 tsm_loss: 0.3302 reg_loss: 0.2375 n_pos_triplets: 81081;  Val: 0.7270 Test: 0.6031
# Epoch: 240, Loss: 0.5321 tsm_loss: 0.3555 reg_loss: 0.1766 n_pos_triplets: 82444;  Val: 0.7080 Test: 0.5882
# Epoch: 241, Loss: 0.5353 tsm_loss: 0.3340 reg_loss: 0.2013 n_pos_triplets: 82763;  Val: 0.7089 Test: 0.5841
# Epoch: 242, Loss: 0.5199 tsm_loss: 0.3404 reg_loss: 0.1795 n_pos_triplets: 79434;  Val: 0.7257 Test: 0.5973
# Epoch: 243, Loss: 0.5578 tsm_loss: 0.3554 reg_loss: 0.2024 n_pos_triplets: 83165;  Val: 0.7115 Test: 0.5886
# Epoch: 244, Loss: 0.4993 tsm_loss: 0.3345 reg_loss: 0.1648 n_pos_triplets: 82371;  Val: 0.7089 Test: 0.5848
# Epoch: 245, Loss: 0.5435 tsm_loss: 0.3401 reg_loss: 0.2034 n_pos_triplets: 82271;  Val: 0.7367 Test: 0.6018
# Epoch: 246, Loss: 0.5691 tsm_loss: 0.3400 reg_loss: 0.2291 n_pos_triplets: 82049;  Val: 0.7140 Test: 0.6029
# Epoch: 247, Loss: 0.5379 tsm_loss: 0.3416 reg_loss: 0.1963 n_pos_triplets: 82651;  Val: 0.7124 Test: 0.6003
# Epoch: 248, Loss: 0.5034 tsm_loss: 0.3246 reg_loss: 0.1788 n_pos_triplets: 80559;  Val: 0.7113 Test: 0.5954
# Epoch: 249, Loss: 0.5202 tsm_loss: 0.3374 reg_loss: 0.1829 n_pos_triplets: 77100;  Val: 0.6929 Test: 0.5841
# Epoch: 250, Loss: 0.5132 tsm_loss: 0.3323 reg_loss: 0.1809 n_pos_triplets: 81648;  Val: 0.7214 Test: 0.5875
# Epoch: 251, Loss: 0.5166 tsm_loss: 0.3271 reg_loss: 0.1895 n_pos_triplets: 77931;  Val: 0.7127 Test: 0.5801
# Epoch: 252, Loss: 0.5215 tsm_loss: 0.3374 reg_loss: 0.1841 n_pos_triplets: 81138;  Val: 0.6970 Test: 0.5788
# Epoch: 253, Loss: 0.4886 tsm_loss: 0.3304 reg_loss: 0.1582 n_pos_triplets: 78683;  Val: 0.7126 Test: 0.5929
# Epoch: 254, Loss: 0.5040 tsm_loss: 0.3253 reg_loss: 0.1787 n_pos_triplets: 78466;  Val: 0.7040 Test: 0.5835
# Epoch: 255, Loss: 0.5049 tsm_loss: 0.3276 reg_loss: 0.1773 n_pos_triplets: 78376;  Val: 0.7016 Test: 0.5661
# Epoch: 256, Loss: 0.5019 tsm_loss: 0.3319 reg_loss: 0.1700 n_pos_triplets: 80853;  Val: 0.7346 Test: 0.6009
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df1 = pd.concat(res1)
df2 = pd.concat(res2)

# %%
df1.to_csv('./with_aca.csv')
df2.to_csv('./without_aca.csv')

# %%
# df1 = pd.read_csv('./with_aca.csv', index_col = 0)
# df2 = pd.read_csv('./without_aca.csv', index_col = 0)

# %%
fig, ax = plt.subplots(figsize=(9, 6))
colors = ['#FFE699','#00B0F0']


y = 'val_rmse'

n1 = r'With AC-awareness ($\mathcal{L}_{mae} + \mathcal{L}_{tsm}$)'
n2 = r'Without AC-awareness ($\mathcal{L}_{mae}$)'


dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 2, ax=ax,color = colors, alpha =1, legend=True)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.2)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.2)

ax.set_ylim(0.60, 1.0)
ax.set_ylabel('Validation RMSE')
ax.set_xlabel('epochs')
ax.spines[['right', 'top']].set_visible(False)

ax.set_xlim(1,800)

ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Validation_RMSE.svg', bbox_inches='tight', dpi=400) 
fig.savefig('./Validation_RMSE.pdf', bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))
colors = ['#FFE699','#00B0F0']


y = 'test_rmse'



dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 2, ax=ax,color = colors, alpha =1, legend=True)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.2)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.2)

ax.set_ylim(0.60, 1.0)
ax.set_ylabel('Test RMSE')
ax.set_xlabel('epochs')
ax.spines[['right', 'top']].set_visible(False)

ax.set_xlim(1,800)

ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Test_RMSE.svg' , bbox_inches='tight', dpi=400) 
fig.savefig('./Test_RMSE.pdf' , bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))


y = 'n_pos_triplets'

dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 3, ax=ax,color = colors, alpha =1, legend=True)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.3)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.3)

#ax.legend(loc='center', bbox_to_anchor=(0.55, 0.5))

ax.spines[['right', 'top']].set_visible(False)

plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax.set_ylabel("No. of HV-ACTs ($M^'$)")
ax.set_xlabel('epochs')
ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
ax.set_xlim(-5,800)

fig.savefig('./Number_of_mined_ACTs_during_training.svg' , bbox_inches='tight', dpi=400) 
fig.savefig('./Number_of_mined_ACTs_during_training.pdf' , bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))
y = 'train_triplet_loss'
dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 3, ax=ax,color = colors, alpha =1, legend=True)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.3)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.3)

ax.spines[['right', 'top']].set_visible(False)
ax.set_xlim(-5,800)
ax.set_ylim(-1,10)

ax.set_ylabel('Training TSM Loss')
ax.set_xlabel('epochs')
ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Triplet_loss_during_training.svg', bbox_inches='tight', dpi=400) 
fig.savefig('./Triplet_loss_during_training.pdf', bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))

y = 'train_mae_loss'

dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 2.5, ax=ax,color = colors, alpha =1, legend=True)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.3)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.3)



ax.set_ylim(0.0, 0.8)
ax.spines[['right', 'top']].set_visible(False)


ax.set_ylabel('Training MAE loss')
ax.set_xlabel('epochs')
#ax.legend(loc='center', bbox_to_anchor=(0.55, 0.5))

ax.set_xlim(1,800)

ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Train_mae_los.svg', bbox_inches='tight', dpi=400) 
fig.savefig('./Train_mae_los.pdf', bbox_inches='tight', dpi=400)
