# %%
from rdkit import Chem
from rdkit.Chem import rdBase,Draw,AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import rdMolDraw2D, IPythonConsole
import networkx as nx
from networkx.readwrite import cytoscape_data
import cyjupyter
from cyjupyter import Cytoscape
from rdkit.Chem.Scaffolds import rdScaffoldNetwork
from urllib import parse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2736084/1116331097.py in <module>
#       5 import networkx as nx
#       6 from networkx.readwrite import cytoscape_data
# ----> 7 import cyjupyter
#       8 from cyjupyter import Cytoscape
#       9 from rdkit.Chem.Scaffolds import rdScaffoldNetwork
#
# ModuleNotFoundError: No module named 'cyjupyter'

# %%
# %pip install cyjupyter
# Out:
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Collecting cyjupyter
#   Downloading cyjupyter-0.2.0-py2.py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 406 kB/s eta 0:00:01
# Requirement already satisfied: ipywidgets>=7.0.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from cyjupyter) (7.6.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (7.29.0)
# Requirement already satisfied: nbformat>=4.2.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (1.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cyjupyter) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (7.1.0)
# Requirement already satisfied: pygments in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (2.10.0)
# Requirement already satisfied: backcall in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (58.0.4)
# Requirement already satisfied: pexpect>4.3 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (4.8.0)
# Requirement already satisfied: pickleshare in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (0.7.5)
# Requirement already satisfied: decorator in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (0.8.3)
# Requirement already satisfied: entrypoints in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /raid/cc_home/.local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cyjupyter) (1.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cyjupyter) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cyjupyter) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cyjupyter) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cyjupyter) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (0.7.0)
# Requirement already satisfied: wcwidth in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->cyjupyter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (6.4.6)
# Requirement already satisfied: nbconvert in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (6.3.0)
# Requirement already satisfied: prometheus-client in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.12.0)
# Requirement already satisfied: argon2-cffi in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.9.4)
# Requirement already satisfied: jinja2 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (3.0.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (1.8.0)
# Requirement already satisfied: cffi>=1.0.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (1.14.6)
# Requirement already satisfied: pycparser in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (2.0.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.5.3)
# Requirement already satisfied: testpath in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.5.0)
# Requirement already satisfied: defusedxml in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.1.2)
# Requirement already satisfied: bleach in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (1.4.3)
# Requirement already satisfied: async-generator in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (1.10)
# Requirement already satisfied: packaging in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (21.3)
# Requirement already satisfied: webencodings in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /raid/cc_home/anaconda3/envs/cuic/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cyjupyter) (3.0.6)
# Installing collected packages: cyjupyter
# Successfully installed cyjupyter-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from rdkit import Chem
from rdkit.Chem import rdBase,Draw,AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import rdMolDraw2D, IPythonConsole
import networkx as nx
from networkx.readwrite import cytoscape_data
import cyjupyter
from cyjupyter import Cytoscape
from rdkit.Chem.Scaffolds import rdScaffoldNetwork
from urllib import parse
print('pakages all installed!')
# Out:
# pakages all installed!

# %%
smile='C1=CC(=CC=C1NC2=C(C=C3C(=C2)C(=O)NC3=O)NC4=CC=C(C=C4)F)F'
mol=Chem.MolFromSmiles(smile)
mol

# %%
SNpara = rdScaffoldNetwork.ScaffoldNetworkParams()
SN = rdScaffoldNetwork.CreateScaffoldNetwork([mol], SNpara)
mol_nodes = [Chem.MolFromSmiles(sma) for sma in SN.nodes]
print(mol_nodes[0])
Draw.MolsToGridImage(mol_nodes)
# Out:
# <rdkit.Chem.rdchem.Mol object at 0x7fc9c66e4ee0>
