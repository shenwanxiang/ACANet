# %%
from estate import EstateFP
from rdkit import Chem
from utils import showAtomIdx, highlight

# %%
mol = Chem.MolFromSmiles('Cc1ccc(F)cc1-c1ccc2ncnc(Nc3cccc4[nH]ncc34)c2c1')
showAtomIdx(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x7FDBB37C0490>

# %%
esfp = EstateFP()
esfp = esfp(mol)
esfp.bitinfodict.keys()
# Out:
# dict_keys([6, 11, 16, 17, 23, 24, 28, 37])

# %%
bitidx = 37
esfp.bits[bitidx].info
# Out:
# ((5, 4),)

# %%
esfp.bits[bitidx].show(mol)

# %%
esfp.bits2df(esfp.bits)
# Out:
#     idx      name  on                                              patt  \
# 0     0   Estate0   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba626ba0>
# 1     1   Estate1   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba626c80>
# 2     2   Estate2   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba626cf0>
# 3     3   Estate3   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba626d60>
# 4     4   Estate4   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba626dd0>
# ..  ...       ...  ..                                               ...
# 74   74  Estate74   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba653cf0>
# 75   75  Estate75   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba653d60>
# 76   76  Estate76   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba653dd0>
# 77   77  Estate77   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba653e40>
# 78   78  Estate78   0  <rdkit.Chem.rdchem.Mol object at 0x7fdbba653eb0>
#
#     smarts info             descr atomInUse bondInUse
# ...
