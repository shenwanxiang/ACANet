# %%
from rgroup import RGroupFP
from rdkit import Chem
from utils import showAtomIdx, highlight

# %%
smiles = 'O=C(NCC1CCCCC1)[C@@H](Cc1cc2cc(ccc2nc1N)-c1ccccc1C)CCC'
mol = Chem.MolFromSmiles(smiles)
showAtomIdx(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x7F907BFBA910>

# %%
fp = RGroupFP(1024)
fp = fp(mol)
fp.bitinfodict.keys()
# Out:
# dict_keys([0, 2, 5, 10, 11, 12, 13, 14, 16, 17, 19, 24, 25, 27, 28, 30, 31, 35, 38, 55, 64, 66, 71, 73, 76, 95, 97, 106, 135, 137, 147, 151, 152, 161, 162, 163, 177, 178, 180, 199, 211, 213, 237, 247, 262, 266, 273, 277, 313, 314, 325, 326, 333, 351, 367, 377, 378, 403, 418, 423, 424, 492, 521, 523, 530, 532, 561, 680, 691, 714, 718, 749, 764, 940, 941, 954, 998, 1016])

# %%
bitidx = 12
fp.bits[bitidx].info
# Out:
# ((12, 13, 14, 19, 20, 21),)

# %%
fp.bits[bitidx].show(mol)

# %%
fp.bits2df(fp.bits)
# Out:
#        idx  name   on                                              patt  \
# 0        0     0  1.0  <rdkit.Chem.rdchem.Mol object at 0x7f90849dd200>
# 1        1     1  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90849dd270>
# 2        2     2  1.0  <rdkit.Chem.rdchem.Mol object at 0x7f90849dd2e0>
# 3        3     3  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90849dd350>
# 4        4     4  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90849dd3c0>
# ...    ...   ...  ...                                               ...
# 1019  1019  1019  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90848cb6d0>
# 1020  1020  1020  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90848cb740>
# 1021  1021  1021  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90848cb7b0>
# 1022  1022  1022  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90848cb820>
# 1023  1023  1023  0.0  <rdkit.Chem.rdchem.Mol object at 0x7f90848cb890>
#
#                      smarts           info  descr atomInUse bondInUse
# 0                         O        ((0,),)  13517       [0]        []
# 1                        OC             ()  12296        []        []
# 2                         N  ((2,), (22,))  11584   [2, 22]        []
# 3                        Cl             ()  11107        []        []
# 4                         F             ()  10490        []        []
# ...                     ...            ...    ...       ...       ...
# 1019        c1ccc(=O)[nH]c1             ()    472        []        []
# 1020             n1cnc(C)c1             ()    471        []        []
# 1021            NCc1ccccc1O             ()    471        []        []
# 1022              NCc1nccs1             ()    470        []        []
# 1023  c1ccnc(N(C)C2CCCC2)n1             ()    470        []        []
#
# [1024 rows x 9 columns]
