# %%
from math import sqrt
import pandas as pd
import numpy as np
import os
import torch
import torch.nn.functional as F
from rdkit import Chem
import matplotlib.pyplot as plt

from torch_geometric.loader import DataLoader
from torch_geometric.datasets import MoleculeNet
from torch_geometric.nn import global_mean_pool, global_max_pool
# %matplotlib inline

# %%
gpuid = 0
torch.cuda.set_device(gpuid)
print(torch.cuda.current_device())
# Out:
# 0

# %%
import sys
sys.path.insert(0, '/home/was966/Research/bidd-clsar/')

# %%
from clsar.dataset import LSSNS, HSSMS
from clsar.feature import Gen39AtomFeatures
from clsar.model.model import ACANet_PNA, get_deg, _fix_reproducibility,ACANet_GAT, ACANet_GCN, ACANet_GIN
from clsar.model.loss import ACALoss, get_best_cliff
_fix_reproducibility(42)

# %%
ACANET_MODEL = ACANet_GCN

# %%
def train(train_loader, model, optimizer, aca_loss):

    total_examples = 0
    total_loss =  0    
    total_tsm_loss = 0
    total_reg_loss = 0   
    n_triplets = []
    n_pos_triplets = []
    model.train()
    for i, data in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        predictions, embeddings = model(data.x.float(), data.edge_index, 
                                        data.edge_attr, data.batch)
        
        loss_out = aca_loss(labels = data.y, 
                            predictions = predictions,
                            embeddings = embeddings)
        loss, reg_loss, tsm_loss, n, n_pos = loss_out
        
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
        total_tsm_loss += float(tsm_loss) * data.num_graphs        
        total_reg_loss += float(reg_loss) * data.num_graphs        
        total_examples += data.num_graphs
        
        n_triplets.append(int(n))
        n_pos_triplets.append(int(n_pos))
        
    train_loss = total_loss / total_examples
    total_tsm_loss = total_tsm_loss / total_examples
    total_reg_loss = total_reg_loss / total_examples
    n_triplets = int(sum(n_triplets) / (i+1))
    n_pos_triplets = int(sum(n_pos_triplets) / (i+1))
    
    return train_loss, total_tsm_loss, total_reg_loss, n_triplets, n_pos_triplets

@torch.no_grad()
def test(test_loader, model, aca_loss):
    model.eval()
    total_examples = 0
    total_loss = 0
    total_tsm_loss = 0
    total_reg_loss = 0
    n_triplets = []
    n_pos_triplets = []
    mse = []
    for i, data in enumerate(test_loader):
        data = data.to(device)
        predictions, embeddings = model(data.x.float(), data.edge_index,
                                        data.edge_attr, data.batch)
        loss_out = aca_loss(labels=data.y,
                            predictions=predictions,
                            embeddings=embeddings)

        loss, reg_loss, tsm_loss, n, n_pos = loss_out

        total_loss += float(loss) * data.num_graphs
        total_tsm_loss += float(tsm_loss) * data.num_graphs
        total_reg_loss += float(reg_loss) * data.num_graphs
        total_examples += data.num_graphs

        n_triplets.append(int(n))
        n_pos_triplets.append(int(n_pos))

        mse.append(F.mse_loss(predictions, data.y, reduction='none').cpu())

    test_loss = total_loss / total_examples
    total_tsm_loss = total_tsm_loss / total_examples
    total_reg_loss = total_reg_loss / total_examples
    n_triplets = int(sum(n_triplets) / (i+1))
    n_pos_triplets = int(sum(n_pos_triplets) / (i+1))
    
    test_rmse = float(torch.cat(mse, dim=0).mean().sqrt())
    
    return test_loss, total_tsm_loss, total_reg_loss, n_triplets, n_pos_triplets, test_rmse



def Test_performance(alpha=1.0):
    
    model = ACANET_MODEL(**pub_args, aggr = 'mean').to(device)  
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=10**-5)
    aca_loss = ACALoss(alpha=alpha, cliff_lower = 1., cliff_upper = 1.)
    
    history = []
    #ls_his = []
    for epoch in range(1, epochs):
        train_loss, tsm_loss, reg_loss, n_triplets, n_pos_triplets = train(train_loader, model, optimizer, aca_loss)

        _, _, _, _, train_n_pos_triplets, train_rmse = test(train_loader, model, aca_loss)
        _, _, _, _, val_n_pos_triplets, val_rmse = test(val_loader, model, aca_loss)
        _, _, _, _, test_n_pos_triplets, test_rmse = test(test_loader, model, aca_loss)

        
        print(f'Epoch: {epoch:03d}, Loss: {train_loss:.4f} tsm_loss: {tsm_loss:.4f} reg_loss: {reg_loss:.4f} '
              f'n_pos_triplets: {n_pos_triplets:03d};  Val: {val_rmse:.4f} Test: {test_rmse:.4f}')
    
        history.append({'Epoch':epoch, 'train_loss':train_loss, 'train_triplet_loss':tsm_loss,'train_mae_loss':reg_loss,
                        'val_rmse':val_rmse, 'test_rmse':test_rmse, 'train_rmse':train_rmse,'n_triplets': n_triplets, 
                        'n_pos_triplets':n_pos_triplets, 
                        'train_n_pos_triplets':train_n_pos_triplets,
                        'val_n_pos_triplets':val_n_pos_triplets,
                        'test_n_pos_triplets':test_n_pos_triplets,
                       
                       })
        #ls_his.append({'Epoch':epoch, 'mae_loss':float(mae_loss), 'triplet_loss':float(triplet_loss)})
    dfh = pd.DataFrame(history)
    return dfh

# %%
dataset_name = 'CHEMBL3979_EC50'
Dataset =  HSSMS #LSSNS 
epochs = 800
batch_size = 128
lr = 1e-4

pre_transform = Gen39AtomFeatures()
in_channels = pre_transform.in_channels
path = '../data/'

## model HPs
pub_args = {'in_channels':pre_transform.in_channels, 
            'edge_dim':pre_transform.edge_dim,
            'convs_layers': [64, 128, 256, 512],   
            'dense_layers': [256, 128, 32], 
            'out_channels':1, 
            # 'aggregators': ['mean', 'min', 'max', 'sum','std'],
            # 'scalers':['identity', 'amplification', 'attenuation'] ,
            'dropout_p': 0}

# %%
len(Dataset(path, name=dataset_name, pre_transform=pre_transform).shuffle(42))
# Out:
# 1125

# %%
# train, valid, test splitting
res1 = []
res2 = []
for seed in [8, 16, 24, 42, 64, 128, 256, 512, 1024, 2048]:
    dataset = Dataset(path, name=dataset_name, pre_transform=pre_transform).shuffle(42)
    N = len(dataset) // 5
    val_dataset = dataset[:N]
    test_dataset = dataset[N:2 * N]
    train_dataset = dataset[2 * N:]
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    deg = get_deg(train_dataset)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # With AC-Awareness ($\alpha = 1$)
    df1 = Test_performance(alpha=1.0)
    df1['seed'] = seed
    # Without AC-Awareness ($\alpha = 0$)
    df2 = Test_performance(alpha=0.0)
    df2['seed'] = seed
    res1.append(df1)
    res2.append(df2)
# Out:
# /home/was966/micromamba/envs/responder/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /home/was966/micromamba/envs/responder/lib/python3.8/site-packages/torch_geometric/warnings.py:17: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# Epoch: 001, Loss: 11.2357 tsm_loss: 4.6409 reg_loss: 6.5948 n_pos_triplets: 226402;  Val: 6.0852 Test: 6.1176
# Epoch: 002, Loss: 9.8413 tsm_loss: 3.9363 reg_loss: 5.9050 n_pos_triplets: 228764;  Val: 5.7904 Test: 5.8164
# Epoch: 003, Loss: 8.5868 tsm_loss: 3.5585 reg_loss: 5.0283 n_pos_triplets: 228152;  Val: 5.1441 Test: 5.1747
# Epoch: 004, Loss: 7.0034 tsm_loss: 3.1436 reg_loss: 3.8598 n_pos_triplets: 225069;  Val: 4.0747 Test: 4.1084
# Epoch: 005, Loss: 5.1450 tsm_loss: 2.7784 reg_loss: 2.3667 n_pos_triplets: 225498;  Val: 2.4978 Test: 2.5298
# Epoch: 006, Loss: 3.7488 tsm_loss: 2.6598 reg_loss: 1.0891 n_pos_triplets: 226579;  Val: 1.1534 Test: 1.1106
# Epoch: 007, Loss: 3.7224 tsm_loss: 2.4534 reg_loss: 1.2690 n_pos_triplets: 221564;  Val: 1.0950 Test: 1.0300
# Epoch: 008, Loss: 3.2741 tsm_loss: 2.2764 reg_loss: 0.9977 n_pos_triplets: 219174;  Val: 1.1472 Test: 1.1154
# Epoch: 009, Loss: 3.0250 tsm_loss: 2.1026 reg_loss: 0.9224 n_pos_triplets: 217027;  Val: 1.2253 Test: 1.2039
# Epoch: 010, Loss: 2.8845 tsm_loss: 1.9830 reg_loss: 0.9015 n_pos_triplets: 218749;  Val: 1.0599 Test: 1.0232
# Epoch: 011, Loss: 2.6800 tsm_loss: 1.8562 reg_loss: 0.8239 n_pos_triplets: 213650;  Val: 0.9566 Test: 0.9019
# Epoch: 012, Loss: 2.6122 tsm_loss: 1.8097 reg_loss: 0.8025 n_pos_triplets: 213299;  Val: 0.9323 Test: 0.8764
# Epoch: 013, Loss: 2.4820 tsm_loss: 1.7135 reg_loss: 0.7685 n_pos_triplets: 209538;  Val: 0.9057 Test: 0.8599
# Epoch: 014, Loss: 2.3446 tsm_loss: 1.6104 reg_loss: 0.7342 n_pos_triplets: 205488;  Val: 0.8823 Test: 0.8370
# Epoch: 015, Loss: 2.2613 tsm_loss: 1.5528 reg_loss: 0.7085 n_pos_triplets: 203148;  Val: 0.8644 Test: 0.8186
# Epoch: 016, Loss: 2.1909 tsm_loss: 1.5044 reg_loss: 0.6865 n_pos_triplets: 199761;  Val: 0.8505 Test: 0.8081
# Epoch: 017, Loss: 2.1263 tsm_loss: 1.4663 reg_loss: 0.6600 n_pos_triplets: 196164;  Val: 0.8356 Test: 0.7890
# Epoch: 018, Loss: 2.0581 tsm_loss: 1.4071 reg_loss: 0.6510 n_pos_triplets: 191030;  Val: 0.8211 Test: 0.7783
# Epoch: 019, Loss: 2.0361 tsm_loss: 1.3964 reg_loss: 0.6397 n_pos_triplets: 192825;  Val: 0.8134 Test: 0.7755
# Epoch: 020, Loss: 1.9884 tsm_loss: 1.3778 reg_loss: 0.6105 n_pos_triplets: 188887;  Val: 0.8012 Test: 0.7610
# Epoch: 021, Loss: 1.9324 tsm_loss: 1.3229 reg_loss: 0.6095 n_pos_triplets: 187842;  Val: 0.7848 Test: 0.7503
# Epoch: 022, Loss: 1.8649 tsm_loss: 1.2734 reg_loss: 0.5914 n_pos_triplets: 187047;  Val: 0.7778 Test: 0.7496
# Epoch: 023, Loss: 1.8054 tsm_loss: 1.2256 reg_loss: 0.5799 n_pos_triplets: 183212;  Val: 0.7709 Test: 0.7410
# Epoch: 024, Loss: 1.8078 tsm_loss: 1.2361 reg_loss: 0.5717 n_pos_triplets: 183517;  Val: 0.7654 Test: 0.7383
# Epoch: 025, Loss: 1.7123 tsm_loss: 1.1584 reg_loss: 0.5539 n_pos_triplets: 178990;  Val: 0.7582 Test: 0.7295
# Epoch: 026, Loss: 1.7310 tsm_loss: 1.1798 reg_loss: 0.5512 n_pos_triplets: 181595;  Val: 0.7518 Test: 0.7272
# Epoch: 027, Loss: 1.6683 tsm_loss: 1.1311 reg_loss: 0.5372 n_pos_triplets: 178292;  Val: 0.7404 Test: 0.7236
# Epoch: 028, Loss: 1.6310 tsm_loss: 1.1072 reg_loss: 0.5238 n_pos_triplets: 175617;  Val: 0.7325 Test: 0.7177
# Epoch: 029, Loss: 1.6126 tsm_loss: 1.0870 reg_loss: 0.5255 n_pos_triplets: 174457;  Val: 0.7285 Test: 0.7159
# Epoch: 030, Loss: 1.5735 tsm_loss: 1.0629 reg_loss: 0.5106 n_pos_triplets: 175324;  Val: 0.7269 Test: 0.7133
# Epoch: 031, Loss: 1.5456 tsm_loss: 1.0421 reg_loss: 0.5035 n_pos_triplets: 174883;  Val: 0.7212 Test: 0.7121
# Epoch: 032, Loss: 1.5440 tsm_loss: 1.0281 reg_loss: 0.5159 n_pos_triplets: 171656;  Val: 0.7194 Test: 0.7136
# Epoch: 033, Loss: 1.4895 tsm_loss: 1.0002 reg_loss: 0.4893 n_pos_triplets: 171029;  Val: 0.7164 Test: 0.7053
# Epoch: 034, Loss: 1.4884 tsm_loss: 1.0016 reg_loss: 0.4868 n_pos_triplets: 171537;  Val: 0.7129 Test: 0.7100
# Epoch: 035, Loss: 1.4705 tsm_loss: 0.9780 reg_loss: 0.4925 n_pos_triplets: 169769;  Val: 0.7094 Test: 0.6977
# Epoch: 036, Loss: 1.4160 tsm_loss: 0.9490 reg_loss: 0.4670 n_pos_triplets: 168744;  Val: 0.7154 Test: 0.7124
# Epoch: 037, Loss: 1.3855 tsm_loss: 0.9171 reg_loss: 0.4684 n_pos_triplets: 163780;  Val: 0.7004 Test: 0.6892
# Epoch: 038, Loss: 1.3929 tsm_loss: 0.9349 reg_loss: 0.4579 n_pos_triplets: 168037;  Val: 0.6962 Test: 0.6966
# Epoch: 039, Loss: 1.3515 tsm_loss: 0.8982 reg_loss: 0.4533 n_pos_triplets: 165051;  Val: 0.6929 Test: 0.6901
# Epoch: 040, Loss: 1.3643 tsm_loss: 0.9059 reg_loss: 0.4583 n_pos_triplets: 164646;  Val: 0.6871 Test: 0.6887
# Epoch: 041, Loss: 1.3328 tsm_loss: 0.8842 reg_loss: 0.4485 n_pos_triplets: 165020;  Val: 0.6915 Test: 0.6856
# Epoch: 042, Loss: 1.3187 tsm_loss: 0.8614 reg_loss: 0.4573 n_pos_triplets: 165550;  Val: 0.6865 Test: 0.6868
# Epoch: 043, Loss: 1.2874 tsm_loss: 0.8571 reg_loss: 0.4303 n_pos_triplets: 162944;  Val: 0.6858 Test: 0.6853
# Epoch: 044, Loss: 1.2587 tsm_loss: 0.8265 reg_loss: 0.4322 n_pos_triplets: 159435;  Val: 0.6860 Test: 0.6851
# Epoch: 045, Loss: 1.2470 tsm_loss: 0.8200 reg_loss: 0.4270 n_pos_triplets: 157456;  Val: 0.6869 Test: 0.6835
# Epoch: 046, Loss: 1.2478 tsm_loss: 0.8146 reg_loss: 0.4331 n_pos_triplets: 158596;  Val: 0.6854 Test: 0.6762
# Epoch: 047, Loss: 1.2364 tsm_loss: 0.8013 reg_loss: 0.4351 n_pos_triplets: 158793;  Val: 0.6806 Test: 0.6807
# Epoch: 048, Loss: 1.2159 tsm_loss: 0.8009 reg_loss: 0.4150 n_pos_triplets: 156429;  Val: 0.6797 Test: 0.6787
# Epoch: 049, Loss: 1.2241 tsm_loss: 0.7841 reg_loss: 0.4400 n_pos_triplets: 156032;  Val: 0.6896 Test: 0.6767
# Epoch: 050, Loss: 1.1788 tsm_loss: 0.7491 reg_loss: 0.4296 n_pos_triplets: 152844;  Val: 0.6855 Test: 0.6853
# Epoch: 051, Loss: 1.1778 tsm_loss: 0.7593 reg_loss: 0.4185 n_pos_triplets: 153828;  Val: 0.6822 Test: 0.6749
# Epoch: 052, Loss: 1.1381 tsm_loss: 0.7400 reg_loss: 0.3981 n_pos_triplets: 151534;  Val: 0.6804 Test: 0.6753
# Epoch: 053, Loss: 1.1063 tsm_loss: 0.7124 reg_loss: 0.3939 n_pos_triplets: 148144;  Val: 0.6870 Test: 0.6734
# Epoch: 054, Loss: 1.1355 tsm_loss: 0.7290 reg_loss: 0.4065 n_pos_triplets: 149928;  Val: 0.6778 Test: 0.6785
# Epoch: 055, Loss: 1.1191 tsm_loss: 0.7276 reg_loss: 0.3915 n_pos_triplets: 150208;  Val: 0.6785 Test: 0.6703
# Epoch: 056, Loss: 1.1149 tsm_loss: 0.7182 reg_loss: 0.3967 n_pos_triplets: 150540;  Val: 0.6729 Test: 0.6716
# Epoch: 057, Loss: 1.0808 tsm_loss: 0.6996 reg_loss: 0.3812 n_pos_triplets: 150199;  Val: 0.6747 Test: 0.6729
# Epoch: 058, Loss: 1.0818 tsm_loss: 0.7026 reg_loss: 0.3792 n_pos_triplets: 152339;  Val: 0.6761 Test: 0.6683
# Epoch: 059, Loss: 1.0566 tsm_loss: 0.6809 reg_loss: 0.3757 n_pos_triplets: 148946;  Val: 0.6779 Test: 0.6776
# Epoch: 060, Loss: 1.0750 tsm_loss: 0.6929 reg_loss: 0.3822 n_pos_triplets: 148739;  Val: 0.6751 Test: 0.6646
# Epoch: 061, Loss: 1.0361 tsm_loss: 0.6638 reg_loss: 0.3723 n_pos_triplets: 145723;  Val: 0.6720 Test: 0.6684
# Epoch: 062, Loss: 1.0299 tsm_loss: 0.6584 reg_loss: 0.3715 n_pos_triplets: 145730;  Val: 0.6696 Test: 0.6657
# Epoch: 063, Loss: 1.0262 tsm_loss: 0.6587 reg_loss: 0.3675 n_pos_triplets: 145371;  Val: 0.6659 Test: 0.6641
# Epoch: 064, Loss: 1.0144 tsm_loss: 0.6494 reg_loss: 0.3650 n_pos_triplets: 143453;  Val: 0.6712 Test: 0.6593
# Epoch: 065, Loss: 1.0028 tsm_loss: 0.6394 reg_loss: 0.3634 n_pos_triplets: 144267;  Val: 0.6855 Test: 0.6889
# Epoch: 066, Loss: 1.0161 tsm_loss: 0.6330 reg_loss: 0.3831 n_pos_triplets: 146236;  Val: 0.6891 Test: 0.6723
# Epoch: 067, Loss: 1.0025 tsm_loss: 0.6286 reg_loss: 0.3739 n_pos_triplets: 144699;  Val: 0.6897 Test: 0.6921
# Epoch: 068, Loss: 0.9923 tsm_loss: 0.6207 reg_loss: 0.3716 n_pos_triplets: 141962;  Val: 0.6882 Test: 0.6745
# Epoch: 069, Loss: 0.9527 tsm_loss: 0.5992 reg_loss: 0.3535 n_pos_triplets: 137066;  Val: 0.6710 Test: 0.6680
# Epoch: 070, Loss: 0.9463 tsm_loss: 0.5981 reg_loss: 0.3482 n_pos_triplets: 142430;  Val: 0.6781 Test: 0.6666
# Epoch: 071, Loss: 0.9473 tsm_loss: 0.5922 reg_loss: 0.3551 n_pos_triplets: 141663;  Val: 0.6727 Test: 0.6791
# Epoch: 072, Loss: 0.9294 tsm_loss: 0.5818 reg_loss: 0.3476 n_pos_triplets: 136850;  Val: 0.6686 Test: 0.6620
# Epoch: 073, Loss: 0.9341 tsm_loss: 0.5897 reg_loss: 0.3444 n_pos_triplets: 138981;  Val: 0.6687 Test: 0.6636
# Epoch: 074, Loss: 0.9419 tsm_loss: 0.5924 reg_loss: 0.3494 n_pos_triplets: 135982;  Val: 0.6752 Test: 0.6565
# Epoch: 075, Loss: 0.9233 tsm_loss: 0.5770 reg_loss: 0.3463 n_pos_triplets: 139957;  Val: 0.6614 Test: 0.6586
# Epoch: 076, Loss: 0.9148 tsm_loss: 0.5805 reg_loss: 0.3343 n_pos_triplets: 138407;  Val: 0.6601 Test: 0.6525
# Epoch: 077, Loss: 0.8796 tsm_loss: 0.5523 reg_loss: 0.3274 n_pos_triplets: 137427;  Val: 0.6606 Test: 0.6556
# Epoch: 078, Loss: 0.9045 tsm_loss: 0.5686 reg_loss: 0.3359 n_pos_triplets: 136239;  Val: 0.6670 Test: 0.6549
# Epoch: 079, Loss: 0.8670 tsm_loss: 0.5450 reg_loss: 0.3220 n_pos_triplets: 134013;  Val: 0.6839 Test: 0.6829
# Epoch: 080, Loss: 0.8983 tsm_loss: 0.5470 reg_loss: 0.3512 n_pos_triplets: 135630;  Val: 0.6750 Test: 0.6592
# Epoch: 081, Loss: 0.8760 tsm_loss: 0.5384 reg_loss: 0.3376 n_pos_triplets: 135151;  Val: 0.7054 Test: 0.7103
# Epoch: 082, Loss: 0.8930 tsm_loss: 0.5216 reg_loss: 0.3714 n_pos_triplets: 133742;  Val: 0.7036 Test: 0.6873
# Epoch: 083, Loss: 0.9214 tsm_loss: 0.5543 reg_loss: 0.3671 n_pos_triplets: 136749;  Val: 0.6886 Test: 0.6961
# Epoch: 084, Loss: 0.8712 tsm_loss: 0.5289 reg_loss: 0.3424 n_pos_triplets: 126323;  Val: 0.6785 Test: 0.6674
# Epoch: 085, Loss: 0.8429 tsm_loss: 0.5082 reg_loss: 0.3348 n_pos_triplets: 128471;  Val: 0.6677 Test: 0.6704
# Epoch: 086, Loss: 0.8210 tsm_loss: 0.5025 reg_loss: 0.3185 n_pos_triplets: 128141;  Val: 0.6741 Test: 0.6655
# Epoch: 087, Loss: 0.8297 tsm_loss: 0.5028 reg_loss: 0.3269 n_pos_triplets: 130150;  Val: 0.6653 Test: 0.6654
# Epoch: 088, Loss: 0.8319 tsm_loss: 0.5083 reg_loss: 0.3235 n_pos_triplets: 127866;  Val: 0.6591 Test: 0.6478
# Epoch: 089, Loss: 0.8077 tsm_loss: 0.5067 reg_loss: 0.3011 n_pos_triplets: 130862;  Val: 0.6649 Test: 0.6611
# Epoch: 090, Loss: 0.8027 tsm_loss: 0.4980 reg_loss: 0.3047 n_pos_triplets: 129992;  Val: 0.6616 Test: 0.6488
# Epoch: 091, Loss: 0.7801 tsm_loss: 0.4821 reg_loss: 0.2980 n_pos_triplets: 124688;  Val: 0.6603 Test: 0.6528
# Epoch: 092, Loss: 0.7975 tsm_loss: 0.4973 reg_loss: 0.3002 n_pos_triplets: 129384;  Val: 0.6588 Test: 0.6464
# Epoch: 093, Loss: 0.7951 tsm_loss: 0.4881 reg_loss: 0.3070 n_pos_triplets: 127566;  Val: 0.6548 Test: 0.6460
# Epoch: 094, Loss: 0.7806 tsm_loss: 0.4846 reg_loss: 0.2961 n_pos_triplets: 125092;  Val: 0.6547 Test: 0.6390
# Epoch: 095, Loss: 0.7816 tsm_loss: 0.4824 reg_loss: 0.2992 n_pos_triplets: 123529;  Val: 0.6732 Test: 0.6515
# Epoch: 096, Loss: 0.8042 tsm_loss: 0.4904 reg_loss: 0.3138 n_pos_triplets: 125238;  Val: 0.6696 Test: 0.6655
# Epoch: 097, Loss: 0.7732 tsm_loss: 0.4775 reg_loss: 0.2957 n_pos_triplets: 123752;  Val: 0.6694 Test: 0.6540
# Epoch: 098, Loss: 0.7697 tsm_loss: 0.4769 reg_loss: 0.2928 n_pos_triplets: 121920;  Val: 0.6800 Test: 0.6778
# Epoch: 099, Loss: 0.7719 tsm_loss: 0.4562 reg_loss: 0.3157 n_pos_triplets: 121816;  Val: 0.6658 Test: 0.6522
# Epoch: 100, Loss: 0.7502 tsm_loss: 0.4597 reg_loss: 0.2905 n_pos_triplets: 124189;  Val: 0.6543 Test: 0.6535
# Epoch: 101, Loss: 0.7578 tsm_loss: 0.4627 reg_loss: 0.2951 n_pos_triplets: 121819;  Val: 0.6635 Test: 0.6522
# Epoch: 102, Loss: 0.7411 tsm_loss: 0.4541 reg_loss: 0.2870 n_pos_triplets: 121734;  Val: 0.6541 Test: 0.6541
# Epoch: 103, Loss: 0.7415 tsm_loss: 0.4464 reg_loss: 0.2951 n_pos_triplets: 118272;  Val: 0.6511 Test: 0.6480
# Epoch: 104, Loss: 0.7193 tsm_loss: 0.4420 reg_loss: 0.2773 n_pos_triplets: 122031;  Val: 0.6505 Test: 0.6452
# Epoch: 105, Loss: 0.7260 tsm_loss: 0.4552 reg_loss: 0.2708 n_pos_triplets: 121446;  Val: 0.6502 Test: 0.6489
# Epoch: 106, Loss: 0.7004 tsm_loss: 0.4333 reg_loss: 0.2671 n_pos_triplets: 119805;  Val: 0.6596 Test: 0.6477
# Epoch: 107, Loss: 0.7337 tsm_loss: 0.4368 reg_loss: 0.2969 n_pos_triplets: 120009;  Val: 0.6446 Test: 0.6398
# Epoch: 108, Loss: 0.6873 tsm_loss: 0.4178 reg_loss: 0.2695 n_pos_triplets: 119332;  Val: 0.6472 Test: 0.6443
# Epoch: 109, Loss: 0.6782 tsm_loss: 0.4191 reg_loss: 0.2591 n_pos_triplets: 116661;  Val: 0.6451 Test: 0.6400
# Epoch: 110, Loss: 0.7097 tsm_loss: 0.4225 reg_loss: 0.2872 n_pos_triplets: 115707;  Val: 0.6464 Test: 0.6426
# Epoch: 111, Loss: 0.6784 tsm_loss: 0.4182 reg_loss: 0.2602 n_pos_triplets: 115829;  Val: 0.6514 Test: 0.6395
# Epoch: 112, Loss: 0.6901 tsm_loss: 0.4118 reg_loss: 0.2784 n_pos_triplets: 114432;  Val: 0.6498 Test: 0.6379
# Epoch: 113, Loss: 0.6907 tsm_loss: 0.4235 reg_loss: 0.2672 n_pos_triplets: 117525;  Val: 0.6519 Test: 0.6425
# Epoch: 114, Loss: 0.6688 tsm_loss: 0.4036 reg_loss: 0.2652 n_pos_triplets: 112625;  Val: 0.6436 Test: 0.6393
# Epoch: 115, Loss: 0.6711 tsm_loss: 0.4153 reg_loss: 0.2558 n_pos_triplets: 115885;  Val: 0.6481 Test: 0.6449
# Epoch: 116, Loss: 0.7322 tsm_loss: 0.4205 reg_loss: 0.3117 n_pos_triplets: 115443;  Val: 0.6900 Test: 0.6919
# Epoch: 117, Loss: 0.7295 tsm_loss: 0.4082 reg_loss: 0.3212 n_pos_triplets: 112946;  Val: 0.6737 Test: 0.6578
# Epoch: 118, Loss: 0.7019 tsm_loss: 0.4136 reg_loss: 0.2883 n_pos_triplets: 113492;  Val: 0.6450 Test: 0.6429
# Epoch: 119, Loss: 0.6814 tsm_loss: 0.4113 reg_loss: 0.2701 n_pos_triplets: 116597;  Val: 0.6555 Test: 0.6460
# Epoch: 120, Loss: 0.6518 tsm_loss: 0.3853 reg_loss: 0.2665 n_pos_triplets: 111615;  Val: 0.6866 Test: 0.6865
# Epoch: 121, Loss: 0.7094 tsm_loss: 0.4013 reg_loss: 0.3082 n_pos_triplets: 111867;  Val: 0.6726 Test: 0.6603
# Epoch: 122, Loss: 0.6511 tsm_loss: 0.3847 reg_loss: 0.2664 n_pos_triplets: 111708;  Val: 0.6884 Test: 0.6945
# Epoch: 123, Loss: 0.6782 tsm_loss: 0.3862 reg_loss: 0.2920 n_pos_triplets: 112761;  Val: 0.6503 Test: 0.6407
# Epoch: 124, Loss: 0.6786 tsm_loss: 0.3837 reg_loss: 0.2948 n_pos_triplets: 111986;  Val: 0.6421 Test: 0.6381
# Epoch: 125, Loss: 0.6364 tsm_loss: 0.3834 reg_loss: 0.2529 n_pos_triplets: 110701;  Val: 0.6625 Test: 0.6510
# Epoch: 126, Loss: 0.6247 tsm_loss: 0.3687 reg_loss: 0.2559 n_pos_triplets: 110219;  Val: 0.6596 Test: 0.6599
# Epoch: 127, Loss: 0.6554 tsm_loss: 0.3803 reg_loss: 0.2750 n_pos_triplets: 108680;  Val: 0.6461 Test: 0.6346
# Epoch: 128, Loss: 0.6151 tsm_loss: 0.3693 reg_loss: 0.2458 n_pos_triplets: 108097;  Val: 0.6438 Test: 0.6380
# Epoch: 129, Loss: 0.6364 tsm_loss: 0.3585 reg_loss: 0.2779 n_pos_triplets: 106269;  Val: 0.6591 Test: 0.6561
# Epoch: 130, Loss: 0.6634 tsm_loss: 0.3664 reg_loss: 0.2971 n_pos_triplets: 106912;  Val: 0.6662 Test: 0.6516
# Epoch: 131, Loss: 0.6330 tsm_loss: 0.3685 reg_loss: 0.2645 n_pos_triplets: 108144;  Val: 0.6913 Test: 0.6950
# Epoch: 132, Loss: 0.6462 tsm_loss: 0.3510 reg_loss: 0.2952 n_pos_triplets: 105236;  Val: 0.6607 Test: 0.6471
# Epoch: 133, Loss: 0.6238 tsm_loss: 0.3601 reg_loss: 0.2638 n_pos_triplets: 105621;  Val: 0.6457 Test: 0.6416
# Epoch: 134, Loss: 0.5876 tsm_loss: 0.3552 reg_loss: 0.2324 n_pos_triplets: 104769;  Val: 0.6426 Test: 0.6381
# Epoch: 135, Loss: 0.5848 tsm_loss: 0.3536 reg_loss: 0.2311 n_pos_triplets: 102589;  Val: 0.6391 Test: 0.6407
# Epoch: 136, Loss: 0.6147 tsm_loss: 0.3702 reg_loss: 0.2445 n_pos_triplets: 108186;  Val: 0.6452 Test: 0.6500
# Epoch: 137, Loss: 0.6087 tsm_loss: 0.3636 reg_loss: 0.2451 n_pos_triplets: 105566;  Val: 0.6456 Test: 0.6379
# Epoch: 138, Loss: 0.5815 tsm_loss: 0.3550 reg_loss: 0.2266 n_pos_triplets: 105466;  Val: 0.6484 Test: 0.6367
# Epoch: 139, Loss: 0.5627 tsm_loss: 0.3331 reg_loss: 0.2296 n_pos_triplets: 102909;  Val: 0.6603 Test: 0.6448
# Epoch: 140, Loss: 0.6133 tsm_loss: 0.3518 reg_loss: 0.2615 n_pos_triplets: 103281;  Val: 0.6462 Test: 0.6346
# Epoch: 141, Loss: 0.5604 tsm_loss: 0.3365 reg_loss: 0.2239 n_pos_triplets: 101940;  Val: 0.6437 Test: 0.6326
# Epoch: 142, Loss: 0.5798 tsm_loss: 0.3401 reg_loss: 0.2397 n_pos_triplets: 103369;  Val: 0.6547 Test: 0.6498
# Epoch: 143, Loss: 0.5903 tsm_loss: 0.3405 reg_loss: 0.2498 n_pos_triplets: 103025;  Val: 0.6408 Test: 0.6278
# Epoch: 144, Loss: 0.5653 tsm_loss: 0.3290 reg_loss: 0.2363 n_pos_triplets: 102930;  Val: 0.6381 Test: 0.6283
# Epoch: 145, Loss: 0.5898 tsm_loss: 0.3421 reg_loss: 0.2477 n_pos_triplets: 101653;  Val: 0.6578 Test: 0.6561
# Epoch: 146, Loss: 0.5851 tsm_loss: 0.3301 reg_loss: 0.2550 n_pos_triplets: 100104;  Val: 0.6458 Test: 0.6418
# Epoch: 147, Loss: 0.5484 tsm_loss: 0.3298 reg_loss: 0.2186 n_pos_triplets: 102418;  Val: 0.6470 Test: 0.6362
# Epoch: 148, Loss: 0.5604 tsm_loss: 0.3277 reg_loss: 0.2327 n_pos_triplets: 100717;  Val: 0.6393 Test: 0.6355
# Epoch: 149, Loss: 0.5298 tsm_loss: 0.3159 reg_loss: 0.2139 n_pos_triplets: 99303;  Val: 0.6395 Test: 0.6449
# Epoch: 150, Loss: 0.5376 tsm_loss: 0.3198 reg_loss: 0.2179 n_pos_triplets: 100064;  Val: 0.6387 Test: 0.6373
# Epoch: 151, Loss: 0.5442 tsm_loss: 0.3214 reg_loss: 0.2228 n_pos_triplets: 97841;  Val: 0.6480 Test: 0.6453
# Epoch: 152, Loss: 0.5257 tsm_loss: 0.3062 reg_loss: 0.2194 n_pos_triplets: 93530;  Val: 0.6358 Test: 0.6309
# Epoch: 153, Loss: 0.5231 tsm_loss: 0.3197 reg_loss: 0.2034 n_pos_triplets: 100481;  Val: 0.6381 Test: 0.6400
# Epoch: 154, Loss: 0.5273 tsm_loss: 0.3125 reg_loss: 0.2148 n_pos_triplets: 97608;  Val: 0.6408 Test: 0.6413
# Epoch: 155, Loss: 0.5311 tsm_loss: 0.3173 reg_loss: 0.2138 n_pos_triplets: 101005;  Val: 0.6350 Test: 0.6358
# Epoch: 156, Loss: 0.5228 tsm_loss: 0.3063 reg_loss: 0.2165 n_pos_triplets: 99071;  Val: 0.6310 Test: 0.6325
# Epoch: 157, Loss: 0.4995 tsm_loss: 0.3030 reg_loss: 0.1965 n_pos_triplets: 95384;  Val: 0.6372 Test: 0.6367
# Epoch: 158, Loss: 0.5284 tsm_loss: 0.3070 reg_loss: 0.2213 n_pos_triplets: 96076;  Val: 0.6351 Test: 0.6331
# Epoch: 159, Loss: 0.4967 tsm_loss: 0.2951 reg_loss: 0.2016 n_pos_triplets: 95956;  Val: 0.6368 Test: 0.6403
# Epoch: 160, Loss: 0.5252 tsm_loss: 0.3081 reg_loss: 0.2171 n_pos_triplets: 95772;  Val: 0.6638 Test: 0.6504
# Epoch: 161, Loss: 0.5358 tsm_loss: 0.2929 reg_loss: 0.2428 n_pos_triplets: 94743;  Val: 0.6434 Test: 0.6417
# Epoch: 162, Loss: 0.5165 tsm_loss: 0.3023 reg_loss: 0.2142 n_pos_triplets: 97462;  Val: 0.6347 Test: 0.6327
# Epoch: 163, Loss: 0.5401 tsm_loss: 0.2964 reg_loss: 0.2437 n_pos_triplets: 95178;  Val: 0.6423 Test: 0.6342
# Epoch: 164, Loss: 0.5440 tsm_loss: 0.3056 reg_loss: 0.2384 n_pos_triplets: 95711;  Val: 0.6439 Test: 0.6347
# Epoch: 165, Loss: 0.5350 tsm_loss: 0.2913 reg_loss: 0.2437 n_pos_triplets: 90921;  Val: 0.6592 Test: 0.6640
# Epoch: 166, Loss: 0.5202 tsm_loss: 0.2886 reg_loss: 0.2316 n_pos_triplets: 91959;  Val: 0.6386 Test: 0.6223
# Epoch: 167, Loss: 0.4887 tsm_loss: 0.2837 reg_loss: 0.2051 n_pos_triplets: 89575;  Val: 0.6357 Test: 0.6248
# Epoch: 168, Loss: 0.4853 tsm_loss: 0.2868 reg_loss: 0.1984 n_pos_triplets: 90968;  Val: 0.6357 Test: 0.6283
# Epoch: 169, Loss: 0.4797 tsm_loss: 0.2778 reg_loss: 0.2018 n_pos_triplets: 91255;  Val: 0.6467 Test: 0.6311
# Epoch: 170, Loss: 0.4783 tsm_loss: 0.2777 reg_loss: 0.2006 n_pos_triplets: 88286;  Val: 0.6454 Test: 0.6414
# Epoch: 171, Loss: 0.4783 tsm_loss: 0.2851 reg_loss: 0.1932 n_pos_triplets: 92721;  Val: 0.6428 Test: 0.6329
# Epoch: 172, Loss: 0.4723 tsm_loss: 0.2665 reg_loss: 0.2058 n_pos_triplets: 89139;  Val: 0.6424 Test: 0.6307
# Epoch: 173, Loss: 0.4732 tsm_loss: 0.2798 reg_loss: 0.1934 n_pos_triplets: 88293;  Val: 0.6396 Test: 0.6310
# Epoch: 174, Loss: 0.4793 tsm_loss: 0.2781 reg_loss: 0.2012 n_pos_triplets: 88758;  Val: 0.6476 Test: 0.6450
# Epoch: 175, Loss: 0.4787 tsm_loss: 0.2883 reg_loss: 0.1904 n_pos_triplets: 89891;  Val: 0.6393 Test: 0.6295
# Epoch: 176, Loss: 0.4352 tsm_loss: 0.2539 reg_loss: 0.1813 n_pos_triplets: 87080;  Val: 0.6439 Test: 0.6416
# Epoch: 177, Loss: 0.4893 tsm_loss: 0.2655 reg_loss: 0.2237 n_pos_triplets: 89868;  Val: 0.6687 Test: 0.6524
# Epoch: 178, Loss: 0.4788 tsm_loss: 0.2629 reg_loss: 0.2159 n_pos_triplets: 87827;  Val: 0.6373 Test: 0.6263
# Epoch: 179, Loss: 0.4829 tsm_loss: 0.2621 reg_loss: 0.2208 n_pos_triplets: 85650;  Val: 0.6392 Test: 0.6235
# Epoch: 180, Loss: 0.4499 tsm_loss: 0.2654 reg_loss: 0.1845 n_pos_triplets: 88566;  Val: 0.6400 Test: 0.6285
# Epoch: 181, Loss: 0.4728 tsm_loss: 0.2745 reg_loss: 0.1984 n_pos_triplets: 87670;  Val: 0.6468 Test: 0.6395
# Epoch: 182, Loss: 0.4345 tsm_loss: 0.2572 reg_loss: 0.1773 n_pos_triplets: 84554;  Val: 0.6362 Test: 0.6231
# Epoch: 183, Loss: 0.4321 tsm_loss: 0.2518 reg_loss: 0.1803 n_pos_triplets: 83351;  Val: 0.6491 Test: 0.6356
# Epoch: 184, Loss: 0.4878 tsm_loss: 0.2544 reg_loss: 0.2333 n_pos_triplets: 84510;  Val: 0.6726 Test: 0.6706
# Epoch: 185, Loss: 0.4881 tsm_loss: 0.2546 reg_loss: 0.2335 n_pos_triplets: 85800;  Val: 0.6480 Test: 0.6324
# Epoch: 186, Loss: 0.4393 tsm_loss: 0.2512 reg_loss: 0.1881 n_pos_triplets: 82858;  Val: 0.6471 Test: 0.6409
# Epoch: 187, Loss: 0.4290 tsm_loss: 0.2381 reg_loss: 0.1910 n_pos_triplets: 79815;  Val: 0.6416 Test: 0.6240
# Epoch: 188, Loss: 0.4345 tsm_loss: 0.2448 reg_loss: 0.1897 n_pos_triplets: 79055;  Val: 0.6469 Test: 0.6287
# Epoch: 189, Loss: 0.4424 tsm_loss: 0.2521 reg_loss: 0.1903 n_pos_triplets: 81408;  Val: 0.6405 Test: 0.6264
# Epoch: 190, Loss: 0.4355 tsm_loss: 0.2533 reg_loss: 0.1822 n_pos_triplets: 82400;  Val: 0.6358 Test: 0.6265
# Epoch: 191, Loss: 0.4229 tsm_loss: 0.2424 reg_loss: 0.1805 n_pos_triplets: 83234;  Val: 0.6362 Test: 0.6278
# Epoch: 192, Loss: 0.4433 tsm_loss: 0.2475 reg_loss: 0.1958 n_pos_triplets: 82827;  Val: 0.6391 Test: 0.6201
# Epoch: 193, Loss: 0.4244 tsm_loss: 0.2528 reg_loss: 0.1716 n_pos_triplets: 82761;  Val: 0.6442 Test: 0.6279
# Epoch: 194, Loss: 0.4243 tsm_loss: 0.2512 reg_loss: 0.1731 n_pos_triplets: 82963;  Val: 0.6378 Test: 0.6212
# Epoch: 195, Loss: 0.4359 tsm_loss: 0.2530 reg_loss: 0.1830 n_pos_triplets: 84276;  Val: 0.6353 Test: 0.6190
# Epoch: 196, Loss: 0.4329 tsm_loss: 0.2365 reg_loss: 0.1964 n_pos_triplets: 81582;  Val: 0.6450 Test: 0.6306
# Epoch: 197, Loss: 0.4231 tsm_loss: 0.2287 reg_loss: 0.1944 n_pos_triplets: 77693;  Val: 0.6385 Test: 0.6184
# Epoch: 198, Loss: 0.4184 tsm_loss: 0.2310 reg_loss: 0.1874 n_pos_triplets: 79383;  Val: 0.6379 Test: 0.6240
# Epoch: 199, Loss: 0.4466 tsm_loss: 0.2339 reg_loss: 0.2127 n_pos_triplets: 78548;  Val: 0.6416 Test: 0.6335
# Epoch: 200, Loss: 0.4238 tsm_loss: 0.2310 reg_loss: 0.1928 n_pos_triplets: 77588;  Val: 0.6361 Test: 0.6273
# Epoch: 201, Loss: 0.4200 tsm_loss: 0.2255 reg_loss: 0.1945 n_pos_triplets: 76434;  Val: 0.6372 Test: 0.6246
# Epoch: 202, Loss: 0.4405 tsm_loss: 0.2438 reg_loss: 0.1967 n_pos_triplets: 79867;  Val: 0.6386 Test: 0.6248
# Epoch: 203, Loss: 0.4356 tsm_loss: 0.2337 reg_loss: 0.2019 n_pos_triplets: 77141;  Val: 0.6431 Test: 0.6154
# Epoch: 204, Loss: 0.4048 tsm_loss: 0.2343 reg_loss: 0.1705 n_pos_triplets: 78819;  Val: 0.6444 Test: 0.6281
# Epoch: 205, Loss: 0.4002 tsm_loss: 0.2197 reg_loss: 0.1806 n_pos_triplets: 75324;  Val: 0.6347 Test: 0.6195
# Epoch: 206, Loss: 0.3810 tsm_loss: 0.2259 reg_loss: 0.1550 n_pos_triplets: 78011;  Val: 0.6377 Test: 0.6301
# Epoch: 207, Loss: 0.3774 tsm_loss: 0.2164 reg_loss: 0.1610 n_pos_triplets: 75032;  Val: 0.6402 Test: 0.6274
# Epoch: 208, Loss: 0.3657 tsm_loss: 0.2137 reg_loss: 0.1519 n_pos_triplets: 74488;  Val: 0.6428 Test: 0.6266
# Epoch: 209, Loss: 0.3765 tsm_loss: 0.2161 reg_loss: 0.1603 n_pos_triplets: 75722;  Val: 0.6370 Test: 0.6228
# Epoch: 210, Loss: 0.3768 tsm_loss: 0.2159 reg_loss: 0.1610 n_pos_triplets: 75276;  Val: 0.6400 Test: 0.6348
# Epoch: 211, Loss: 0.3865 tsm_loss: 0.2195 reg_loss: 0.1670 n_pos_triplets: 76559;  Val: 0.6331 Test: 0.6187
# Epoch: 212, Loss: 0.3671 tsm_loss: 0.2105 reg_loss: 0.1566 n_pos_triplets: 71591;  Val: 0.6358 Test: 0.6150
# Epoch: 213, Loss: 0.3771 tsm_loss: 0.2000 reg_loss: 0.1771 n_pos_triplets: 73152;  Val: 0.6340 Test: 0.6181
# Epoch: 214, Loss: 0.4079 tsm_loss: 0.2152 reg_loss: 0.1927 n_pos_triplets: 75708;  Val: 0.6596 Test: 0.6520
# Epoch: 215, Loss: 0.3927 tsm_loss: 0.2083 reg_loss: 0.1844 n_pos_triplets: 74762;  Val: 0.6434 Test: 0.6163
# Epoch: 216, Loss: 0.3540 tsm_loss: 0.2074 reg_loss: 0.1466 n_pos_triplets: 71747;  Val: 0.6485 Test: 0.6379
# Epoch: 217, Loss: 0.3870 tsm_loss: 0.2046 reg_loss: 0.1824 n_pos_triplets: 73441;  Val: 0.6332 Test: 0.6225
# Epoch: 218, Loss: 0.4474 tsm_loss: 0.2094 reg_loss: 0.2380 n_pos_triplets: 73983;  Val: 0.6486 Test: 0.6320
# Epoch: 219, Loss: 0.4134 tsm_loss: 0.2077 reg_loss: 0.2057 n_pos_triplets: 73940;  Val: 0.6945 Test: 0.6885
# Epoch: 220, Loss: 0.4369 tsm_loss: 0.2205 reg_loss: 0.2164 n_pos_triplets: 77565;  Val: 0.6546 Test: 0.6279
# Epoch: 221, Loss: 0.4204 tsm_loss: 0.2057 reg_loss: 0.2147 n_pos_triplets: 69589;  Val: 0.6848 Test: 0.6839
# Epoch: 222, Loss: 0.4753 tsm_loss: 0.2120 reg_loss: 0.2633 n_pos_triplets: 73427;  Val: 0.6352 Test: 0.6254
# Epoch: 223, Loss: 0.3949 tsm_loss: 0.1924 reg_loss: 0.2026 n_pos_triplets: 66892;  Val: 0.6319 Test: 0.6202
# Epoch: 224, Loss: 0.3742 tsm_loss: 0.1978 reg_loss: 0.1763 n_pos_triplets: 68432;  Val: 0.6481 Test: 0.6406
# Epoch: 225, Loss: 0.3713 tsm_loss: 0.2085 reg_loss: 0.1628 n_pos_triplets: 70958;  Val: 0.6524 Test: 0.6249
# Epoch: 226, Loss: 0.4095 tsm_loss: 0.2015 reg_loss: 0.2079 n_pos_triplets: 71291;  Val: 0.6459 Test: 0.6332
# Epoch: 227, Loss: 0.3836 tsm_loss: 0.2035 reg_loss: 0.1801 n_pos_triplets: 71547;  Val: 0.6339 Test: 0.6248
# Epoch: 228, Loss: 0.3834 tsm_loss: 0.1953 reg_loss: 0.1881 n_pos_triplets: 70225;  Val: 0.6436 Test: 0.6297
# Epoch: 229, Loss: 0.4120 tsm_loss: 0.2043 reg_loss: 0.2076 n_pos_triplets: 68875;  Val: 0.6770 Test: 0.6703
# Epoch: 230, Loss: 0.3999 tsm_loss: 0.1988 reg_loss: 0.2011 n_pos_triplets: 71429;  Val: 0.6570 Test: 0.6322
# Epoch: 231, Loss: 0.3954 tsm_loss: 0.1994 reg_loss: 0.1961 n_pos_triplets: 69541;  Val: 0.6560 Test: 0.6499
# Epoch: 232, Loss: 0.3668 tsm_loss: 0.1994 reg_loss: 0.1674 n_pos_triplets: 71168;  Val: 0.6310 Test: 0.6118
# Epoch: 233, Loss: 0.3490 tsm_loss: 0.1894 reg_loss: 0.1596 n_pos_triplets: 68956;  Val: 0.6439 Test: 0.6138
# Epoch: 234, Loss: 0.3770 tsm_loss: 0.1982 reg_loss: 0.1788 n_pos_triplets: 71147;  Val: 0.6597 Test: 0.6503
# Epoch: 235, Loss: 0.3590 tsm_loss: 0.1956 reg_loss: 0.1634 n_pos_triplets: 69499;  Val: 0.6424 Test: 0.6213
# Epoch: 236, Loss: 0.4010 tsm_loss: 0.1806 reg_loss: 0.2203 n_pos_triplets: 66092;  Val: 0.6453 Test: 0.6389
# Epoch: 237, Loss: 0.3550 tsm_loss: 0.1958 reg_loss: 0.1592 n_pos_triplets: 69391;  Val: 0.6317 Test: 0.6124
# Epoch: 238, Loss: 0.3574 tsm_loss: 0.1819 reg_loss: 0.1755 n_pos_triplets: 64825;  Val: 0.6384 Test: 0.6174
# Epoch: 239, Loss: 0.3614 tsm_loss: 0.1892 reg_loss: 0.1722 n_pos_triplets: 65180;  Val: 0.6579 Test: 0.6549
# Epoch: 240, Loss: 0.3504 tsm_loss: 0.1916 reg_loss: 0.1588 n_pos_triplets: 67734;  Val: 0.6381 Test: 0.6240
# Epoch: 241, Loss: 0.3273 tsm_loss: 0.1821 reg_loss: 0.1452 n_pos_triplets: 66382;  Val: 0.6381 Test: 0.6296
# Epoch: 242, Loss: 0.3434 tsm_loss: 0.1859 reg_loss: 0.1575 n_pos_triplets: 67905;  Val: 0.6384 Test: 0.6270
# Epoch: 243, Loss: 0.3506 tsm_loss: 0.1812 reg_loss: 0.1694 n_pos_triplets: 66117;  Val: 0.6349 Test: 0.6191
# Epoch: 244, Loss: 0.3248 tsm_loss: 0.1766 reg_loss: 0.1481 n_pos_triplets: 63316;  Val: 0.6361 Test: 0.6282
# Epoch: 245, Loss: 0.3287 tsm_loss: 0.1851 reg_loss: 0.1436 n_pos_triplets: 64217;  Val: 0.6647 Test: 0.6617
# Epoch: 246, Loss: 0.3758 tsm_loss: 0.1768 reg_loss: 0.1990 n_pos_triplets: 64141;  Val: 0.6360 Test: 0.6109
# Epoch: 247, Loss: 0.3848 tsm_loss: 0.1892 reg_loss: 0.1956 n_pos_triplets: 68366;  Val: 0.6420 Test: 0.6285
# Epoch: 248, Loss: 0.3426 tsm_loss: 0.1817 reg_loss: 0.1609 n_pos_triplets: 64616;  Val: 0.6322 Test: 0.6182
# Epoch: 249, Loss: 0.3649 tsm_loss: 0.1825 reg_loss: 0.1824 n_pos_triplets: 66686;  Val: 0.6366 Test: 0.6200
# Epoch: 250, Loss: 0.3169 tsm_loss: 0.1742 reg_loss: 0.1427 n_pos_triplets: 65577;  Val: 0.6340 Test: 0.6158
# Epoch: 251, Loss: 0.3223 tsm_loss: 0.1713 reg_loss: 0.1510 n_pos_triplets: 61125;  Val: 0.6406 Test: 0.6248
# Epoch: 252, Loss: 0.3436 tsm_loss: 0.1822 reg_loss: 0.1613 n_pos_triplets: 67378;  Val: 0.6309 Test: 0.6176
# Epoch: 253, Loss: 0.3128 tsm_loss: 0.1824 reg_loss: 0.1305 n_pos_triplets: 67427;  Val: 0.6402 Test: 0.6293
# Epoch: 254, Loss: 0.3219 tsm_loss: 0.1781 reg_loss: 0.1438 n_pos_triplets: 65850;  Val: 0.6343 Test: 0.6150
# Epoch: 255, Loss: 0.3147 tsm_loss: 0.1718 reg_loss: 0.1429 n_pos_triplets: 62115;  Val: 0.6354 Test: 0.6194
# Epoch: 256, Loss: 0.2926 tsm_loss: 0.1652 reg_loss: 0.1274 n_pos_triplets: 63867;  Val: 0.6347 Test: 0.6170
# Epoch: 257, Loss: 0.3015 tsm_loss: 0.1705 reg_loss: 0.1310 n_pos_triplets: 63453;  Val: 0.6308 Test: 0.6129
# Epoch: 258, Loss: 0.3228 tsm_loss: 0.1755 reg_loss: 0.1473 n_pos_triplets: 61151;  Val: 0.6341 Test: 0.6206
# Epoch: 259, Loss: 0.3669 tsm_loss: 0.1800 reg_loss: 0.1869 n_pos_triplets: 66139;  Val: 0.6493 Test: 0.6407
# Epoch: 260, Loss: 0.3773 tsm_loss: 0.1709 reg_loss: 0.2064 n_pos_triplets: 62457;  Val: 0.6399 Test: 0.6171
# Epoch: 261, Loss: 0.3280 tsm_loss: 0.1669 reg_loss: 0.1611 n_pos_triplets: 61396;  Val: 0.6339 Test: 0.6162
# Epoch: 262, Loss: 0.3470 tsm_loss: 0.1795 reg_loss: 0.1674 n_pos_triplets: 64892;  Val: 0.6590 Test: 0.6568
# Epoch: 263, Loss: 0.3401 tsm_loss: 0.1749 reg_loss: 0.1651 n_pos_triplets: 65439;  Val: 0.6364 Test: 0.6112
# Epoch: 264, Loss: 0.3150 tsm_loss: 0.1746 reg_loss: 0.1404 n_pos_triplets: 64382;  Val: 0.6379 Test: 0.6212
# Epoch: 265, Loss: 0.3147 tsm_loss: 0.1611 reg_loss: 0.1536 n_pos_triplets: 60892;  Val: 0.6307 Test: 0.6194
# Epoch: 266, Loss: 0.2945 tsm_loss: 0.1613 reg_loss: 0.1332 n_pos_triplets: 61848;  Val: 0.6311 Test: 0.6125
# Epoch: 267, Loss: 0.2907 tsm_loss: 0.1582 reg_loss: 0.1325 n_pos_triplets: 60643;  Val: 0.6314 Test: 0.6103
# Epoch: 268, Loss: 0.2854 tsm_loss: 0.1611 reg_loss: 0.1243 n_pos_triplets: 61109;  Val: 0.6309 Test: 0.6147
# Epoch: 269, Loss: 0.2995 tsm_loss: 0.1681 reg_loss: 0.1314 n_pos_triplets: 60663;  Val: 0.6473 Test: 0.6320
# Epoch: 270, Loss: 0.2887 tsm_loss: 0.1571 reg_loss: 0.1316 n_pos_triplets: 59045;  Val: 0.6401 Test: 0.6135
# Epoch: 271, Loss: 0.3069 tsm_loss: 0.1615 reg_loss: 0.1454 n_pos_triplets: 61288;  Val: 0.6376 Test: 0.6261
# Epoch: 272, Loss: 0.2990 tsm_loss: 0.1679 reg_loss: 0.1311 n_pos_triplets: 60772;  Val: 0.6321 Test: 0.6157
# Epoch: 273, Loss: 0.2883 tsm_loss: 0.1615 reg_loss: 0.1267 n_pos_triplets: 60532;  Val: 0.6278 Test: 0.6090
# Epoch: 274, Loss: 0.3254 tsm_loss: 0.1768 reg_loss: 0.1486 n_pos_triplets: 63317;  Val: 0.6279 Test: 0.6163
# Epoch: 275, Loss: 0.3179 tsm_loss: 0.1695 reg_loss: 0.1484 n_pos_triplets: 61092;  Val: 0.6300 Test: 0.6161
# Epoch: 276, Loss: 0.2965 tsm_loss: 0.1629 reg_loss: 0.1335 n_pos_triplets: 59711;  Val: 0.6279 Test: 0.6247
# Epoch: 277, Loss: 0.3049 tsm_loss: 0.1715 reg_loss: 0.1334 n_pos_triplets: 62917;  Val: 0.6341 Test: 0.6229
# Epoch: 278, Loss: 0.3016 tsm_loss: 0.1551 reg_loss: 0.1465 n_pos_triplets: 57876;  Val: 0.6321 Test: 0.6156
# Epoch: 279, Loss: 0.3106 tsm_loss: 0.1677 reg_loss: 0.1429 n_pos_triplets: 60190;  Val: 0.6487 Test: 0.6252
# Epoch: 280, Loss: 0.3665 tsm_loss: 0.1639 reg_loss: 0.2026 n_pos_triplets: 59809;  Val: 0.6501 Test: 0.6310
# Epoch: 281, Loss: 0.2898 tsm_loss: 0.1639 reg_loss: 0.1259 n_pos_triplets: 60910;  Val: 0.6338 Test: 0.6225
# Epoch: 282, Loss: 0.2963 tsm_loss: 0.1719 reg_loss: 0.1244 n_pos_triplets: 62601;  Val: 0.6314 Test: 0.6128
# Epoch: 283, Loss: 0.2963 tsm_loss: 0.1653 reg_loss: 0.1310 n_pos_triplets: 62031;  Val: 0.6291 Test: 0.6168
# Epoch: 284, Loss: 0.2829 tsm_loss: 0.1579 reg_loss: 0.1250 n_pos_triplets: 58587;  Val: 0.6259 Test: 0.6146
# Epoch: 285, Loss: 0.2908 tsm_loss: 0.1601 reg_loss: 0.1307 n_pos_triplets: 59245;  Val: 0.6401 Test: 0.6332
# Epoch: 286, Loss: 0.2659 tsm_loss: 0.1485 reg_loss: 0.1173 n_pos_triplets: 59264;  Val: 0.6324 Test: 0.6154
# Epoch: 287, Loss: 0.2917 tsm_loss: 0.1463 reg_loss: 0.1454 n_pos_triplets: 57999;  Val: 0.6349 Test: 0.6245
# Epoch: 288, Loss: 0.3247 tsm_loss: 0.1545 reg_loss: 0.1702 n_pos_triplets: 58349;  Val: 0.6415 Test: 0.6333
# Epoch: 289, Loss: 0.2859 tsm_loss: 0.1441 reg_loss: 0.1418 n_pos_triplets: 55647;  Val: 0.6288 Test: 0.6080
# Epoch: 290, Loss: 0.3033 tsm_loss: 0.1604 reg_loss: 0.1429 n_pos_triplets: 60767;  Val: 0.6320 Test: 0.6173
# Epoch: 291, Loss: 0.2813 tsm_loss: 0.1496 reg_loss: 0.1318 n_pos_triplets: 57202;  Val: 0.6339 Test: 0.6133
# Epoch: 292, Loss: 0.2998 tsm_loss: 0.1559 reg_loss: 0.1439 n_pos_triplets: 58253;  Val: 0.6336 Test: 0.6143
# Epoch: 293, Loss: 0.2980 tsm_loss: 0.1544 reg_loss: 0.1436 n_pos_triplets: 58007;  Val: 0.6701 Test: 0.6576
# Epoch: 294, Loss: 0.3483 tsm_loss: 0.1549 reg_loss: 0.1934 n_pos_triplets: 58711;  Val: 0.6420 Test: 0.6118
# Epoch: 295, Loss: 0.2982 tsm_loss: 0.1492 reg_loss: 0.1490 n_pos_triplets: 56974;  Val: 0.6332 Test: 0.6090
# Epoch: 296, Loss: 0.3021 tsm_loss: 0.1551 reg_loss: 0.1470 n_pos_triplets: 56691;  Val: 0.6448 Test: 0.6278
# Epoch: 297, Loss: 0.3169 tsm_loss: 0.1528 reg_loss: 0.1640 n_pos_triplets: 59130;  Val: 0.6371 Test: 0.6214
# Epoch: 298, Loss: 0.3205 tsm_loss: 0.1559 reg_loss: 0.1646 n_pos_triplets: 57347;  Val: 0.6347 Test: 0.6159
# Epoch: 299, Loss: 0.3267 tsm_loss: 0.1579 reg_loss: 0.1688 n_pos_triplets: 56431;  Val: 0.6417 Test: 0.6265
# Epoch: 300, Loss: 0.3385 tsm_loss: 0.1586 reg_loss: 0.1799 n_pos_triplets: 58800;  Val: 0.6475 Test: 0.6347
# Epoch: 301, Loss: 0.3586 tsm_loss: 0.1530 reg_loss: 0.2056 n_pos_triplets: 57698;  Val: 0.6448 Test: 0.6146
# Epoch: 302, Loss: 0.3195 tsm_loss: 0.1503 reg_loss: 0.1692 n_pos_triplets: 56218;  Val: 0.6529 Test: 0.6392
# Epoch: 303, Loss: 0.3261 tsm_loss: 0.1595 reg_loss: 0.1666 n_pos_triplets: 57316;  Val: 0.6452 Test: 0.6276
# Epoch: 304, Loss: 0.3420 tsm_loss: 0.1491 reg_loss: 0.1929 n_pos_triplets: 56948;  Val: 0.6425 Test: 0.6215
# Epoch: 305, Loss: 0.3841 tsm_loss: 0.1558 reg_loss: 0.2283 n_pos_triplets: 58232;  Val: 0.6855 Test: 0.6762
# Epoch: 306, Loss: 0.4481 tsm_loss: 0.1461 reg_loss: 0.3019 n_pos_triplets: 55283;  Val: 0.6611 Test: 0.6297
# Epoch: 307, Loss: 0.3806 tsm_loss: 0.1481 reg_loss: 0.2324 n_pos_triplets: 56035;  Val: 0.6641 Test: 0.6503
# Epoch: 308, Loss: 0.3763 tsm_loss: 0.1477 reg_loss: 0.2286 n_pos_triplets: 55798;  Val: 0.6585 Test: 0.6242
# Epoch: 309, Loss: 0.3322 tsm_loss: 0.1488 reg_loss: 0.1834 n_pos_triplets: 53910;  Val: 0.6518 Test: 0.6369
# Epoch: 310, Loss: 0.3023 tsm_loss: 0.1465 reg_loss: 0.1559 n_pos_triplets: 55848;  Val: 0.6353 Test: 0.6178
# Epoch: 311, Loss: 0.2949 tsm_loss: 0.1591 reg_loss: 0.1358 n_pos_triplets: 56041;  Val: 0.6430 Test: 0.6208
# Epoch: 312, Loss: 0.3001 tsm_loss: 0.1474 reg_loss: 0.1527 n_pos_triplets: 55446;  Val: 0.6808 Test: 0.6815
# Epoch: 313, Loss: 0.3622 tsm_loss: 0.1483 reg_loss: 0.2140 n_pos_triplets: 57303;  Val: 0.6476 Test: 0.6230
# Epoch: 314, Loss: 0.3393 tsm_loss: 0.1474 reg_loss: 0.1919 n_pos_triplets: 55746;  Val: 0.6466 Test: 0.6337
# Epoch: 315, Loss: 0.2840 tsm_loss: 0.1412 reg_loss: 0.1428 n_pos_triplets: 54017;  Val: 0.6343 Test: 0.6190
# Epoch: 316, Loss: 0.2908 tsm_loss: 0.1433 reg_loss: 0.1475 n_pos_triplets: 55092;  Val: 0.6313 Test: 0.6179
# Epoch: 317, Loss: 0.3454 tsm_loss: 0.1454 reg_loss: 0.2000 n_pos_triplets: 54737;  Val: 0.6630 Test: 0.6406
# Epoch: 318, Loss: 0.3327 tsm_loss: 0.1461 reg_loss: 0.1867 n_pos_triplets: 53865;  Val: 0.6487 Test: 0.6201
# Epoch: 319, Loss: 0.2991 tsm_loss: 0.1437 reg_loss: 0.1553 n_pos_triplets: 55023;  Val: 0.6457 Test: 0.6313
# Epoch: 320, Loss: 0.2927 tsm_loss: 0.1362 reg_loss: 0.1565 n_pos_triplets: 53408;  Val: 0.6322 Test: 0.6145
# Epoch: 321, Loss: 0.2792 tsm_loss: 0.1446 reg_loss: 0.1345 n_pos_triplets: 55197;  Val: 0.6324 Test: 0.6157
# Epoch: 322, Loss: 0.2507 tsm_loss: 0.1332 reg_loss: 0.1175 n_pos_triplets: 51994;  Val: 0.6318 Test: 0.6140
# Epoch: 323, Loss: 0.2599 tsm_loss: 0.1342 reg_loss: 0.1257 n_pos_triplets: 52923;  Val: 0.6455 Test: 0.6194
# Epoch: 324, Loss: 0.3126 tsm_loss: 0.1412 reg_loss: 0.1714 n_pos_triplets: 53945;  Val: 0.6711 Test: 0.6588
# Epoch: 325, Loss: 0.3126 tsm_loss: 0.1369 reg_loss: 0.1758 n_pos_triplets: 52700;  Val: 0.6364 Test: 0.6168
# Epoch: 326, Loss: 0.2659 tsm_loss: 0.1351 reg_loss: 0.1308 n_pos_triplets: 52584;  Val: 0.6378 Test: 0.6092
# Epoch: 327, Loss: 0.2583 tsm_loss: 0.1356 reg_loss: 0.1227 n_pos_triplets: 52728;  Val: 0.6541 Test: 0.6308
# Epoch: 328, Loss: 0.2856 tsm_loss: 0.1355 reg_loss: 0.1501 n_pos_triplets: 50123;  Val: 0.6425 Test: 0.6166
# Epoch: 329, Loss: 0.2755 tsm_loss: 0.1348 reg_loss: 0.1408 n_pos_triplets: 52742;  Val: 0.6529 Test: 0.6436
# Epoch: 330, Loss: 0.3231 tsm_loss: 0.1311 reg_loss: 0.1920 n_pos_triplets: 51766;  Val: 0.6345 Test: 0.6171
# Epoch: 331, Loss: 0.2623 tsm_loss: 0.1313 reg_loss: 0.1310 n_pos_triplets: 53365;  Val: 0.6492 Test: 0.6237
# Epoch: 332, Loss: 0.2947 tsm_loss: 0.1251 reg_loss: 0.1695 n_pos_triplets: 51033;  Val: 0.6524 Test: 0.6393
# Epoch: 333, Loss: 0.2606 tsm_loss: 0.1333 reg_loss: 0.1273 n_pos_triplets: 53423;  Val: 0.6321 Test: 0.6175
# Epoch: 334, Loss: 0.2476 tsm_loss: 0.1306 reg_loss: 0.1170 n_pos_triplets: 52531;  Val: 0.6307 Test: 0.6177
# Epoch: 335, Loss: 0.2634 tsm_loss: 0.1446 reg_loss: 0.1188 n_pos_triplets: 54349;  Val: 0.6317 Test: 0.6089
# Epoch: 336, Loss: 0.2604 tsm_loss: 0.1297 reg_loss: 0.1307 n_pos_triplets: 51561;  Val: 0.6382 Test: 0.6162
# Epoch: 337, Loss: 0.2774 tsm_loss: 0.1334 reg_loss: 0.1440 n_pos_triplets: 52619;  Val: 0.6406 Test: 0.6204
# Epoch: 338, Loss: 0.2465 tsm_loss: 0.1221 reg_loss: 0.1244 n_pos_triplets: 49273;  Val: 0.6559 Test: 0.6468
# Epoch: 339, Loss: 0.2622 tsm_loss: 0.1303 reg_loss: 0.1319 n_pos_triplets: 50399;  Val: 0.6347 Test: 0.6124
# Epoch: 340, Loss: 0.2809 tsm_loss: 0.1277 reg_loss: 0.1532 n_pos_triplets: 49353;  Val: 0.6342 Test: 0.6134
# Epoch: 341, Loss: 0.2404 tsm_loss: 0.1337 reg_loss: 0.1067 n_pos_triplets: 52845;  Val: 0.6330 Test: 0.6132
# Epoch: 342, Loss: 0.2558 tsm_loss: 0.1272 reg_loss: 0.1286 n_pos_triplets: 51836;  Val: 0.6386 Test: 0.6161
# Epoch: 343, Loss: 0.2459 tsm_loss: 0.1314 reg_loss: 0.1145 n_pos_triplets: 52781;  Val: 0.6307 Test: 0.6151
# Epoch: 344, Loss: 0.2561 tsm_loss: 0.1224 reg_loss: 0.1337 n_pos_triplets: 48510;  Val: 0.6430 Test: 0.6269
# Epoch: 345, Loss: 0.2923 tsm_loss: 0.1279 reg_loss: 0.1644 n_pos_triplets: 50076;  Val: 0.6409 Test: 0.6253
# Epoch: 346, Loss: 0.2664 tsm_loss: 0.1238 reg_loss: 0.1426 n_pos_triplets: 48728;  Val: 0.6430 Test: 0.6171
# Epoch: 347, Loss: 0.2511 tsm_loss: 0.1283 reg_loss: 0.1228 n_pos_triplets: 51967;  Val: 0.6408 Test: 0.6230
# Epoch: 348, Loss: 0.2492 tsm_loss: 0.1297 reg_loss: 0.1195 n_pos_triplets: 52288;  Val: 0.6388 Test: 0.6222
# Epoch: 349, Loss: 0.2451 tsm_loss: 0.1248 reg_loss: 0.1202 n_pos_triplets: 50701;  Val: 0.6369 Test: 0.6122
# Epoch: 350, Loss: 0.2439 tsm_loss: 0.1296 reg_loss: 0.1143 n_pos_triplets: 51586;  Val: 0.6352 Test: 0.6130
# Epoch: 351, Loss: 0.2388 tsm_loss: 0.1223 reg_loss: 0.1166 n_pos_triplets: 49845;  Val: 0.6369 Test: 0.6163
# Epoch: 352, Loss: 0.2581 tsm_loss: 0.1252 reg_loss: 0.1329 n_pos_triplets: 50892;  Val: 0.6704 Test: 0.6633
# Epoch: 353, Loss: 0.2518 tsm_loss: 0.1180 reg_loss: 0.1338 n_pos_triplets: 49329;  Val: 0.6411 Test: 0.6162
# Epoch: 354, Loss: 0.2640 tsm_loss: 0.1265 reg_loss: 0.1374 n_pos_triplets: 50531;  Val: 0.6360 Test: 0.6201
# Epoch: 355, Loss: 0.2658 tsm_loss: 0.1287 reg_loss: 0.1371 n_pos_triplets: 49352;  Val: 0.6490 Test: 0.6372
# Epoch: 356, Loss: 0.2394 tsm_loss: 0.1263 reg_loss: 0.1131 n_pos_triplets: 48851;  Val: 0.6349 Test: 0.6154
# Epoch: 357, Loss: 0.2443 tsm_loss: 0.1217 reg_loss: 0.1226 n_pos_triplets: 48654;  Val: 0.6632 Test: 0.6552
# Epoch: 358, Loss: 0.3354 tsm_loss: 0.1318 reg_loss: 0.2037 n_pos_triplets: 52554;  Val: 0.6403 Test: 0.6153
# Epoch: 359, Loss: 0.2565 tsm_loss: 0.1206 reg_loss: 0.1359 n_pos_triplets: 49585;  Val: 0.6320 Test: 0.6060
# Epoch: 360, Loss: 0.2488 tsm_loss: 0.1149 reg_loss: 0.1340 n_pos_triplets: 48477;  Val: 0.6499 Test: 0.6343
# Epoch: 361, Loss: 0.2764 tsm_loss: 0.1186 reg_loss: 0.1578 n_pos_triplets: 49091;  Val: 0.6469 Test: 0.6257
# Epoch: 362, Loss: 0.2110 tsm_loss: 0.1168 reg_loss: 0.0942 n_pos_triplets: 48621;  Val: 0.6374 Test: 0.6123
# Epoch: 363, Loss: 0.2683 tsm_loss: 0.1154 reg_loss: 0.1528 n_pos_triplets: 48096;  Val: 0.6411 Test: 0.6190
# Epoch: 364, Loss: 0.2859 tsm_loss: 0.1252 reg_loss: 0.1607 n_pos_triplets: 50405;  Val: 0.6418 Test: 0.6235
# Epoch: 365, Loss: 0.2271 tsm_loss: 0.1202 reg_loss: 0.1070 n_pos_triplets: 48008;  Val: 0.6343 Test: 0.6098
# Epoch: 366, Loss: 0.2672 tsm_loss: 0.1242 reg_loss: 0.1431 n_pos_triplets: 50395;  Val: 0.6374 Test: 0.6114
# Epoch: 367, Loss: 0.2293 tsm_loss: 0.1161 reg_loss: 0.1131 n_pos_triplets: 49870;  Val: 0.6580 Test: 0.6404
# Epoch: 368, Loss: 0.2768 tsm_loss: 0.1166 reg_loss: 0.1602 n_pos_triplets: 47354;  Val: 0.6485 Test: 0.6247
# Epoch: 369, Loss: 0.3106 tsm_loss: 0.1187 reg_loss: 0.1919 n_pos_triplets: 48191;  Val: 0.6552 Test: 0.6476
# Epoch: 370, Loss: 0.2550 tsm_loss: 0.1244 reg_loss: 0.1306 n_pos_triplets: 50243;  Val: 0.6392 Test: 0.6178
# Epoch: 371, Loss: 0.2687 tsm_loss: 0.1170 reg_loss: 0.1518 n_pos_triplets: 49050;  Val: 0.6371 Test: 0.6112
# Epoch: 372, Loss: 0.2458 tsm_loss: 0.1227 reg_loss: 0.1231 n_pos_triplets: 49035;  Val: 0.6368 Test: 0.6217
# Epoch: 373, Loss: 0.2299 tsm_loss: 0.1196 reg_loss: 0.1102 n_pos_triplets: 46786;  Val: 0.6444 Test: 0.6272
# Epoch: 374, Loss: 0.2275 tsm_loss: 0.1136 reg_loss: 0.1139 n_pos_triplets: 47568;  Val: 0.6362 Test: 0.6176
# Epoch: 375, Loss: 0.2233 tsm_loss: 0.1203 reg_loss: 0.1030 n_pos_triplets: 46698;  Val: 0.6334 Test: 0.6140
# Epoch: 376, Loss: 0.2349 tsm_loss: 0.1238 reg_loss: 0.1110 n_pos_triplets: 49016;  Val: 0.6387 Test: 0.6206
# Epoch: 377, Loss: 0.2244 tsm_loss: 0.1188 reg_loss: 0.1056 n_pos_triplets: 48827;  Val: 0.6343 Test: 0.6177
# Epoch: 378, Loss: 0.2494 tsm_loss: 0.1241 reg_loss: 0.1253 n_pos_triplets: 50383;  Val: 0.6384 Test: 0.6201
# Epoch: 379, Loss: 0.2398 tsm_loss: 0.1231 reg_loss: 0.1167 n_pos_triplets: 48538;  Val: 0.6533 Test: 0.6423
# Epoch: 380, Loss: 0.2545 tsm_loss: 0.1266 reg_loss: 0.1278 n_pos_triplets: 50700;  Val: 0.6319 Test: 0.6109
# Epoch: 381, Loss: 0.2262 tsm_loss: 0.1162 reg_loss: 0.1100 n_pos_triplets: 47564;  Val: 0.6386 Test: 0.6196
# Epoch: 382, Loss: 0.2213 tsm_loss: 0.1194 reg_loss: 0.1019 n_pos_triplets: 48210;  Val: 0.6366 Test: 0.6126
# Epoch: 383, Loss: 0.2788 tsm_loss: 0.1110 reg_loss: 0.1679 n_pos_triplets: 47005;  Val: 0.6415 Test: 0.6193
# Epoch: 384, Loss: 0.2660 tsm_loss: 0.1149 reg_loss: 0.1511 n_pos_triplets: 48661;  Val: 0.6357 Test: 0.6171
# Epoch: 385, Loss: 0.2431 tsm_loss: 0.1161 reg_loss: 0.1270 n_pos_triplets: 46484;  Val: 0.6287 Test: 0.6164
# Epoch: 386, Loss: 0.2215 tsm_loss: 0.1169 reg_loss: 0.1047 n_pos_triplets: 46420;  Val: 0.6279 Test: 0.6163
# Epoch: 387, Loss: 0.2374 tsm_loss: 0.1206 reg_loss: 0.1168 n_pos_triplets: 48682;  Val: 0.6288 Test: 0.6093
# Epoch: 388, Loss: 0.2152 tsm_loss: 0.1131 reg_loss: 0.1021 n_pos_triplets: 47533;  Val: 0.6360 Test: 0.6128
# Epoch: 389, Loss: 0.2300 tsm_loss: 0.1165 reg_loss: 0.1135 n_pos_triplets: 45979;  Val: 0.6487 Test: 0.6310
# Epoch: 390, Loss: 0.2119 tsm_loss: 0.1130 reg_loss: 0.0989 n_pos_triplets: 46589;  Val: 0.6322 Test: 0.6066
# Epoch: 391, Loss: 0.2800 tsm_loss: 0.1158 reg_loss: 0.1642 n_pos_triplets: 49248;  Val: 0.6338 Test: 0.6053
# Epoch: 392, Loss: 0.2473 tsm_loss: 0.1133 reg_loss: 0.1341 n_pos_triplets: 47603;  Val: 0.6438 Test: 0.6228
# Epoch: 393, Loss: 0.3185 tsm_loss: 0.1198 reg_loss: 0.1987 n_pos_triplets: 47531;  Val: 0.6472 Test: 0.6192
# Epoch: 394, Loss: 0.2895 tsm_loss: 0.1083 reg_loss: 0.1812 n_pos_triplets: 46201;  Val: 0.7072 Test: 0.7033
# Epoch: 395, Loss: 0.3488 tsm_loss: 0.1179 reg_loss: 0.2309 n_pos_triplets: 48922;  Val: 0.6620 Test: 0.6287
# Epoch: 396, Loss: 0.4791 tsm_loss: 0.1251 reg_loss: 0.3540 n_pos_triplets: 48813;  Val: 0.6432 Test: 0.6159
# Epoch: 397, Loss: 0.2851 tsm_loss: 0.1152 reg_loss: 0.1699 n_pos_triplets: 47602;  Val: 0.6397 Test: 0.6074
# Epoch: 398, Loss: 0.2478 tsm_loss: 0.1064 reg_loss: 0.1414 n_pos_triplets: 45443;  Val: 0.6390 Test: 0.6124
# Epoch: 399, Loss: 0.2547 tsm_loss: 0.1120 reg_loss: 0.1427 n_pos_triplets: 45961;  Val: 0.6503 Test: 0.6361
# Epoch: 400, Loss: 0.3085 tsm_loss: 0.1047 reg_loss: 0.2038 n_pos_triplets: 44600;  Val: 0.6451 Test: 0.6119
# Epoch: 401, Loss: 0.2418 tsm_loss: 0.1096 reg_loss: 0.1322 n_pos_triplets: 46378;  Val: 0.6437 Test: 0.6113
# Epoch: 402, Loss: 0.2094 tsm_loss: 0.1036 reg_loss: 0.1058 n_pos_triplets: 44642;  Val: 0.6351 Test: 0.6066
# Epoch: 403, Loss: 0.2287 tsm_loss: 0.1078 reg_loss: 0.1209 n_pos_triplets: 45980;  Val: 0.6338 Test: 0.6102
# Epoch: 404, Loss: 0.2149 tsm_loss: 0.1131 reg_loss: 0.1018 n_pos_triplets: 46583;  Val: 0.6445 Test: 0.6233
# Epoch: 405, Loss: 0.2322 tsm_loss: 0.1130 reg_loss: 0.1192 n_pos_triplets: 47047;  Val: 0.6351 Test: 0.6093
# Epoch: 406, Loss: 0.2132 tsm_loss: 0.1074 reg_loss: 0.1058 n_pos_triplets: 44818;  Val: 0.6381 Test: 0.6176
# Epoch: 407, Loss: 0.2402 tsm_loss: 0.1095 reg_loss: 0.1307 n_pos_triplets: 45456;  Val: 0.6413 Test: 0.6168
# Epoch: 408, Loss: 0.2555 tsm_loss: 0.1125 reg_loss: 0.1430 n_pos_triplets: 46699;  Val: 0.6401 Test: 0.6028
# Epoch: 409, Loss: 0.2552 tsm_loss: 0.1092 reg_loss: 0.1460 n_pos_triplets: 45609;  Val: 0.6458 Test: 0.6266
# Epoch: 410, Loss: 0.2358 tsm_loss: 0.1110 reg_loss: 0.1248 n_pos_triplets: 46105;  Val: 0.6383 Test: 0.6142
# Epoch: 411, Loss: 0.2132 tsm_loss: 0.1085 reg_loss: 0.1047 n_pos_triplets: 46542;  Val: 0.6357 Test: 0.6184
# Epoch: 412, Loss: 0.2095 tsm_loss: 0.1146 reg_loss: 0.0949 n_pos_triplets: 47358;  Val: 0.6283 Test: 0.6131
# Epoch: 413, Loss: 0.2113 tsm_loss: 0.1089 reg_loss: 0.1024 n_pos_triplets: 44895;  Val: 0.6328 Test: 0.6080
# Epoch: 414, Loss: 0.2064 tsm_loss: 0.1121 reg_loss: 0.0944 n_pos_triplets: 45799;  Val: 0.6409 Test: 0.6282
# Epoch: 415, Loss: 0.1989 tsm_loss: 0.1032 reg_loss: 0.0956 n_pos_triplets: 43858;  Val: 0.6350 Test: 0.6067
# Epoch: 416, Loss: 0.2116 tsm_loss: 0.1087 reg_loss: 0.1029 n_pos_triplets: 45401;  Val: 0.6375 Test: 0.6210
# Epoch: 417, Loss: 0.1876 tsm_loss: 0.1014 reg_loss: 0.0862 n_pos_triplets: 43948;  Val: 0.6342 Test: 0.6104
# Epoch: 418, Loss: 0.2136 tsm_loss: 0.1129 reg_loss: 0.1006 n_pos_triplets: 45916;  Val: 0.6312 Test: 0.6089
# Epoch: 419, Loss: 0.2160 tsm_loss: 0.1121 reg_loss: 0.1038 n_pos_triplets: 46465;  Val: 0.6408 Test: 0.6240
# Epoch: 420, Loss: 0.2154 tsm_loss: 0.1129 reg_loss: 0.1025 n_pos_triplets: 47237;  Val: 0.6379 Test: 0.6164
# Epoch: 421, Loss: 0.2285 tsm_loss: 0.1084 reg_loss: 0.1200 n_pos_triplets: 44038;  Val: 0.6452 Test: 0.6286
# Epoch: 422, Loss: 0.2499 tsm_loss: 0.1143 reg_loss: 0.1356 n_pos_triplets: 46635;  Val: 0.6319 Test: 0.6198
# Epoch: 423, Loss: 0.2393 tsm_loss: 0.1086 reg_loss: 0.1307 n_pos_triplets: 45388;  Val: 0.6360 Test: 0.6156
# Epoch: 424, Loss: 0.2263 tsm_loss: 0.1120 reg_loss: 0.1143 n_pos_triplets: 45680;  Val: 0.6451 Test: 0.6181
# Epoch: 425, Loss: 0.2258 tsm_loss: 0.1125 reg_loss: 0.1133 n_pos_triplets: 47754;  Val: 0.6343 Test: 0.6119
# Epoch: 426, Loss: 0.2032 tsm_loss: 0.1017 reg_loss: 0.1015 n_pos_triplets: 44978;  Val: 0.6305 Test: 0.6203
# Epoch: 427, Loss: 0.2136 tsm_loss: 0.1041 reg_loss: 0.1095 n_pos_triplets: 45392;  Val: 0.6336 Test: 0.6126
# Epoch: 428, Loss: 0.2191 tsm_loss: 0.1050 reg_loss: 0.1141 n_pos_triplets: 43298;  Val: 0.6385 Test: 0.6105
# Epoch: 429, Loss: 0.2514 tsm_loss: 0.1030 reg_loss: 0.1484 n_pos_triplets: 43808;  Val: 0.6311 Test: 0.6109
# Epoch: 430, Loss: 0.2254 tsm_loss: 0.1049 reg_loss: 0.1205 n_pos_triplets: 43049;  Val: 0.6337 Test: 0.6096
# Epoch: 431, Loss: 0.2051 tsm_loss: 0.0981 reg_loss: 0.1069 n_pos_triplets: 42391;  Val: 0.6414 Test: 0.6144
# Epoch: 432, Loss: 0.2304 tsm_loss: 0.1073 reg_loss: 0.1231 n_pos_triplets: 45041;  Val: 0.6391 Test: 0.6164
# Epoch: 433, Loss: 0.2438 tsm_loss: 0.1067 reg_loss: 0.1370 n_pos_triplets: 42693;  Val: 0.6345 Test: 0.6165
# Epoch: 434, Loss: 0.2109 tsm_loss: 0.1039 reg_loss: 0.1070 n_pos_triplets: 41664;  Val: 0.6552 Test: 0.6344
# Epoch: 435, Loss: 0.2111 tsm_loss: 0.1036 reg_loss: 0.1075 n_pos_triplets: 44850;  Val: 0.6466 Test: 0.6204
# Epoch: 436, Loss: 0.2102 tsm_loss: 0.0954 reg_loss: 0.1148 n_pos_triplets: 41735;  Val: 0.6393 Test: 0.6112
# Epoch: 437, Loss: 0.2323 tsm_loss: 0.1005 reg_loss: 0.1318 n_pos_triplets: 44501;  Val: 0.6464 Test: 0.6199
# Epoch: 438, Loss: 0.1804 tsm_loss: 0.0954 reg_loss: 0.0851 n_pos_triplets: 41491;  Val: 0.6356 Test: 0.6090
# ...
# Epoch: 404, Loss: 0.2444 tsm_loss: 0.1080 reg_loss: 0.1364 n_pos_triplets: 43575;  Val: 0.7363 Test: 0.7163
# Epoch: 405, Loss: 0.2597 tsm_loss: 0.1070 reg_loss: 0.1527 n_pos_triplets: 44429;  Val: 0.7197 Test: 0.6723
# Epoch: 406, Loss: 0.2199 tsm_loss: 0.1077 reg_loss: 0.1122 n_pos_triplets: 45151;  Val: 0.7158 Test: 0.6842
# Epoch: 407, Loss: 0.1989 tsm_loss: 0.1111 reg_loss: 0.0878 n_pos_triplets: 43221;  Val: 0.7241 Test: 0.6922
# Epoch: 408, Loss: 0.2036 tsm_loss: 0.1081 reg_loss: 0.0955 n_pos_triplets: 43406;  Val: 0.7199 Test: 0.6872
# Epoch: 409, Loss: 0.2152 tsm_loss: 0.1106 reg_loss: 0.1046 n_pos_triplets: 45080;  Val: 0.7359 Test: 0.7199
# Epoch: 410, Loss: 0.2516 tsm_loss: 0.1064 reg_loss: 0.1452 n_pos_triplets: 44181;  Val: 0.7259 Test: 0.6693
# Epoch: 411, Loss: 0.2368 tsm_loss: 0.1081 reg_loss: 0.1287 n_pos_triplets: 45279;  Val: 0.7141 Test: 0.6872
# Epoch: 412, Loss: 0.2154 tsm_loss: 0.1071 reg_loss: 0.1083 n_pos_triplets: 43529;  Val: 0.7381 Test: 0.7239
# Epoch: 413, Loss: 0.2576 tsm_loss: 0.1047 reg_loss: 0.1529 n_pos_triplets: 43959;  Val: 0.7322 Test: 0.6747
# Epoch: 414, Loss: 0.2367 tsm_loss: 0.1141 reg_loss: 0.1226 n_pos_triplets: 47620;  Val: 0.7209 Test: 0.6833
# Epoch: 415, Loss: 0.2120 tsm_loss: 0.1072 reg_loss: 0.1048 n_pos_triplets: 44583;  Val: 0.7260 Test: 0.6933
# Epoch: 416, Loss: 0.2054 tsm_loss: 0.1045 reg_loss: 0.1010 n_pos_triplets: 43582;  Val: 0.7174 Test: 0.6791
# Epoch: 417, Loss: 0.2069 tsm_loss: 0.1124 reg_loss: 0.0945 n_pos_triplets: 45691;  Val: 0.7208 Test: 0.6916
# Epoch: 418, Loss: 0.1996 tsm_loss: 0.1015 reg_loss: 0.0980 n_pos_triplets: 42774;  Val: 0.7188 Test: 0.6834
# Epoch: 419, Loss: 0.1931 tsm_loss: 0.1037 reg_loss: 0.0894 n_pos_triplets: 43552;  Val: 0.7166 Test: 0.6738
# Epoch: 420, Loss: 0.2209 tsm_loss: 0.1049 reg_loss: 0.1160 n_pos_triplets: 42502;  Val: 0.7236 Test: 0.6844
# Epoch: 421, Loss: 0.2152 tsm_loss: 0.1059 reg_loss: 0.1093 n_pos_triplets: 44900;  Val: 0.7200 Test: 0.6811
# Epoch: 422, Loss: 0.1992 tsm_loss: 0.1016 reg_loss: 0.0977 n_pos_triplets: 42596;  Val: 0.7159 Test: 0.6746
# Epoch: 423, Loss: 0.2433 tsm_loss: 0.0991 reg_loss: 0.1443 n_pos_triplets: 41436;  Val: 0.7371 Test: 0.7201
# Epoch: 424, Loss: 0.2557 tsm_loss: 0.1040 reg_loss: 0.1516 n_pos_triplets: 42372;  Val: 0.7200 Test: 0.6716
# Epoch: 425, Loss: 0.2172 tsm_loss: 0.1032 reg_loss: 0.1140 n_pos_triplets: 43094;  Val: 0.7222 Test: 0.7032
# Epoch: 426, Loss: 0.2205 tsm_loss: 0.0990 reg_loss: 0.1216 n_pos_triplets: 42953;  Val: 0.7207 Test: 0.6743
# Epoch: 427, Loss: 0.2370 tsm_loss: 0.1079 reg_loss: 0.1291 n_pos_triplets: 44413;  Val: 0.7204 Test: 0.6711
# Epoch: 428, Loss: 0.2207 tsm_loss: 0.1045 reg_loss: 0.1161 n_pos_triplets: 43081;  Val: 0.7260 Test: 0.7106
# Epoch: 429, Loss: 0.2002 tsm_loss: 0.1007 reg_loss: 0.0994 n_pos_triplets: 42704;  Val: 0.7230 Test: 0.6847
# Epoch: 430, Loss: 0.2052 tsm_loss: 0.1023 reg_loss: 0.1029 n_pos_triplets: 43501;  Val: 0.7167 Test: 0.6825
# Epoch: 431, Loss: 0.1931 tsm_loss: 0.0969 reg_loss: 0.0962 n_pos_triplets: 41120;  Val: 0.7153 Test: 0.6738
# Epoch: 432, Loss: 0.2067 tsm_loss: 0.1003 reg_loss: 0.1064 n_pos_triplets: 39538;  Val: 0.7169 Test: 0.6759
# Epoch: 433, Loss: 0.2065 tsm_loss: 0.0940 reg_loss: 0.1125 n_pos_triplets: 40934;  Val: 0.7178 Test: 0.6933
# Epoch: 434, Loss: 0.2082 tsm_loss: 0.1011 reg_loss: 0.1072 n_pos_triplets: 41769;  Val: 0.7182 Test: 0.6975
# Epoch: 435, Loss: 0.2166 tsm_loss: 0.1006 reg_loss: 0.1160 n_pos_triplets: 42608;  Val: 0.7155 Test: 0.6809
# Epoch: 436, Loss: 0.1964 tsm_loss: 0.1040 reg_loss: 0.0924 n_pos_triplets: 43912;  Val: 0.7148 Test: 0.6979
# Epoch: 437, Loss: 0.2039 tsm_loss: 0.1032 reg_loss: 0.1007 n_pos_triplets: 42116;  Val: 0.7271 Test: 0.7070
# Epoch: 438, Loss: 0.2079 tsm_loss: 0.1030 reg_loss: 0.1050 n_pos_triplets: 41586;  Val: 0.7283 Test: 0.6709
# Epoch: 439, Loss: 0.2432 tsm_loss: 0.1042 reg_loss: 0.1391 n_pos_triplets: 43585;  Val: 0.7156 Test: 0.6895
# Epoch: 440, Loss: 0.1951 tsm_loss: 0.1016 reg_loss: 0.0935 n_pos_triplets: 42537;  Val: 0.7228 Test: 0.6782
# Epoch: 441, Loss: 0.2221 tsm_loss: 0.1102 reg_loss: 0.1120 n_pos_triplets: 44124;  Val: 0.7205 Test: 0.6961
# Epoch: 442, Loss: 0.2264 tsm_loss: 0.1054 reg_loss: 0.1210 n_pos_triplets: 43651;  Val: 0.7379 Test: 0.6784
# Epoch: 443, Loss: 0.2796 tsm_loss: 0.1029 reg_loss: 0.1766 n_pos_triplets: 42291;  Val: 0.7255 Test: 0.6929
# Epoch: 444, Loss: 0.2307 tsm_loss: 0.0961 reg_loss: 0.1346 n_pos_triplets: 40777;  Val: 0.7195 Test: 0.6811
# Epoch: 445, Loss: 0.2169 tsm_loss: 0.0891 reg_loss: 0.1278 n_pos_triplets: 38680;  Val: 0.7162 Test: 0.6679
# Epoch: 446, Loss: 0.2210 tsm_loss: 0.1008 reg_loss: 0.1202 n_pos_triplets: 41595;  Val: 0.7185 Test: 0.6765
# Epoch: 447, Loss: 0.2068 tsm_loss: 0.1008 reg_loss: 0.1060 n_pos_triplets: 43572;  Val: 0.7289 Test: 0.6731
# Epoch: 448, Loss: 0.2223 tsm_loss: 0.1033 reg_loss: 0.1190 n_pos_triplets: 41519;  Val: 0.7388 Test: 0.7315
# Epoch: 449, Loss: 0.2245 tsm_loss: 0.0954 reg_loss: 0.1291 n_pos_triplets: 41379;  Val: 0.7180 Test: 0.6778
# Epoch: 450, Loss: 0.2080 tsm_loss: 0.0990 reg_loss: 0.1090 n_pos_triplets: 41643;  Val: 0.7212 Test: 0.6814
# Epoch: 451, Loss: 0.2272 tsm_loss: 0.1034 reg_loss: 0.1238 n_pos_triplets: 42721;  Val: 0.7367 Test: 0.7089
# Epoch: 452, Loss: 0.2089 tsm_loss: 0.0914 reg_loss: 0.1175 n_pos_triplets: 39216;  Val: 0.7194 Test: 0.6747
# Epoch: 453, Loss: 0.1834 tsm_loss: 0.0947 reg_loss: 0.0887 n_pos_triplets: 40808;  Val: 0.7152 Test: 0.6726
# Epoch: 454, Loss: 0.1786 tsm_loss: 0.0937 reg_loss: 0.0848 n_pos_triplets: 40236;  Val: 0.7265 Test: 0.6784
# Epoch: 455, Loss: 0.2042 tsm_loss: 0.0960 reg_loss: 0.1082 n_pos_triplets: 40448;  Val: 0.7288 Test: 0.6979
# Epoch: 456, Loss: 0.2016 tsm_loss: 0.0960 reg_loss: 0.1056 n_pos_triplets: 41848;  Val: 0.7148 Test: 0.6784
# Epoch: 457, Loss: 0.2169 tsm_loss: 0.0990 reg_loss: 0.1179 n_pos_triplets: 40351;  Val: 0.7173 Test: 0.6741
# Epoch: 458, Loss: 0.2224 tsm_loss: 0.0961 reg_loss: 0.1263 n_pos_triplets: 40087;  Val: 0.7406 Test: 0.7268
# Epoch: 459, Loss: 0.2735 tsm_loss: 0.0972 reg_loss: 0.1763 n_pos_triplets: 41878;  Val: 0.7324 Test: 0.6813
# Epoch: 460, Loss: 0.2189 tsm_loss: 0.0943 reg_loss: 0.1246 n_pos_triplets: 39526;  Val: 0.7280 Test: 0.7033
# Epoch: 461, Loss: 0.2599 tsm_loss: 0.1046 reg_loss: 0.1553 n_pos_triplets: 39660;  Val: 0.7246 Test: 0.6741
# Epoch: 462, Loss: 0.2249 tsm_loss: 0.0956 reg_loss: 0.1293 n_pos_triplets: 40376;  Val: 0.7226 Test: 0.6768
# Epoch: 463, Loss: 0.2170 tsm_loss: 0.1029 reg_loss: 0.1141 n_pos_triplets: 44375;  Val: 0.7225 Test: 0.6705
# Epoch: 464, Loss: 0.2064 tsm_loss: 0.0916 reg_loss: 0.1148 n_pos_triplets: 40014;  Val: 0.7190 Test: 0.6792
# Epoch: 465, Loss: 0.2240 tsm_loss: 0.0949 reg_loss: 0.1291 n_pos_triplets: 41486;  Val: 0.7329 Test: 0.7144
# Epoch: 466, Loss: 0.2551 tsm_loss: 0.0922 reg_loss: 0.1629 n_pos_triplets: 40172;  Val: 0.7288 Test: 0.6756
# Epoch: 467, Loss: 0.2492 tsm_loss: 0.0974 reg_loss: 0.1518 n_pos_triplets: 41427;  Val: 0.7203 Test: 0.6828
# Epoch: 468, Loss: 0.2212 tsm_loss: 0.0934 reg_loss: 0.1278 n_pos_triplets: 39052;  Val: 0.7400 Test: 0.7160
# Epoch: 469, Loss: 0.2387 tsm_loss: 0.0931 reg_loss: 0.1456 n_pos_triplets: 39612;  Val: 0.7304 Test: 0.6707
# Epoch: 470, Loss: 0.2177 tsm_loss: 0.0921 reg_loss: 0.1257 n_pos_triplets: 37621;  Val: 0.7322 Test: 0.7114
# Epoch: 471, Loss: 0.1924 tsm_loss: 0.0947 reg_loss: 0.0977 n_pos_triplets: 41198;  Val: 0.7208 Test: 0.6835
# Epoch: 472, Loss: 0.2024 tsm_loss: 0.0998 reg_loss: 0.1026 n_pos_triplets: 40999;  Val: 0.7188 Test: 0.6783
# Epoch: 473, Loss: 0.1919 tsm_loss: 0.0914 reg_loss: 0.1005 n_pos_triplets: 39583;  Val: 0.7198 Test: 0.6734
# Epoch: 474, Loss: 0.2175 tsm_loss: 0.0880 reg_loss: 0.1295 n_pos_triplets: 37882;  Val: 0.7203 Test: 0.6788
# Epoch: 475, Loss: 0.1906 tsm_loss: 0.0928 reg_loss: 0.0978 n_pos_triplets: 38539;  Val: 0.7241 Test: 0.6935
# Epoch: 476, Loss: 0.2035 tsm_loss: 0.0942 reg_loss: 0.1093 n_pos_triplets: 41739;  Val: 0.7253 Test: 0.6698
# Epoch: 477, Loss: 0.1893 tsm_loss: 0.0913 reg_loss: 0.0980 n_pos_triplets: 39215;  Val: 0.7251 Test: 0.6833
# Epoch: 478, Loss: 0.1777 tsm_loss: 0.0860 reg_loss: 0.0917 n_pos_triplets: 38642;  Val: 0.7336 Test: 0.7132
# Epoch: 479, Loss: 0.2163 tsm_loss: 0.0963 reg_loss: 0.1199 n_pos_triplets: 38836;  Val: 0.7299 Test: 0.6967
# Epoch: 480, Loss: 0.1901 tsm_loss: 0.0926 reg_loss: 0.0975 n_pos_triplets: 40202;  Val: 0.7297 Test: 0.6732
# Epoch: 481, Loss: 0.2249 tsm_loss: 0.0953 reg_loss: 0.1296 n_pos_triplets: 39534;  Val: 0.7142 Test: 0.6938
# Epoch: 482, Loss: 0.2623 tsm_loss: 0.0985 reg_loss: 0.1638 n_pos_triplets: 42260;  Val: 0.7113 Test: 0.6853
# Epoch: 483, Loss: 0.2060 tsm_loss: 0.0869 reg_loss: 0.1191 n_pos_triplets: 38180;  Val: 0.7171 Test: 0.6686
# Epoch: 484, Loss: 0.2108 tsm_loss: 0.0895 reg_loss: 0.1213 n_pos_triplets: 37899;  Val: 0.7276 Test: 0.7086
# Epoch: 485, Loss: 0.2230 tsm_loss: 0.0895 reg_loss: 0.1335 n_pos_triplets: 38447;  Val: 0.7271 Test: 0.6718
# Epoch: 486, Loss: 0.2275 tsm_loss: 0.0935 reg_loss: 0.1339 n_pos_triplets: 40550;  Val: 0.7153 Test: 0.6757
# Epoch: 487, Loss: 0.1827 tsm_loss: 0.0880 reg_loss: 0.0948 n_pos_triplets: 38141;  Val: 0.7266 Test: 0.7083
# Epoch: 488, Loss: 0.2205 tsm_loss: 0.0862 reg_loss: 0.1343 n_pos_triplets: 36962;  Val: 0.7211 Test: 0.6782
# Epoch: 489, Loss: 0.1888 tsm_loss: 0.0913 reg_loss: 0.0975 n_pos_triplets: 39475;  Val: 0.7192 Test: 0.6706
# Epoch: 490, Loss: 0.2166 tsm_loss: 0.0966 reg_loss: 0.1200 n_pos_triplets: 39428;  Val: 0.7254 Test: 0.7075
# Epoch: 491, Loss: 0.2115 tsm_loss: 0.0871 reg_loss: 0.1244 n_pos_triplets: 38949;  Val: 0.7252 Test: 0.6707
# Epoch: 492, Loss: 0.2516 tsm_loss: 0.0895 reg_loss: 0.1622 n_pos_triplets: 38580;  Val: 0.7256 Test: 0.6894
# Epoch: 493, Loss: 0.2020 tsm_loss: 0.0912 reg_loss: 0.1107 n_pos_triplets: 37963;  Val: 0.7181 Test: 0.6861
# Epoch: 494, Loss: 0.1711 tsm_loss: 0.0842 reg_loss: 0.0869 n_pos_triplets: 36724;  Val: 0.7190 Test: 0.6906
# Epoch: 495, Loss: 0.1832 tsm_loss: 0.0894 reg_loss: 0.0938 n_pos_triplets: 39535;  Val: 0.7211 Test: 0.6931
# Epoch: 496, Loss: 0.1738 tsm_loss: 0.0871 reg_loss: 0.0868 n_pos_triplets: 36796;  Val: 0.7129 Test: 0.6843
# Epoch: 497, Loss: 0.1935 tsm_loss: 0.0920 reg_loss: 0.1014 n_pos_triplets: 39635;  Val: 0.7171 Test: 0.6757
# Epoch: 498, Loss: 0.2315 tsm_loss: 0.0877 reg_loss: 0.1438 n_pos_triplets: 39744;  Val: 0.7234 Test: 0.6708
# Epoch: 499, Loss: 0.2038 tsm_loss: 0.0871 reg_loss: 0.1167 n_pos_triplets: 38098;  Val: 0.7196 Test: 0.6866
# Epoch: 500, Loss: 0.1688 tsm_loss: 0.0828 reg_loss: 0.0861 n_pos_triplets: 34947;  Val: 0.7234 Test: 0.7025
# Epoch: 501, Loss: 0.2346 tsm_loss: 0.0877 reg_loss: 0.1468 n_pos_triplets: 37725;  Val: 0.7212 Test: 0.6741
# Epoch: 502, Loss: 0.2054 tsm_loss: 0.0887 reg_loss: 0.1167 n_pos_triplets: 38308;  Val: 0.7162 Test: 0.6792
# Epoch: 503, Loss: 0.1795 tsm_loss: 0.0875 reg_loss: 0.0920 n_pos_triplets: 37293;  Val: 0.7192 Test: 0.6964
# Epoch: 504, Loss: 0.1706 tsm_loss: 0.0856 reg_loss: 0.0850 n_pos_triplets: 38734;  Val: 0.7115 Test: 0.6760
# Epoch: 505, Loss: 0.1667 tsm_loss: 0.0859 reg_loss: 0.0808 n_pos_triplets: 38145;  Val: 0.7148 Test: 0.6888
# Epoch: 506, Loss: 0.1644 tsm_loss: 0.0834 reg_loss: 0.0810 n_pos_triplets: 37351;  Val: 0.7182 Test: 0.6923
# Epoch: 507, Loss: 0.1787 tsm_loss: 0.0860 reg_loss: 0.0927 n_pos_triplets: 37881;  Val: 0.7170 Test: 0.6873
# Epoch: 508, Loss: 0.1884 tsm_loss: 0.0843 reg_loss: 0.1042 n_pos_triplets: 36546;  Val: 0.7274 Test: 0.6707
# Epoch: 509, Loss: 0.1965 tsm_loss: 0.0845 reg_loss: 0.1120 n_pos_triplets: 37870;  Val: 0.7238 Test: 0.6817
# Epoch: 510, Loss: 0.1513 tsm_loss: 0.0785 reg_loss: 0.0729 n_pos_triplets: 35502;  Val: 0.7201 Test: 0.6842
# Epoch: 511, Loss: 0.1789 tsm_loss: 0.0848 reg_loss: 0.0941 n_pos_triplets: 37638;  Val: 0.7276 Test: 0.6983
# Epoch: 512, Loss: 0.1894 tsm_loss: 0.0839 reg_loss: 0.1055 n_pos_triplets: 36903;  Val: 0.7183 Test: 0.6717
# Epoch: 513, Loss: 0.1911 tsm_loss: 0.0846 reg_loss: 0.1066 n_pos_triplets: 36489;  Val: 0.7176 Test: 0.6921
# Epoch: 514, Loss: 0.1804 tsm_loss: 0.0845 reg_loss: 0.0958 n_pos_triplets: 37125;  Val: 0.7111 Test: 0.6875
# Epoch: 515, Loss: 0.1650 tsm_loss: 0.0832 reg_loss: 0.0818 n_pos_triplets: 36764;  Val: 0.7105 Test: 0.6810
# Epoch: 516, Loss: 0.1917 tsm_loss: 0.0846 reg_loss: 0.1071 n_pos_triplets: 36755;  Val: 0.7248 Test: 0.6946
# Epoch: 517, Loss: 0.2170 tsm_loss: 0.0889 reg_loss: 0.1281 n_pos_triplets: 37911;  Val: 0.7212 Test: 0.6942
# Epoch: 518, Loss: 0.1669 tsm_loss: 0.0825 reg_loss: 0.0844 n_pos_triplets: 36589;  Val: 0.7163 Test: 0.6852
# Epoch: 519, Loss: 0.1774 tsm_loss: 0.0807 reg_loss: 0.0967 n_pos_triplets: 35104;  Val: 0.7184 Test: 0.6876
# Epoch: 520, Loss: 0.1644 tsm_loss: 0.0833 reg_loss: 0.0811 n_pos_triplets: 36412;  Val: 0.7225 Test: 0.7039
# Epoch: 521, Loss: 0.1848 tsm_loss: 0.0871 reg_loss: 0.0977 n_pos_triplets: 36667;  Val: 0.7210 Test: 0.6899
# Epoch: 522, Loss: 0.1686 tsm_loss: 0.0836 reg_loss: 0.0850 n_pos_triplets: 36609;  Val: 0.7247 Test: 0.7044
# Epoch: 523, Loss: 0.1972 tsm_loss: 0.0878 reg_loss: 0.1094 n_pos_triplets: 37590;  Val: 0.7343 Test: 0.6782
# Epoch: 524, Loss: 0.1830 tsm_loss: 0.0832 reg_loss: 0.0998 n_pos_triplets: 36466;  Val: 0.7230 Test: 0.6783
# Epoch: 525, Loss: 0.1843 tsm_loss: 0.0841 reg_loss: 0.1001 n_pos_triplets: 37163;  Val: 0.7226 Test: 0.6770
# Epoch: 526, Loss: 0.1924 tsm_loss: 0.0885 reg_loss: 0.1039 n_pos_triplets: 38497;  Val: 0.7293 Test: 0.7058
# Epoch: 527, Loss: 0.1905 tsm_loss: 0.0805 reg_loss: 0.1099 n_pos_triplets: 35647;  Val: 0.7242 Test: 0.7012
# Epoch: 528, Loss: 0.1666 tsm_loss: 0.0830 reg_loss: 0.0835 n_pos_triplets: 36458;  Val: 0.7197 Test: 0.6841
# Epoch: 529, Loss: 0.1631 tsm_loss: 0.0774 reg_loss: 0.0857 n_pos_triplets: 34956;  Val: 0.7162 Test: 0.6916
# Epoch: 530, Loss: 0.1787 tsm_loss: 0.0870 reg_loss: 0.0918 n_pos_triplets: 38538;  Val: 0.7155 Test: 0.6775
# Epoch: 531, Loss: 0.1675 tsm_loss: 0.0814 reg_loss: 0.0861 n_pos_triplets: 36194;  Val: 0.7184 Test: 0.7045
# Epoch: 532, Loss: 0.1629 tsm_loss: 0.0756 reg_loss: 0.0874 n_pos_triplets: 36306;  Val: 0.7242 Test: 0.6850
# Epoch: 533, Loss: 0.1724 tsm_loss: 0.0810 reg_loss: 0.0914 n_pos_triplets: 36915;  Val: 0.7245 Test: 0.7054
# Epoch: 534, Loss: 0.1735 tsm_loss: 0.0857 reg_loss: 0.0878 n_pos_triplets: 36176;  Val: 0.7144 Test: 0.6818
# Epoch: 535, Loss: 0.1746 tsm_loss: 0.0806 reg_loss: 0.0940 n_pos_triplets: 36636;  Val: 0.7163 Test: 0.6876
# Epoch: 536, Loss: 0.1822 tsm_loss: 0.0849 reg_loss: 0.0972 n_pos_triplets: 37462;  Val: 0.7185 Test: 0.7060
# Epoch: 537, Loss: 0.1761 tsm_loss: 0.0810 reg_loss: 0.0950 n_pos_triplets: 35645;  Val: 0.7310 Test: 0.6826
# Epoch: 538, Loss: 0.2226 tsm_loss: 0.0860 reg_loss: 0.1366 n_pos_triplets: 37261;  Val: 0.7190 Test: 0.6819
# Epoch: 539, Loss: 0.1757 tsm_loss: 0.0851 reg_loss: 0.0905 n_pos_triplets: 36775;  Val: 0.7165 Test: 0.6907
# Epoch: 540, Loss: 0.2033 tsm_loss: 0.0827 reg_loss: 0.1206 n_pos_triplets: 35184;  Val: 0.7192 Test: 0.6988
# Epoch: 541, Loss: 0.2052 tsm_loss: 0.0811 reg_loss: 0.1241 n_pos_triplets: 36495;  Val: 0.7338 Test: 0.6810
# Epoch: 542, Loss: 0.2169 tsm_loss: 0.0913 reg_loss: 0.1256 n_pos_triplets: 38891;  Val: 0.7468 Test: 0.7213
# Epoch: 543, Loss: 0.2318 tsm_loss: 0.0821 reg_loss: 0.1497 n_pos_triplets: 36104;  Val: 0.7270 Test: 0.6773
# Epoch: 544, Loss: 0.1718 tsm_loss: 0.0818 reg_loss: 0.0900 n_pos_triplets: 36328;  Val: 0.7260 Test: 0.6978
# Epoch: 545, Loss: 0.1785 tsm_loss: 0.0773 reg_loss: 0.1012 n_pos_triplets: 34217;  Val: 0.7234 Test: 0.6972
# Epoch: 546, Loss: 0.1674 tsm_loss: 0.0773 reg_loss: 0.0901 n_pos_triplets: 33949;  Val: 0.7231 Test: 0.6844
# Epoch: 547, Loss: 0.1548 tsm_loss: 0.0798 reg_loss: 0.0750 n_pos_triplets: 34844;  Val: 0.7174 Test: 0.6842
# Epoch: 548, Loss: 0.1585 tsm_loss: 0.0846 reg_loss: 0.0739 n_pos_triplets: 35893;  Val: 0.7302 Test: 0.7146
# Epoch: 549, Loss: 0.1820 tsm_loss: 0.0810 reg_loss: 0.1010 n_pos_triplets: 36281;  Val: 0.7250 Test: 0.6792
# Epoch: 550, Loss: 0.1602 tsm_loss: 0.0817 reg_loss: 0.0784 n_pos_triplets: 36729;  Val: 0.7146 Test: 0.6817
# Epoch: 551, Loss: 0.1678 tsm_loss: 0.0819 reg_loss: 0.0858 n_pos_triplets: 36684;  Val: 0.7202 Test: 0.7031

# %%
df1 = pd.concat(res1)
df2 = pd.concat(res2)

# %%
df1.to_csv('./with_aca.csv')
df2.to_csv('./without_aca.csv')

# %%
fig, ax = plt.subplots(figsize=(9, 6))
colors = ['#FFE699','#00B0F0']


y = 'val_rmse'

n1 = r'With AC-awareness ($\mathcal{L}_{mae} + \mathcal{L}_{tsm}$)'
n2 = r'Without AC-awareness ($\mathcal{L}_{mae}$)'


dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 2, ax=ax,color = colors, alpha =1)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.2)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.2)

ax.set_ylim(0.60, 1.0)
ax.set_ylabel('Validation RMSE')
ax.set_xlabel('epochs')
ax.spines[['right', 'top']].set_visible(False)

ax.set_xlim(1,800)

ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Validation_RMSE.svg', bbox_inches='tight', dpi=400) 
fig.savefig('./Validation_RMSE.pdf', bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))
colors = ['#FFE699','#00B0F0']


y = 'test_rmse'



dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 2, ax=ax,color = colors, alpha =1)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.2)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.2)

ax.set_ylim(0.60, 1.0)
ax.set_ylabel('Test RMSE')
ax.set_xlabel('epochs')
ax.spines[['right', 'top']].set_visible(False)

ax.set_xlim(1,800)

ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Test_RMSE.svg' , bbox_inches='tight', dpi=400) 
fig.savefig('./Test_RMSE.pdf' , bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))


y = 'n_pos_triplets'

dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 3, ax=ax,color = colors, alpha =1)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.3)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.3)

ax.legend(loc='center', bbox_to_anchor=(0.55, 0.5))

ax.spines[['right', 'top']].set_visible(False)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax.set_ylabel("No. of HV-ACTs ($M^'$)")
ax.set_xlabel('epochs')
ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
ax.set_xlim(-5,800)


fig.savefig('./Number_of_mined_ACTs_during_training.svg' , bbox_inches='tight', dpi=400) 
fig.savefig('./Number_of_mined_ACTs_during_training.pdf' , bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))
y = 'train_triplet_loss'
dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 3, ax=ax,color = colors, alpha =1)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.3)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.3)

ax.spines[['right', 'top']].set_visible(False)
ax.set_xlim(-5,800)
ax.set_ylim(-1,10)

ax.set_ylabel('Training TSM Loss')
ax.set_xlabel('epochs')
ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Triplet_loss_during_training.svg', bbox_inches='tight', dpi=400) 
fig.savefig('./Triplet_loss_during_training.pdf', bbox_inches='tight', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(9, 6))

y = 'train_mae_loss'

dfp = df2.groupby('Epoch').mean()[y].to_frame(name = n2).join(df1.groupby('Epoch').mean()[y].to_frame(name = n1)).rolling(1).mean()
dfp_std = df2.groupby('Epoch').std()[y].to_frame(name = n2).join(df1.groupby('Epoch').std()[y].to_frame(name = n1)).rolling(1).mean()

dfp.plot(lw = 2.5, ax=ax,color = colors, alpha =1)
ax.fill_between(dfp.index, (dfp - dfp_std)[n1], (dfp + dfp_std)[n1], color=colors[1], alpha=0.3)
ax.fill_between(dfp.index, (dfp - dfp_std)[n2], (dfp + dfp_std)[n2], color=colors[0], alpha=0.3)



ax.set_ylim(0.0, 0.8)
ax.spines[['right', 'top']].set_visible(False)


ax.set_ylabel('Training MAE loss')
ax.set_xlabel('epochs')
ax.legend(loc='center', bbox_to_anchor=(0.55, 0.5))

ax.set_xlim(1,800)

ax.tick_params(left='off', labelleft='on', labelbottom='on', bottom = 'off',  pad=.5,)
fig.savefig('./Train_mae_los.svg', bbox_inches='tight', dpi=400) 
fig.savefig('./Train_mae_los.pdf', bbox_inches='tight', dpi=400)
